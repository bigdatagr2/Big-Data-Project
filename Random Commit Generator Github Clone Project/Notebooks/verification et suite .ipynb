# %%
import json
import requests
import pandas as pd
headers = {'Content-Type':'Application/json'}
root = 'http://88.169.46.187:9200'
database = root + '/github'

# %%
requests.put(root + '/_sarch',headers=headers, data=json.dumps(

    {
    "index": {
    "blocks": {
    "read_only_allow_delete": "false"
    }
    }
    }
)).json()

# %%
requests.get(database + '/_search?',headers=headers, data=json.dumps({
 "size": 0,
    "aggs": {
        "nb_type": {
            "terms": {
                "field" : "repo.name",
                 "size": 20
            }
        }
    }
})).json()
#    "size": 0,
# Out:
# {'_shards': {'failed': 0, 'skipped': 0, 'successful': 1, 'total': 1},
#  'aggregations': {'nb_type': {'buckets': [{'doc_count': 268508,
#      'key': 'unitydemo2/Docworks'},
#     {'doc_count': 183685,
#      'key': 'dipper-github-fra-sin-syd-nrt/test-python-sample'},
#     {'doc_count': 137443,
#      'key': 'dipper-github-lhr-yul-sfo-icn/test-python-sample'},
#     {'doc_count': 122596, 'key': 'shenzhouzd/update'},
#     {'doc_count': 80515, 'key': 'direwolf-github/my-app'},
#     {'doc_count': 63509,
#      'key': 'dipper-github-fra-sin-syd-nrt/test-ruby-sample'},
#     {'doc_count': 62876, 'key': 'dotclear/dotclear'},
#     {'doc_count': 60179, 'key': 'CodePipeline-Test/feature-tests'},
#     {'doc_count': 52995, 'key': 'TalibAzir/AllahPadishah'},
#     {'doc_count': 52478, 'key': 'nicopeters/sigrhtest'},
#     {'doc_count': 50869, 'key': 'kubernetes/kubernetes'},
#     {'doc_count': 45880,
#      'key': 'dipper-github-icn-bom-cdg/test-python-sample'},
# ...

# %%
xres = requests.get(database + '/_search?',headers=headers, data=json.dumps({
 "size": 0,
    "aggs": {
        "nb_type": {
            "terms": {
                "field" : "type",
                "size": 20
            }
        }
    }
})).json()
display(xres['aggregations']['nb_type']['buckets'])
#    "size": 0,
# display (pd.DataFrame(xres))

display (pd.DataFrame(xres['aggregations']))

# display (pd.DataFrame(xres['aggregations']['nb_type']))

display(pd.DataFrame(xres['aggregations']['nb_type']['buckets']))
# Out:
# [{'doc_count': 25378468, 'key': 'PushEvent'},
#  {'doc_count': 6988049, 'key': 'CreateEvent'},
#  {'doc_count': 4186030, 'key': 'WatchEvent'},
#  {'doc_count': 3456161, 'key': 'IssueCommentEvent'},
#  {'doc_count': 2642784, 'key': 'PullRequestEvent'},
#  {'doc_count': 1753088, 'key': 'IssuesEvent'},
#  {'doc_count': 1413459, 'key': 'ForkEvent'},
#  {'doc_count': 1331844, 'key': 'DeleteEvent'},
#  {'doc_count': 862828, 'key': 'PullRequestReviewCommentEvent'},
#  {'doc_count': 319486, 'key': 'GollumEvent'},
#  {'doc_count': 235272, 'key': 'MemberEvent'},
#  {'doc_count': 180661, 'key': 'ReleaseEvent'},
#  {'doc_count': 99237, 'key': 'CommitCommentEvent'},
#  {'doc_count': 50757, 'key': 'PublicEvent'}]
#                                                                        nb_type
# buckets                      [{'key': 'PushEvent', 'doc_count': 25378468}, ...
# doc_count_error_upper_bound                                                  0
# ...

# %%
xres = requests.post(database + '/_search?',headers=headers, data=json.dumps({
 "size": 0,
    "aggs": {
        "nb_type": {
            "terms": {
                "field" : "type",
                
            },
            "aggs" : {
            "note_moyenne" : {"avg" : {"field" : "id"}},
            "note_min" : {"min" : {"field" : "id"}},
            "note_max" : {"max" : {"field" : "id"}}
        }
        }
    }
})).json()

# display(xres['aggregations']['nb_type']['buckets'])
#    "size": 0,
# display (pd.DataFrame(xres))

# display (pd.DataFrame(xres['aggregations']))

# display (pd.DataFrame(xres['aggregations']['nb_type']))


xbucket=xres['aggregations']['nb_type']['buckets']
display(pd.DataFrame(xbucket))
# display(pd.DataFrame([[x[0] +  (':' + str(x[1]['value']) if isinstance(x[1],dict) else ':' + str(x[1])) for x in d.items()] for d in xbucket], columns=xbucket[0].keys())) 
display(pd.DataFrame([[ ( str(x[1]['value']) if isinstance(x[1],dict) else  str(x[1])) for x in d.items()] for d in xbucket], columns=xbucket[0].keys())) 

# [[x[0] + ':' + str(json.loads(x[1].replace("'",'"'))) for x in d.items()] for d in xres['aggregations']['nb_type']['buckets']] 
# [d[0],d[1],d[2],d[3].get('value', 'alt')]  
#    "size": 0,
# Out:
#    doc_count                            key                 note_max  \
# 0   25378468                      PushEvent  {'value': 7183297066.0}
# 1    6988049                    CreateEvent  {'value': 7183297063.0}
# 2    4186030                     WatchEvent  {'value': 7183297017.0}
# 3    3456161              IssueCommentEvent  {'value': 7183297032.0}
# 4    2642784               PullRequestEvent  {'value': 7183296917.0}
# 5    1753088                    IssuesEvent  {'value': 7183297001.0}
# 6    1413459                      ForkEvent  {'value': 7183297035.0}
# 7    1331844                    DeleteEvent  {'value': 7183296964.0}
# 8     862828  PullRequestReviewCommentEvent  {'value': 7183297050.0}
# 9     319486                    GollumEvent  {'value': 7183296712.0}
#
#                   note_min                   note_moyenne
# 0  {'value': 3709939278.0}  {'value': 6629627022.9680805}
# 1  {'value': 3709939302.0}   {'value': 6580197215.669279}
# ...

# %%
xres=requests.get(database + '/_search?',headers=headers, data=json.dumps({
 "size": 0,
    "aggs": {
        "nb_type": {
            "terms": {
                "field" : "created_at",
                "size" : 20
            }
        }
    }
})).json()
#    "size": 0,
display(xres)
xbucket=xres['aggregations']['nb_type']['buckets']
display(pd.DataFrame(xbucket))
# Out:
# {'_shards': {'failed': 0, 'skipped': 0, 'successful': 1, 'total': 1},
#  'aggregations': {'nb_type': {'buckets': [{'doc_count': 214,
#      'key': 1517331871000,
#      'key_as_string': '2018-01-30T17:04:31.000Z'},
#     {'doc_count': 198,
#      'key': 1516643199000,
#      'key_as_string': '2018-01-22T17:46:39.000Z'},
#     {'doc_count': 192,
#      'key': 1516645645000,
#      'key_as_string': '2018-01-22T18:27:25.000Z'},
#     {'doc_count': 191,
#      'key': 1516821457000,
#      'key_as_string': '2018-01-24T19:17:37.000Z'},
#     {'doc_count': 189,
#      'key': 1516645496000,
#      'key_as_string': '2018-01-22T18:24:56.000Z'},
#     {'doc_count': 189,
#      'key': 1516645625000,
#      'key_as_string': '2018-01-22T18:27:05.000Z'},
#     {'doc_count': 188,
#      'key': 1516644235000,
#      'key_as_string': '2018-01-22T18:03:55.000Z'},
#     {'doc_count': 187,
#      'key': 1516641047000,
#      'key_as_string': '2018-01-22T17:10:47.000Z'},
#     {'doc_count': 186,
# ...

# %%
xres=requests.get(database + '/_search?',headers=headers, data=json.dumps({
 "size": 0,
    "aggs": {
        "nb_type": {
            "terms": {
                "field" : "created_at",
                "size" : 20
            }
        }
    }
})).json()
#    "size": 0,
display(xres)
xbucket=xres['aggregations']['nb_type']['buckets']
display(pd.DataFrame(xbucket))
# Out:
# {'_shards': {'failed': 0, 'skipped': 0, 'successful': 1, 'total': 1},
#  'aggregations': {'nb_type': {'buckets': [{'doc_count': 214,
#      'key': 1517331871000,
#      'key_as_string': '2018-01-30T17:04:31.000Z'},
#     {'doc_count': 198,
#      'key': 1516643199000,
#      'key_as_string': '2018-01-22T17:46:39.000Z'},
#     {'doc_count': 192,
#      'key': 1516645645000,
#      'key_as_string': '2018-01-22T18:27:25.000Z'},
#     {'doc_count': 191,
#      'key': 1516821457000,
#      'key_as_string': '2018-01-24T19:17:37.000Z'},
#     {'doc_count': 189,
#      'key': 1516645496000,
#      'key_as_string': '2018-01-22T18:24:56.000Z'},
#     {'doc_count': 189,
#      'key': 1516645625000,
#      'key_as_string': '2018-01-22T18:27:05.000Z'},
#     {'doc_count': 188,
#      'key': 1516644235000,
#      'key_as_string': '2018-01-22T18:03:55.000Z'},
#     {'doc_count': 187,
#      'key': 1516641047000,
#      'key_as_string': '2018-01-22T17:10:47.000Z'},
#     {'doc_count': 186,
# ...

# %%
xres = requests.post(database + '/_search?',headers=headers, data=json.dumps({
 "size": 0,
        "aggs" : {
        "note_moyenne" : {"avg" : {"field" : "id"}},
        "note_min" : {"min" : {"field" : "id"}},
        "note_max" : {"max" : {"field" : "id"}}
    }
 }

)).json()

# %%
xres['aggregations']
# Out:
# {'note_max': {'value': 7183297066.0},
#  'note_min': {'value': 3709939278.0},
#  'note_moyenne': {'value': 6610948867.49936}}

# %%
xres2 = requests.post(database + '/_search?',headers=headers, data=json.dumps({
 "size": 0,
        
"aggs" : {
    "Trance_ID" : {
        "histogram" : {
            "field" : "id",
            "interval" : 1000000000,
                    }
                }
            }
        
 }

)).json()
xres2['aggregations']['Trance_ID']['buckets']
# Out:
# [{'doc_count': 203882, 'key': 3000000000.0},
#  {'doc_count': 0, 'key': 4000000000.0},
#  {'doc_count': 12253501, 'key': 5000000000.0},
#  {'doc_count': 0, 'key': 6000000000.0},
#  {'doc_count': 36440741, 'key': 7000000000.0}]

# %%
xres2 = requests.post(database + '/_search?',headers=headers, data=json.dumps({
    "query" :{
        "wildcard" : {"type" : "*Event"}
    },
    
"size": 0,
        
"aggs" : {
    "Trance_ID" : {
        "histogram" : {
            "field" : "id",
            "interval" : 1000000000,
                    }
                }
            }
        
 }

)).json()
# xres2
xres2['aggregations']['Trance_ID']['buckets']
# Out:
# [{'doc_count': 203882, 'key': 3000000000.0},
#  {'doc_count': 0, 'key': 4000000000.0},
#  {'doc_count': 12253501, 'key': 5000000000.0},
#  {'doc_count': 0, 'key': 6000000000.0},
#  {'doc_count': 36440741, 'key': 7000000000.0}]

# %%
requests.get(database + '/_search?',headers=headers, data=json.dumps(
{
  "query": {
    "function_score": {
      "query": {
        "match_all": {}
      },
      "functions": [
        {
          "random_score": {}
        }
      ]
    }
  }

    ,"size":20
    ,"_source":["type","created_at","id","repo.id","repo.name","actor.id"]
}    

)).json()
#    "size": 0,
# Out:
# {'_shards': {'failed': 0, 'skipped': 0, 'successful': 1, 'total': 1},
#  'hits': {'hits': [{'_id': '7065484811',
#     '_index': 'github',
#     '_score': 0.99999976,
#     '_source': {'actor': {'id': 26122193},
#      'created_at': '2018-01-06T20:37:52Z',
#      'id': '7065484811',
#      'repo': {'id': 111715346, 'name': 'ugkontzal/ussr'},
#      'type': 'PushEvent'},
#     '_type': 'data'},
#    {'_id': '5114873245',
#     '_index': 'github',
#     '_score': 0.99999976,
#     '_source': {'actor': {'id': 2352663},
#      'created_at': '2017-01-06T19:55:46Z',
#      'id': '5114873245',
#      'repo': {'id': 27193779, 'name': 'nodejs/node'},
#      'type': 'IssueCommentEvent'},
#     '_type': 'data'},
#    {'_id': '7067519152',
#     '_index': 'github',
#     '_score': 0.99999976,
#     '_source': {'actor': {'id': 7740438},
#      'created_at': '2018-01-08T00:04:37Z',
#      'id': '7067519152',
#      'repo': {'id': 116609025, 'name': 'marcospy/dotfiles'},
# ...

# %%
requests.get(database + '/_search?',headers=headers, data=json.dumps(
{
  "query": {
    "function_score": {
      "query": {
        "match_all": {}
      },
      "functions": [
        {
          "random_score": {}
        }
      ]
    }
  }

    ,"size":20
    ,"_source":["type","created_at","id","repo.id","repo.name","actor.id"]
}    

)).json()
#    "size": 0,
# Out:
# {'_shards': {'failed': 0, 'skipped': 0, 'successful': 1, 'total': 1},
#  'hits': {'hits': [{'_id': '7067001306',
#     '_index': 'github',
#     '_score': 0.9999998,
#     '_source': {'actor': {'id': 7187815},
#      'created_at': '2018-01-07T17:57:50Z',
#      'id': '7067001306',
#      'repo': {'id': 45750356, 'name': 'facebook/mention-bot'},
#      'type': 'WatchEvent'},
#     '_type': 'data'},
#    {'_id': '7096624219',
#     '_index': 'github',
#     '_score': 0.9999998,
#     '_source': {'actor': {'id': 9133893},
#      'created_at': '2018-01-14T09:59:41Z',
#      'id': '7096624219',
#      'repo': {'id': 116606627,
#       'name': 'DevSinghSachan/Attention_is_All_You_Need'},
#      'type': 'PushEvent'},
#     '_type': 'data'},
#    {'_id': '7148129065',
#     '_index': 'github',
#     '_score': 0.9999998,
#     '_source': {'actor': {'id': 13977613},
#      'created_at': '2018-01-25T04:55:47Z',
#      'id': '7148129065',
# ...

# %%
xres3=requests.get(database + '/_search?',headers=headers, data=json.dumps(
{
  "query": {
    "function_score": {
      "query": {
        "match_all": {}
      },
      "functions": [
        {
          "random_score": {}
        }
      ]
    }
  }

    ,"size":5000
    ,"_source":["type","created_at","id","repo.id","repo.name","actor.id"]
}    

)).json()
#    "size": 0,

# %%
# len(xres3)
# len(xres3.items())
xres3['hits']['hits']
pd.DataFrame(xres3['hits']['hits']). ._source
# object.keys(xres).length
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-74-381d2230e4ce> in <module>()
#       2 # len(xres3.items())
#       3 xres3['hits']['hits']
# ----> 4 pd.DataFrame(xres3['hits']['hits'])._source()
#       5 # object.keys(xres).length
#
# TypeError: 'Series' object is not callable

# %%
import threading
import time
x = 0

def printit(xtxt_):
    try :
        xt = threading.Timer(2.0, printit, [xtxt_])
        
        while True:
            global x
            print("%s - %d " % (xtxt_ , x))
            x = x + 1
            time.sleep(2.000)
            xt.daemon = True
            xt.start()
    except KeyboardInterrupt:
#         logger = init_logger("exit_after_decorator")
#         logger.info("Timeout reached!")
        print("Timeout reached!")
        xt.cancel()
    finally:
        xt.cancel()
#         t.start()

xtxt = "Hello world"
printit(xtxt)
# t = threading.Timer(2.0, printit, [xtxt + str(x)])
# t.daemon = True
# t.start()

# printit()
    
# curl -XPOST  http://revirevy.pythonanywhere.com/ -d
# Out:
# Hello world - 0
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-1-3245f4c54ad9> in printit(xtxt_)
#      13             xt = threading.Timer(2.0, printit, [xtxt_])
# ---> 14             xt.wait(1.0)
#      15             xt.daemon = True
#
# AttributeError: 'Timer' object has no attribute 'wait'
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-3245f4c54ad9> in <module>()
#      25
#      26 xtxt = "Hello world"
# ---> 27 printit(xtxt)
#      28 # t = threading.Timer(2.0, printit, [xtxt + str(x)])
#      29 # t.daemon = True
#
# <ipython-input-1-3245f4c54ad9> in printit(xtxt_)
#      21         timer.cancel()
#      22     finally:
# ---> 23         timer.cancel()
#      24 #         t.start()
#      25
#
# ...

# %%
dir(threading.Timer)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_bootstrap',
#  '_bootstrap_inner',
#  '_delete',
#  '_exc_info',
#  '_initialized',
#  '_reset_internal_locks',
#  '_set_ident',
#  '_set_tstate_lock',
#  '_stop',
#  '_wait_for_tstate_lock',
#  'cancel',
#  'daemon',
#  'getName',
#  'ident',
#  'isAlive',
#  'isDaemon',
#  'is_alive',
#  'join',
#  'name',
#  'run',
#  'setDaemon',
#  'setName',
#  'start']

# %%
import threading
import time
x = 0

def postit(xtxt_):
#     global x
    curl -XPOST  http://revirevy.pythonanywhere.com/ -d xtxt_

#         t.start()

xtxt = "Hello world"

# t.daemon = True


while True:
#     print("%s - %d " % (xtxt_, x))
    postit("This is data to post %d" % x)
    t = threading.Timer(1.0, printit, [xtxt])
    t.start()
    x = x + 1
    time.sleep(3.0)

# printit()
    
# curl -XPOST  http://revirevy.pythonanywhere.com/ -d

# %%
def hello():
#     print ("hello")
    global t 
    global x
    print("%s : %d " % ("Data n° " , x))
    x = x + 1
    t = threading.Timer(3.0, hello)
    t.start()

t = threading.Timer(3.0, hello)
t.start()
# Out:
# Data n°  - 1
# Data n°  - 2
# Data n°  - 3
# Data n°  - 4
# Data n°  - 5
# Data n°  - 6

# %%
t.cancel()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-38d5df9d848a> in <module>()
# ----> 1 t.cancel()
#
# NameError: name 't' is not defined
# xpost realisé avec : test envoi de commit du 2018-03-10 23:49:52.284652
#
# xpost realisé avec : test envoi de commit du 2018-03-10 23:50:02.309588
#
# xpost realisé avec : test envoi de commit du 2018-03-10 23:50:09.131763

# %%
import requests
import threading
import json
import random
# from datetime import date
import datetime

headers = {'Content-Type':'Application/json'}
database = 'http://192.168.39.23:9200/github'
# target = 'http://revirevy.pythonanywhere.com/xpost'
target = 'http://revirevy.pythonanywhere.com/xpost'
t = threading.Timer

def xtimer():
    global t
    print(sendPost())
    t = threading.Timer(3.0, xtimer)
    t.start()

def sendPost()  :
    global target
#     xdate = date.today()
#     xdate = date.today().strftime("%Y-%m-%d %H:%M:%S.%f")
    xdate = datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")
    xindex = random.randrange( 3709939278.0, 7183297066.0,1) #(5,60,5)

    xres = requests.post(target,headers=headers, data=
                         """test envoi de commit du %d
                         Envoi ce %s
                         """ % (xindex, xdate) )

    return xres.text
    # requests.dele.te(database).json()
    # requests.get(database ).json()


xtimer()
# Out:
# xpost realisé avec : test envoi de commit du 5179311140
#                          Envoi ce 2018-03-11 18:47:36.436285
#
#
# xpost realisé avec : test envoi de commit du 5198052259
#                          Envoi ce 2018-03-11 18:47:40.612755
#
#
# xpost realisé avec : test envoi de commit du 4707458392
#                          Envoi ce 2018-03-11 18:47:44.421182
#
#
# xpost realisé avec : test envoi de commit du 3929603268
#                          Envoi ce 2018-03-11 18:47:48.683533

# %%
global t
t.cancel()
