# %%
import json
import requests
headers = {'Content-Type':'Application/json'}
root = 'http://192.168.39.23:9200'
database = root + '/github'

# %%
requests.get(database + '/_search?',headers=headers, data=json.dumps({
 "size": 0,
    "aggs": {
        "nb_type": {
            "terms": {
                "field" : "type"
            }
        }
    }
})).json()
#    "size": 0,
# Out:
# {'_shards': {'failed': 0, 'skipped': 0, 'successful': 5, 'total': 5},
#  'aggregations': {'nb_type': {'buckets': [{'doc_count': 23201518,
#      'key': 'PushEvent'},
#     {'doc_count': 5942205, 'key': 'CreateEvent'},
#     {'doc_count': 3885239, 'key': 'WatchEvent'},
#     {'doc_count': 3776087, 'key': 'IssueCommentEvent'},
#     {'doc_count': 1889824, 'key': 'IssuesEvent'},
#     {'doc_count': 1333843, 'key': 'ForkEvent'},
#     {'doc_count': 999013, 'key': 'DeleteEvent'},
#     {'doc_count': 340352, 'key': 'GollumEvent'},
#     {'doc_count': 264230, 'key': 'MemberEvent'},
#     {'doc_count': 153761, 'key': 'ReleaseEvent'}],
#    'doc_count_error_upper_bound': 0,
#    'sum_other_doc_count': 171320}},
#  'hits': {'hits': [], 'max_score': 0.0, 'total': 41957395},
#  'timed_out': False,
#  'took': 3969}

# %%
requests.get(root + '/_nodes/stats' ).json()
# Out:
# {'_nodes': {'failed': 0, 'successful': 1, 'total': 1},
#  'cluster_name': 'docker-cluster',
#  'nodes': {'olQOvhaUT--GxXOQEi4oWQ': {'adaptive_selection': {'olQOvhaUT--GxXOQEi4oWQ': {'avg_queue_size': 10,
#      'avg_response_time_ns': 14732914,
#      'avg_service_time_ns': 6631236,
#      'outgoing_searches': 0,
#      'rank': '215.3'}},
#    'attributes': {'ml.enabled': 'true',
#     'ml.machine_memory': '5242880000',
#     'ml.max_open_jobs': '20'},
#    'breakers': {'accounting': {'estimated_size': '146.5mb',
#      'estimated_size_in_bytes': 153673497,
#      'limit_size': '4.9gb',
#      'limit_size_in_bytes': 5342560256,
#      'overhead': 1.0,
#      'tripped': 0},
#     'fielddata': {'estimated_size': '7.9kb',
#      'estimated_size_in_bytes': 8152,
#      'limit_size': '2.9gb',
#      'limit_size_in_bytes': 3205536153,
#      'overhead': 1.03,
#      'tripped': 0},
#     'in_flight_requests': {'estimated_size': '53.8mb',
#      'estimated_size_in_bytes': 56478280,
#      'limit_size': '4.9gb',
#      'limit_size_in_bytes': 5342560256,
#      'overhead': 1.0,
#      'tripped': 0},
#     'parent': {'estimated_size': '200.4mb',
#      'estimated_size_in_bytes': 210159929,
#      'limit_size': '3.4gb',
#      'limit_size_in_bytes': 3739792179,
#      'overhead': 1.0,
#      'tripped': 0},
#     'request': {'estimated_size': '0b',
#      'estimated_size_in_bytes': 0,
#      'limit_size': '2.9gb',
#      'limit_size_in_bytes': 3205536153,
#      'overhead': 1.0,
#      'tripped': 0}},
#    'discovery': {'cluster_state_queue': {'committed': 0,
#      'pending': 0,
#      'total': 0},
#     'published_cluster_states': {'compatible_diffs': 0,
#      'full_states': 0,
#      'incompatible_diffs': 0}},
#    'fs': {'data': [{'available_in_bytes': 54218764288,
#       'free_in_bytes': 63735541760,
#       'mount': '/ (none)',
#       'path': '/usr/share/elasticsearch/data/nodes/0',
#       'total_in_bytes': 186883813376,
#       'type': 'aufs'}],
#     'io_stats': {},
#     'least_usage_estimate': {'available_in_bytes': 54221017088,
#      'path': '/usr/share/elasticsearch/data/nodes/0',
#      'total_in_bytes': 186883813376,
#      'used_disk_percent': 70.98677723420045},
#     'most_usage_estimate': {'available_in_bytes': 54221017088,
#      'path': '/usr/share/elasticsearch/data/nodes/0',
#      'total_in_bytes': 186883813376,
#      'used_disk_percent': 70.98677723420045},
#     'timestamp': 1520503309656,
#     'total': {'available_in_bytes': 54218764288,
#      'free_in_bytes': 63735541760,
#      'total_in_bytes': 186883813376}},
#    'host': '172.18.0.3',
#    'http': {'current_open': 22, 'total_opened': 336},
#    'indices': {'completion': {'size_in_bytes': 0},
#     'docs': {'count': 29670071, 'deleted': 90},
#     'fielddata': {'evictions': 0, 'memory_size_in_bytes': 8152},
#     'flush': {'total': 11, 'total_time_in_millis': 194228},
#     'get': {'current': 0,
#      'exists_time_in_millis': 27253,
#      'exists_total': 210,
#      'missing_time_in_millis': 0,
#      'missing_total': 0,
#      'time_in_millis': 27253,
#      'total': 210},
#     'indexing': {'delete_current': 0,
#      'delete_time_in_millis': 0,
#      'delete_total': 0,
#      'index_current': 0,
#      'index_failed': 0,
#      'index_time_in_millis': 924842,
#      'index_total': 850308,
#      'is_throttled': False,
#      'noop_update_total': 0,
#      'throttle_time_in_millis': 0},
#     'merges': {'current': 3,
#      'current_docs': 2365333,
#      'current_size_in_bytes': 5178647892,
#      'total': 79,
#      'total_auto_throttle_in_bytes': 230513401,
#      'total_docs': 1195260,
#      'total_size_in_bytes': 1019221778,
#      'total_stopped_time_in_millis': 0,
#      'total_throttled_time_in_millis': 28528,
#      'total_time_in_millis': 656483},
#     'query_cache': {'cache_count': 0,
#      'cache_size': 0,
#      'evictions': 0,
#      'hit_count': 0,
#      'memory_size_in_bytes': 0,
#      'miss_count': 0,
#      'total_count': 0},
#     'recovery': {'current_as_source': 0,
#      'current_as_target': 0,
#      'throttle_time_in_millis': 0},
#     'refresh': {'listeners': 0, 'total': 917, 'total_time_in_millis': 571740},
#     'request_cache': {'evictions': 0,
#      'hit_count': 1887,
#      'memory_size_in_bytes': 497066,
#      'miss_count': 2972},
#     'search': {'fetch_current': 0,
#      'fetch_time_in_millis': 1711,
#      'fetch_total': 380,
#      'open_contexts': 0,
#      'query_current': 0,
#      'query_time_in_millis': 418769,
#      'query_total': 5995,
#      'scroll_current': 0,
#      'scroll_time_in_millis': 0,
#      'scroll_total': 0,
#      'suggest_current': 0,
#      'suggest_time_in_millis': 0,
#      'suggest_total': 0},
#     'segments': {'count': 107,
#      'doc_values_memory_in_bytes': 2660660,
#      'file_sizes': {},
#      'fixed_bit_set_memory_in_bytes': 0,
#      'index_writer_memory_in_bytes': 234374384,
#      'max_unsafe_auto_id_timestamp': 1520501055286,
#      'memory_in_bytes': 153673497,
#      'norms_memory_in_bytes': 82432,
#      'points_memory_in_bytes': 1786016,
#      'stored_fields_memory_in_bytes': 13391664,
#      'term_vectors_memory_in_bytes': 0,
#      'terms_memory_in_bytes': 135752725,
#      'version_map_memory_in_bytes': 4408514},
#     'store': {'size_in_bytes': 60006813055},
#     'translog': {'operations': 401417,
#      'size_in_bytes': 1046420595,
#      'uncommitted_operations': 142981,
#      'uncommitted_size_in_bytes': 438808953},
#     'warmer': {'current': 0, 'total': 860, 'total_time_in_millis': 142}},
#    'ingest': {'pipelines': {'xpack_monitoring_2': {'count': 0,
#       'current': 0,
#       'failed': 0,
#       'time_in_millis': 0},
#      'xpack_monitoring_6': {'count': 0,
#       'current': 0,
#       'failed': 0,
#       'time_in_millis': 0}},
#     'total': {'count': 0, 'current': 0, 'failed': 0, 'time_in_millis': 0}},
#    'ip': '172.18.0.3:9300',
#    'jvm': {'buffer_pools': {'direct': {'count': 41,
#       'total_capacity_in_bytes': 101474497,
#       'used_in_bytes': 101474498},
#      'mapped': {'count': 205,
#       'total_capacity_in_bytes': 56817556860,
#       'used_in_bytes': 56817556860}},
#     'classes': {'current_loaded_count': 15361,
#      'total_loaded_count': 15452,
#      'total_unloaded_count': 91},
#     'gc': {'collectors': {'old': {'collection_count': 7,
#        'collection_time_in_millis': 919},
#       'young': {'collection_count': 815,
#        'collection_time_in_millis': 378474}}},
#     'mem': {'heap_committed_in_bytes': 5342560256,
#      'heap_max_in_bytes': 5342560256,
#      'heap_used_in_bytes': 1495521696,
#      'heap_used_percent': 27,
#      'non_heap_committed_in_bytes': 151592960,
#      'non_heap_used_in_bytes': 141978000,
#      'pools': {'old': {'max_in_bytes': 5107023872,
#        'peak_max_in_bytes': 5107023872,
#        'peak_used_in_bytes': 3880163056,
#        'used_in_bytes': 1463664664},
#       'survivor': {'max_in_bytes': 26148864,
#        'peak_max_in_bytes': 26148864,
#        'peak_used_in_bytes': 26148864,
#        'used_in_bytes': 12052272},
#       'young': {'max_in_bytes': 209387520,
#        'peak_max_in_bytes': 209387520,
#        'peak_used_in_bytes': 209387520,
#        'used_in_bytes': 19804760}}},
#     'threads': {'count': 61, 'peak_count': 67},
#     'timestamp': 1520503309656,
#     'uptime_in_millis': 2426983},
#    'name': 'olQOvha',
#    'os': {'cgroup': {'cpu': {'cfs_period_micros': 100000,
#       'cfs_quota_micros': -1,
#       'control_group': '/',
#       'stat': {'number_of_elapsed_periods': 0,
#        'number_of_times_throttled': 0,
#        'time_throttled_nanos': 0}},
#      'cpuacct': {'control_group': '/', 'usage_nanos': 1463274747914},
#      'memory': {'control_group': '/',
#       'limit_in_bytes': '5242880000',
#       'usage_in_bytes': '5242847232'}},
#     'cpu': {'load_average': {'15m': 3.19, '1m': 3.22, '5m': 3.49},
#      'percent': 21},
#     'mem': {'free_in_bytes': 285339648,
#      'free_percent': 3,
#      'total_in_bytes': 8270290944,
#      'used_in_bytes': 7984951296,
#      'used_percent': 97},
#     'swap': {'free_in_bytes': 7642017792,
#      'total_in_bytes': 8910794752,
#      'used_in_bytes': 1268776960},
#     'timestamp': 1520503309655},
#    'process': {'cpu': {'percent': 11, 'total_in_millis': 1460410},
#     'max_file_descriptors': 1048576,
#     'mem': {'total_virtual_in_bytes': 66132910080},
#     'open_file_descriptors': 322,
#     'timestamp': 1520503309655},
#    'roles': ['master', 'data', 'ingest'],
#    'script': {'cache_evictions': 0, 'compilations': 3},
#    'thread_pool': {'bulk': {'active': 0,
#      'completed': 1159,
#      'largest': 3,
#      'queue': 0,
#      'rejected': 0,
#      'threads': 3},
#     'fetch_shard_started': {'active': 0,
#      'completed': 11,
#      'largest': 6,
#      'queue': 0,
#      'rejected': 0,
#      'threads': 1},
#     'fetch_shard_store': {'active': 0,
#      'completed': 0,
#      'largest': 0,
#      'queue': 0,
#      'rejected': 0,
#      'threads': 0},
#     'flush': {'active': 0,
#      'completed': 39,
#      'largest': 2,
#      'queue': 0,
#      'rejected': 0,
#      'threads': 2},
#     'force_merge': {'active': 0,
#      'completed': 0,
#      'largest': 0,
#      'queue': 0,
#      'rejected': 0,
#      'threads': 0},
#     'generic': {'active': 0,
#      'completed': 3184,
#      'largest': 9,
#      'queue': 0,
#      'rejected': 0,
#      'threads': 9},
#     'get': {'active': 0,
#      'completed': 210,
#      'largest': 3,
#      'queue': 0,
#      'rejected': 0,
#      'threads': 3},
#     'index': {'active': 0,
#      'completed': 0,
#      'largest': 0,
#      'queue': 0,
#      'rejected': 0,
#      'threads': 0},
#     'listener': {'active': 0,
#      'completed': 0,
#      'largest': 0,
#      'queue': 0,
#      'rejected': 0,
#      'threads': 0},
#     'management': {'active': 1,
#      'completed': 3230,
#      'largest': 4,
#      'queue': 0,
#      'rejected': 0,
#      'threads': 4},
#     'ml_autodetect': {'active': 0,
#      'completed': 0,
#      'largest': 0,
#      'queue': 0,
#      'rejected': 0,
#      'threads': 0},
#     'ml_datafeed': {'active': 0,
#      'completed': 0,
#      'largest': 0,
#      'queue': 0,
#      'rejected': 0,
#      'threads': 0},
#     'ml_utility': {'active': 0,
#      'completed': 0,
#      'largest': 0,
#      'queue': 0,
#      'rejected': 0,
#      'threads': 0},
#     'refresh': {'active': 0,
#      'completed': 11478,
#      'largest': 2,
#      'queue': 0,
#      'rejected': 0,
#      'threads': 2},
#     'search': {'active': 0,
#      'completed': 8445,
#      'largest': 5,
#      'queue': 0,
#      'rejected': 0,
#      'threads': 5},
#     'security-token-key': {'active': 0,
#      'completed': 0,
#      'largest': 0,
#      'queue': 0,
#      'rejected': 0,
#      'threads': 0},
#     'snapshot': {'active': 0,
#      'completed': 0,
#      'largest': 0,
#      'queue': 0,
#      'rejected': 0,
#      'threads': 0},
#     'warmer': {'active': 0,
#      'completed': 0,
#      'largest': 0,
#      'queue': 0,
#      'rejected': 0,
#      'threads': 0},
#     'watcher': {'active': 0,
#      'completed': 0,
#      'largest': 0,
#      'queue': 0,
#      'rejected': 0,
#      'threads': 0}},
#    'timestamp': 1520503309615,
#    'transport': {'rx_count': 8,
#     'rx_size_in_bytes': 1016,
#     'server_open': 0,
#     'tx_count': 8,
#     'tx_size_in_bytes': 1016},
#    'transport_address': '172.18.0.3:9300'}}}

# %%
requests.put(root + '/_settings',headers=headers, data=json.dumps(

    {
    "index": {
    "blocks": {
    "read_only_allow_delete": "false"
    }
    }
    }
)).json()
# Out:
# {'acknowledged': True}

# %%
requests.get(root + '/_settings').json()
# Out:
# {'.kibana': {'settings': {'index': {'auto_expand_replicas': '0-1',
#     'blocks': {'read_only_allow_delete': 'false'},
#     'creation_date': '1520445122446',
#     'mapping': {'total_fields': {'limit': '2000'}},
#     'number_of_replicas': '0',
#     'number_of_shards': '2',
#     'provided_name': '.kibana',
#     'uuid': '-hcEdu4FQhGCzNMj0o-9Ig',
#     'version': {'created': '6020299'}}}},
#  '.monitoring-es-6-2018.03.07': {'settings': {'index': {'auto_expand_replicas': '0-1',
#     'blocks': {'read_only_allow_delete': 'false'},
#     'codec': 'best_compression',
#     'creation_date': '1520423666808',
#     'format': '6',
#     'mapping': {'total_fields': {'limit': '2000'}},
#     'number_of_replicas': '0',
#     'number_of_shards': '1',
#     'provided_name': '.monitoring-es-6-2018.03.07',
#     'uuid': 'vXBd_5zrQLuXLpcoLurreA',
#     'version': {'created': '6020299'}}}},
#  '.monitoring-es-6-2018.03.08': {'settings': {'index': {'auto_expand_replicas': '0-1',
#     'blocks': {'read_only_allow_delete': 'false'},
#     'codec': 'best_compression',
#     'creation_date': '1520467211034',
#     'format': '6',
#     'mapping': {'total_fields': {'limit': '2000'}},
#     'number_of_replicas': '0',
#     'number_of_shards': '2',
#     'provided_name': '.monitoring-es-6-2018.03.08',
#     'uuid': '7kqrF8WIQruUZ01F-pklFw',
#     'version': {'created': '6020299'}}}},
#  '.monitoring-kibana-6-2018.03.07': {'settings': {'index': {'auto_expand_replicas': '0-1',
#     'blocks': {'read_only_allow_delete': 'false'},
#     'codec': 'best_compression',
#     'creation_date': '1520444321978',
#     'format': '6',
#     'mapping': {'total_fields': {'limit': '2000'}},
#     'number_of_replicas': '0',
#     'number_of_shards': '1',
#     'provided_name': '.monitoring-kibana-6-2018.03.07',
#     'uuid': 'JzwpGzAVTt6qqY-mZFTrgw',
#     'version': {'created': '6020299'}}}},
#  '.monitoring-kibana-6-2018.03.08': {'settings': {'index': {'auto_expand_replicas': '0-1',
#     'blocks': {'read_only_allow_delete': 'false'},
#     'codec': 'best_compression',
#     'creation_date': '1520467205942',
#     'format': '6',
#     'mapping': {'total_fields': {'limit': '2000'}},
#     'number_of_replicas': '0',
#     'number_of_shards': '2',
#     'provided_name': '.monitoring-kibana-6-2018.03.08',
#     'uuid': '2yXHfAOiRM2kJIi17mp4RA',
#     'version': {'created': '6020299'}}}},
#  'github': {'settings': {'index': {'blocks': {'read_only_allow_delete': 'false'},
#     'creation_date': '1520423714605',
#     'mapping': {'total_fields': {'limit': '2000'}},
#     'number_of_replicas': '0',
#     'number_of_shards': '1',
#     'provided_name': 'github',
#     'refresh_interval': '60s',
#     'uuid': 'H_o9bNZkT7OnDJUxgaD9sg',
#     'version': {'created': '6020299'}}}},
#  'test': {'settings': {'index': {'blocks': {'read_only_allow_delete': 'false'},
#     'creation_date': '1520443462171',
#     'mapping': {'total_fields': {'limit': '2000'}},
#     'number_of_replicas': '0',
#     'number_of_shards': '2',
#     'provided_name': 'test',
#     'uuid': '37YMGGI2StCtc6kZyvsCzg',
#     'version': {'created': '6020299'}}}}}
