# %%
import json
import requests
headers = {'Content-Type':'Application/json'}
root = 'http://192.168.39.23:9200'
# database = root + '/github'
database = root + '/github'
# requests.delete(database).json()
# requests.get(database ).json()

# %%
requests.get(root + '/_settings').json()
# Out:
# {'.kibana': {'settings': {'index': {'auto_expand_replicas': '0-1',
#     'blocks': {'read_only_allow_delete': 'false'},
#     'creation_date': '1520445122446',
#     'mapping': {'total_fields': {'limit': '2000'}},
#     'number_of_replicas': '0',
#     'number_of_shards': '2',
#     'provided_name': '.kibana',
#     'uuid': '-hcEdu4FQhGCzNMj0o-9Ig',
#     'version': {'created': '6020299'}}}},
#  '.monitoring-es-6-2018.03.07': {'settings': {'index': {'auto_expand_replicas': '0-1',
#     'blocks': {'read_only_allow_delete': 'false'},
#     'codec': 'best_compression',
#     'creation_date': '1520423666808',
#     'format': '6',
#     'mapping': {'total_fields': {'limit': '2000'}},
#     'number_of_replicas': '0',
#     'number_of_shards': '1',
#     'provided_name': '.monitoring-es-6-2018.03.07',
#     'uuid': 'vXBd_5zrQLuXLpcoLurreA',
#     'version': {'created': '6020299'}}}},
#  '.monitoring-es-6-2018.03.08': {'settings': {'index': {'auto_expand_replicas': '0-1',
#     'blocks': {'read_only_allow_delete': 'false'},
#     'codec': 'best_compression',
#     'creation_date': '1520467211034',
#     'format': '6',
#     'mapping': {'total_fields': {'limit': '2000'}},
#     'number_of_replicas': '0',
#     'number_of_shards': '2',
#     'provided_name': '.monitoring-es-6-2018.03.08',
#     'uuid': '7kqrF8WIQruUZ01F-pklFw',
#     'version': {'created': '6020299'}}}},
#  '.monitoring-es-6-2018.03.09': {'settings': {'index': {'auto_expand_replicas': '0-1',
#     'codec': 'best_compression',
#     'creation_date': '1520553606930',
#     'format': '6',
#     'mapping': {'total_fields': {'limit': '2000'}},
#     'number_of_replicas': '0',
#     'number_of_shards': '2',
#     'provided_name': '.monitoring-es-6-2018.03.09',
#     'uuid': 'wkOw9uzTSSusQMjwc-VH4w',
#     'version': {'created': '6020299'}}}},
#  '.monitoring-es-6-2018.03.10': {'settings': {'index': {'auto_expand_replicas': '0-1',
#     'codec': 'best_compression',
#     'creation_date': '1520640009171',
#     'format': '6',
#     'mapping': {'total_fields': {'limit': '2000'}},
#     'number_of_replicas': '0',
#     'number_of_shards': '2',
#     'provided_name': '.monitoring-es-6-2018.03.10',
#     'uuid': 'QQ9Fh-bnRMm7NtcDCHlMAg',
#     'version': {'created': '6020299'}}}},
#  '.monitoring-es-6-2018.03.11': {'settings': {'index': {'auto_expand_replicas': '0-1',
#     'codec': 'best_compression',
#     'creation_date': '1520726409460',
#     'format': '6',
#     'mapping': {'total_fields': {'limit': '2000'}},
#     'number_of_replicas': '0',
#     'number_of_shards': '2',
#     'provided_name': '.monitoring-es-6-2018.03.11',
#     'uuid': 'QnRFWICcSoiNFiWLS2T2bA',
#     'version': {'created': '6020299'}}}},
#  '.monitoring-kibana-6-2018.03.07': {'settings': {'index': {'auto_expand_replicas': '0-1',
#     'blocks': {'read_only_allow_delete': 'false'},
#     'codec': 'best_compression',
#     'creation_date': '1520444321978',
#     'format': '6',
#     'mapping': {'total_fields': {'limit': '2000'}},
#     'number_of_replicas': '0',
#     'number_of_shards': '1',
#     'provided_name': '.monitoring-kibana-6-2018.03.07',
#     'uuid': 'JzwpGzAVTt6qqY-mZFTrgw',
#     'version': {'created': '6020299'}}}},
#  '.monitoring-kibana-6-2018.03.08': {'settings': {'index': {'auto_expand_replicas': '0-1',
#     'blocks': {'read_only_allow_delete': 'false'},
#     'codec': 'best_compression',
#     'creation_date': '1520467205942',
#     'format': '6',
#     'mapping': {'total_fields': {'limit': '2000'}},
#     'number_of_replicas': '0',
#     'number_of_shards': '2',
#     'provided_name': '.monitoring-kibana-6-2018.03.08',
#     'uuid': '2yXHfAOiRM2kJIi17mp4RA',
#     'version': {'created': '6020299'}}}},
#  '.monitoring-kibana-6-2018.03.09': {'settings': {'index': {'auto_expand_replicas': '0-1',
#     'codec': 'best_compression',
#     'creation_date': '1520553608011',
#     'format': '6',
#     'mapping': {'total_fields': {'limit': '2000'}},
#     'number_of_replicas': '0',
#     'number_of_shards': '2',
#     'provided_name': '.monitoring-kibana-6-2018.03.09',
#     'uuid': 'bc5ATsdZQtazo_BKWfZvpA',
#     'version': {'created': '6020299'}}}},
#  '.monitoring-kibana-6-2018.03.10': {'settings': {'index': {'auto_expand_replicas': '0-1',
#     'codec': 'best_compression',
#     'creation_date': '1520640001024',
#     'format': '6',
#     'mapping': {'total_fields': {'limit': '2000'}},
#     'number_of_replicas': '0',
#     'number_of_shards': '2',
#     'provided_name': '.monitoring-kibana-6-2018.03.10',
#     'uuid': 'W_Vi9ydFQrKswygFNVPiUw',
#     'version': {'created': '6020299'}}}},
#  '.monitoring-kibana-6-2018.03.11': {'settings': {'index': {'auto_expand_replicas': '0-1',
#     'codec': 'best_compression',
#     'creation_date': '1520784965313',
#     'format': '6',
#     'mapping': {'total_fields': {'limit': '2000'}},
#     'number_of_replicas': '0',
#     'number_of_shards': '1',
#     'provided_name': '.monitoring-kibana-6-2018.03.11',
#     'uuid': '4WrPQKO6SOCdC6KK65TVjg',
#     'version': {'created': '6020299'}}}},
#  'github': {'settings': {'index': {'blocks': {'read_only_allow_delete': 'false'},
#     'creation_date': '1520423714605',
#     'mapping': {'total_fields': {'limit': '2000'}},
#     'number_of_replicas': '0',
#     'number_of_shards': '1',
#     'provided_name': 'github',
#     'refresh_interval': '60s',
#     'uuid': 'H_o9bNZkT7OnDJUxgaD9sg',
#     'version': {'created': '6020299'}}}},
#  'test': {'settings': {'index': {'blocks': {'read_only_allow_delete': 'false'},
#     'creation_date': '1520443462171',
#     'mapping': {'total_fields': {'limit': '2000'}},
#     'number_of_replicas': '0',
#     'number_of_shards': '2',
#     'provided_name': 'test',
#     'uuid': '37YMGGI2StCtc6kZyvsCzg',
#     'version': {'created': '6020299'}}}}}

# %%
print(requests.get(root + '/_cat/indices').text)
# Out:
# green open .monitoring-es-6-2018.03.07     vXBd_5zrQLuXLpcoLurreA 1 0    28033  28  12.7mb  12.7mb
# green open .monitoring-es-6-2018.03.09     wkOw9uzTSSusQMjwc-VH4w 2 0   112509 135  52.9mb  52.9mb
# green open github                          H_o9bNZkT7OnDJUxgaD9sg 1 0 48898124   0  88.7gb  88.7gb
# green open .monitoring-kibana-6-2018.03.09 bc5ATsdZQtazo_BKWfZvpA 2 0     8636   0   2.1mb   2.1mb
# green open .monitoring-kibana-6-2018.03.11 4WrPQKO6SOCdC6KK65TVjg 1 0      167   0 105.8kb 105.8kb
# green open test                            37YMGGI2StCtc6kZyvsCzg 2 0        2   0  69.3kb  69.3kb
# green open .monitoring-kibana-6-2018.03.08 2yXHfAOiRM2kJIi17mp4RA 2 0     6583   0   1.6mb   1.6mb
# green open .kibana                         -hcEdu4FQhGCzNMj0o-9Ig 2 0        2   0  38.3kb  38.3kb
# green open .monitoring-kibana-6-2018.03.07 JzwpGzAVTt6qqY-mZFTrgw 1 0     2222   0 697.9kb 697.9kb
# green open .monitoring-es-6-2018.03.08     7kqrF8WIQruUZ01F-pklFw 2 0    69200  60  34.4mb  34.4mb
# green open .monitoring-es-6-2018.03.10     QQ9Fh-bnRMm7NtcDCHlMAg 2 0   127930 127  61.9mb  61.9mb
# green open .monitoring-kibana-6-2018.03.10 W_Vi9ydFQrKswygFNVPiUw 2 0     7657   0   1.9mb   1.9mb
# green open .monitoring-es-6-2018.03.11     QnRFWICcSoiNFiWLS2T2bA 2 0    96562 171  39.8mb  39.8mb

# %%
# !pip install py2neo
# Out:
# Requirement already satisfied: py2neo in /home/rhevi/anaconda3/lib/python3.6/site-packages

# %%
import py2neo

# %%
dir(py2neo)
# Out:
# ['BoltDataSource',
#  'BoltNode',
#  'BoltPath',
#  'BoltRelationship',
#  'BoltTransaction',
#  'ClientError',
#  'Commander',
#  'ConstraintError',
#  'Cursor',
#  'CypherSyntaxError',
#  'CypherTypeError',
#  'CypherWriter',
#  'DBMS',
#  'DataSource',
#  'DatabaseError',
#  'Entity',
#  'Forbidden',
#  'Graph',
#  'GraphDatabase',
#  'GraphError',
#  'HTTPDataSource',
#  'HTTPResponse',
#  'HTTPTransaction',
#  'JAVA_INTEGER_MAX_VALUE',
#  'JAVA_INTEGER_MIN_VALUE',
#  'JSONResponse',
#  'Mapping',
#  'NOT_FOUND',
#  'Node',
#  'NodeSelection',
#  'NodeSelector',
#  'OrderedDict',
#  'PRODUCT',
#  'PULL_ALL',
#  'Path',
#  'PropertyDict',
#  'RUN',
#  'Record',
#  'Relatable',
#  'Relationship',
#  'RemoteEntity',
#  'ReprIO',
#  'Resource',
#  'ResourceTemplate',
#  'Response',
#  'Schema',
#  'ServerAddress',
#  'ServerAuth',
#  'ServerError',
#  'ServerPlugin',
#  'SetView',
#  'StringIO',
#  'Subgraph',
#  'ThreadLocalEntityCache',
#  'Transaction',
#  'TransactionFinished',
#  'TransientError',
#  'UNAUTHORIZED',
#  'URI',
#  'Unauthorized',
#  'UnmanagedExtension',
#  'Walkable',
#  'Watcher',
#  '__author__',
#  '__builtins__',
#  '__cached__',
#  '__copyright__',
#  '__doc__',
#  '__email__',
#  '__file__',
#  '__license__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  'auth',
#  'authenticate',
#  'b64encode',
#  'basic_auth',
#  'bolt_hydrate',
#  'caching',
#  'cast',
#  'cast_node',
#  'cast_relationship',
#  'chain',
#  'client_errors',
#  'coerce_atomic_property',
#  'coerce_property',
#  'compat',
#  'cypher',
#  'cypher_escape',
#  'cypher_repr',
#  'cypher_request',
#  'database',
#  'deprecated',
#  'deque',
#  'ext',
#  'get_auth',
#  'get_http_headers',
#  'getenv',
#  'http',
#  'integer',
#  'is_collection',
#  'json_dumps',
#  'keyring',
#  'main',
#  'mktime_tz',
#  'normalise_request',
#  'order',
#  'packages',
#  'parsedate_tz',
#  'raise_from',
#  'register_server',
#  'relationship_case',
#  'remote',
#  'round_robin',
#  'selection',
#  'set_http_header',
#  'size',
#  'snake_case',
#  'status',
#  'stdout',
#  'string',
#  'types',
#  'unicode',
#  'update_stats_keys',
#  'user_agent',
#  'ustr',
#  'util',
#  'uuid4',
#  'version_tuple',
#  'walk',
#  'warn',
#  'watch',
#  'webbrowser',
#  'xstr']
