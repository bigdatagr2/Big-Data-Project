# %%
import json
import requests
import pandas as pd
headers = {'Content-Type':'Application/json'}
root = 'http://88.169.46.187:9200'
database = root + '/github'

# %%
requests.get(database + '/_search?',headers=headers, data=json.dumps(
{
 "query": {
                    "bool": {
                        #"minimum_should_match": "75%",
                        "must": {
                            "multi_match" : {
                                "query": "linux", 
                                "fields": [
                                    "payload.commits.message"
                                ],
                                "type": "phrase_prefix",
                                "analyzer":"standard"
                            }
                        }                       
                    }
                }
    ,"size":10    
    ,"_source":["type","created_at","id","repo.id","repo.name","actor.id","payload"]
} 
)
            ).json()
# Out:
# {'_shards': {'failed': 0, 'skipped': 0, 'successful': 1, 'total': 1},
#  'hits': {'hits': [{'_id': '7061971523',
#     '_index': 'github',
#     '_score': 41.493835,
#     '_source': {'actor': {'id': 1056976},
#      'created_at': '2018-01-05T15:31:21Z',
#      'id': '7061971523',
#      'payload': {'before': '060c0198a0ef0dca2c54c3884c545ea36a5f1fef',
#       'commits': [{'author': {'email': '00f63b104cc192f7f01eceab27b343d9965c9f26@voidlinux.eu',
#          'name': 'Enno Boland'},
#         'distinct': True,
#         'message': 'linux4.14: update to 4.14.12.',
#         'sha': 'd546cdbd9fe05b4faf6a6e5e1cc28ae6db334016',
#         'url': 'https://api.github.com/repos/voidlinux/void-packages/commits/d546cdbd9fe05b4faf6a6e5e1cc28ae6db334016'},
#        {'author': {'email': '00f63b104cc192f7f01eceab27b343d9965c9f26@voidlinux.eu',
#          'name': 'Enno Boland'},
#         'distinct': True,
#         'message': 'linux4.9: update to 4.9.75.',
#         'sha': '58f946ae2c0a691dab0a001c6aeaf150c50bb96e',
#         'url': 'https://api.github.com/repos/voidlinux/void-packages/commits/58f946ae2c0a691dab0a001c6aeaf150c50bb96e'},
#        {'author': {'email': '00f63b104cc192f7f01eceab27b343d9965c9f26@voidlinux.eu',
#          'name': 'Enno Boland'},
#         'distinct': True,
#         'message': 'linux4.4: update to 4.4.110.',
#         'sha': '5b8d2de1bafc897ec5836db015082fc0b919a5d8',
#         'url': 'https://api.github.com/repos/voidlinux/void-packages/commits/5b8d2de1bafc897ec5836db015082fc0b919a5d8'}],
#       'distinct_size': 3,
#       'head': '5b8d2de1bafc897ec5836db015082fc0b919a5d8',
#       'push_id': 2234891553,
#       'ref': 'refs/heads/master',
#       'size': 3},
#      'repo': {'id': 2060910, 'name': 'voidlinux/void-packages'},
#      'type': 'PushEvent'},
#     '_type': 'data'},
#    {'_id': '7062216341',
#     '_index': 'github',
#     '_score': 37.12463,
#     '_source': {'actor': {'id': 465279},
#      'created_at': '2018-01-05T16:23:11Z',
#      'id': '7062216341',
#      'payload': {'before': '060c0198a0ef0dca2c54c3884c545ea36a5f1fef',
#       'commits': [{'author': {'email': '00f63b104cc192f7f01eceab27b343d9965c9f26@voidlinux.eu',
#          'name': 'Enno Boland'},
#         'distinct': True,
#         'message': 'linux4.14: update to 4.14.12.',
#         'sha': 'd546cdbd9fe05b4faf6a6e5e1cc28ae6db334016',
#         'url': 'https://api.github.com/repos/kraj/void-packages/commits/d546cdbd9fe05b4faf6a6e5e1cc28ae6db334016'},
#        {'author': {'email': '00f63b104cc192f7f01eceab27b343d9965c9f26@voidlinux.eu',
#          'name': 'Enno Boland'},
#         'distinct': True,
#         'message': 'linux4.9: update to 4.9.75.',
#         'sha': '58f946ae2c0a691dab0a001c6aeaf150c50bb96e',
#         'url': 'https://api.github.com/repos/kraj/void-packages/commits/58f946ae2c0a691dab0a001c6aeaf150c50bb96e'},
#        {'author': {'email': '00f63b104cc192f7f01eceab27b343d9965c9f26@voidlinux.eu',
#          'name': 'Enno Boland'},
#         'distinct': True,
#         'message': 'linux4.4: update to 4.4.110.',
#         'sha': '5b8d2de1bafc897ec5836db015082fc0b919a5d8',
#         'url': 'https://api.github.com/repos/kraj/void-packages/commits/5b8d2de1bafc897ec5836db015082fc0b919a5d8'},
#        {'author': {'email': '1d6e1cf70ec6f9ab28d3ea4b27a49a77654d370e@duncano.de',
#          'name': 'Duncaen'},
#         'distinct': True,
#         'message': 'inadyn: update to 2.3.',
#         'sha': '4f9fddb6f9bfe91090b27832330a69e2460753cd',
#         'url': 'https://api.github.com/repos/kraj/void-packages/commits/4f9fddb6f9bfe91090b27832330a69e2460753cd'}],
#       'distinct_size': 4,
#       'head': '4f9fddb6f9bfe91090b27832330a69e2460753cd',
#       'push_id': 2235014697,
#       'ref': 'refs/heads/master',
#       'size': 4},
#      'repo': {'id': 97267062, 'name': 'kraj/void-packages'},
#      'type': 'PushEvent'},
#     '_type': 'data'},
#    {'_id': '5148278291',
#     '_index': 'github',
#     '_score': 36.836594,
#     '_source': {'actor': {'id': 7137649},
#      'created_at': '2017-01-13T10:42:28Z',
#      'id': '5148278291',
#      'payload': {'before': 'b4f7c7d05aa6eceab676b817991d981f9323de10',
#       'commits': [{'author': {'email': '6e411ee7d0ab73d570579742c0485f5d4b49b2c2@gmail.com',
#          'name': 'Ahmet Gürel'},
#         'distinct': True,
#         'message': 'posts',
#         'sha': '083c132e97d0b7cf942c0f5a5ee89868cac82043',
#         'url': 'https://api.github.com/repos/ahmetgurel/ahmetgurel.github.io/commits/083c132e97d0b7cf942c0f5a5ee89868cac82043'},
#        {'author': {'email': '6e411ee7d0ab73d570579742c0485f5d4b49b2c2@gmail.com',
#          'name': 'Ahmet Gürel'},
#         'distinct': True,
#         'message': 'postss\n\n# Conflicts:\n#\t_posts/2016-10-28-Linux2.md\n#\t_posts/2016-10-28-Linux3.md\n#\t_posts/2016-10-28-Linux4.md',
#         'sha': '6084d3499341dc26eb8152b10db84227ccbdf185',
#         'url': 'https://api.github.com/repos/ahmetgurel/ahmetgurel.github.io/commits/6084d3499341dc26eb8152b10db84227ccbdf185'}],
#       'distinct_size': 2,
#       'head': '6084d3499341dc26eb8152b10db84227ccbdf185',
#       'push_id': 1499155047,
#       'ref': 'refs/heads/master',
#       'size': 2},
#      'repo': {'id': 72179746, 'name': 'ahmetgurel/ahmetgurel.github.io'},
#      'type': 'PushEvent'},
#     '_type': 'data'},
#    {'_id': '7081059047',
#     '_index': 'github',
#     '_score': 31.268139,
#     '_source': {'actor': {'id': 28957163},
#      'created_at': '2018-01-10T15:30:47Z',
#      'id': '7081059047',
#      'payload': {'before': '6738b395c26250cf0e654ae53795858403313982',
#       'commits': [{'author': {'email': '2bc9a21a85bf848cea1235e78a89481be6c9fa2a@lonw.net',
#          'name': 'Lon Willett'},
#         'distinct': True,
#         'message': 'linux4.14: update custom config',
#         'sha': '41a9e8dc0a6898d5d9ab45b7d140c078fd4c1eea',
#         'url': 'https://api.github.com/repos/lonwillett/void-packages/commits/41a9e8dc0a6898d5d9ab45b7d140c078fd4c1eea'},
#        {'author': {'email': '2bc9a21a85bf848cea1235e78a89481be6c9fa2a@lonw.net',
#          'name': 'Lon Willett'},
#         'distinct': True,
#         'message': 'linux4.14: update to 4.14.13',
#         'sha': 'ddc4c944149ed00c7cb8c71189bc62d5b9a0c622',
#         'url': 'https://api.github.com/repos/lonwillett/void-packages/commits/ddc4c944149ed00c7cb8c71189bc62d5b9a0c622'},
#        {'author': {'email': '2bc9a21a85bf848cea1235e78a89481be6c9fa2a@lonw.net',
#          'name': 'Lon Willett'},
#         'distinct': True,
#         'message': 'linux4.9: update to 4.9.76',
#         'sha': '67c4be706375f87544f8a668654f507bcc93f2af',
#         'url': 'https://api.github.com/repos/lonwillett/void-packages/commits/67c4be706375f87544f8a668654f507bcc93f2af'}],
#       'distinct_size': 3,
#       'head': '67c4be706375f87544f8a668654f507bcc93f2af',
#       'push_id': 2244847018,
#       'ref': 'refs/heads/sandbox',
#       'size': 3},
#      'repo': {'id': 92431021, 'name': 'lonwillett/void-packages'},
#      'type': 'PushEvent'},
#     '_type': 'data'},
#    {'_id': '7111339336',
#     '_index': 'github',
#     '_score': 30.4333,
#     '_source': {'actor': {'id': 28957163},
#      'created_at': '2018-01-17T13:56:41Z',
#      'id': '7111339336',
#      'payload': {'before': 'a5f45869cea481044866d7cac255295f900d3b57',
#       'commits': [{'author': {'email': '2bc9a21a85bf848cea1235e78a89481be6c9fa2a@lonw.net',
#          'name': 'Lon Willett'},
#         'distinct': True,
#         'message': 'linux4.9: update to 4.9.77',
#         'sha': '28ad8a4e491545a20dafdbf725d019b2cc9fe306',
#         'url': 'https://api.github.com/repos/lonwillett/void-packages/commits/28ad8a4e491545a20dafdbf725d019b2cc9fe306'},
#        {'author': {'email': '2bc9a21a85bf848cea1235e78a89481be6c9fa2a@lonw.net',
#          'name': 'Lon Willett'},
#         'distinct': True,
#         'message': 'linux4.14: update to 4.14.14',
#         'sha': '7937c80a60cbcc4b5ded09f407dab773bd00bbc9',
#         'url': 'https://api.github.com/repos/lonwillett/void-packages/commits/7937c80a60cbcc4b5ded09f407dab773bd00bbc9'}],
#       'distinct_size': 2,
#       'head': '7937c80a60cbcc4b5ded09f407dab773bd00bbc9',
#       'push_id': 2260644739,
#       'ref': 'refs/heads/sandbox',
#       'size': 2},
#      'repo': {'id': 92431021, 'name': 'lonwillett/void-packages'},
#      'type': 'PushEvent'},
#     '_type': 'data'},
#    {'_id': '7111388170',
#     '_index': 'github',
#     '_score': 30.4333,
#     '_source': {'actor': {'id': 28957163},
#      'created_at': '2018-01-17T14:05:24Z',
#      'id': '7111388170',
#      'payload': {'before': 'afbf584d11d20696b2fbc28348884ce3af8cb7a0',
#       'commits': [{'author': {'email': '2bc9a21a85bf848cea1235e78a89481be6c9fa2a@lonw.net',
#          'name': 'Lon Willett'},
#         'distinct': True,
#         'message': 'linux4.9: update custom config',
#         'sha': '280a7611c30e6783c710ce2f715bafcc08c523aa',
#         'url': 'https://api.github.com/repos/lonwillett/void-packages/commits/280a7611c30e6783c710ce2f715bafcc08c523aa'},
#        {'author': {'email': '2bc9a21a85bf848cea1235e78a89481be6c9fa2a@lonw.net',
#          'name': 'Lon Willett'},
#         'distinct': True,
#         'message': 'linux4.14: update custom config',
#         'sha': 'd6868338f3621dbf55c6f5229dccc967c0fe1b2d',
#         'url': 'https://api.github.com/repos/lonwillett/void-packages/commits/d6868338f3621dbf55c6f5229dccc967c0fe1b2d'}],
#       'distinct_size': 2,
#       'head': 'd6868338f3621dbf55c6f5229dccc967c0fe1b2d',
#       'push_id': 2260669360,
#       'ref': 'refs/heads/sandbox',
#       'size': 2},
#      'repo': {'id': 92431021, 'name': 'lonwillett/void-packages'},
#      'type': 'PushEvent'},
#     '_type': 'data'},
#    {'_id': '7062224290',
#     '_index': 'github',
#     '_score': 30.098423,
#     '_source': {'actor': {'id': 1056976},
#      'created_at': '2018-01-05T16:24:52Z',
#      'id': '7062224290',
#      'payload': {'before': '4f9fddb6f9bfe91090b27832330a69e2460753cd',
#       'commits': [{'author': {'email': '00f63b104cc192f7f01eceab27b343d9965c9f26@voidlinux.eu',
#          'name': 'Enno Boland'},
#         'distinct': True,
#         'message': 'linux4.4: update config, enable CONFIG_PAGE_TABLE_ISOLATION.',
#         'sha': '03f552cc33b37c5bce0979bc74c3df4bcadef2ae',
#         'url': 'https://api.github.com/repos/voidlinux/void-packages/commits/03f552cc33b37c5bce0979bc74c3df4bcadef2ae'},
#        {'author': {'email': '00f63b104cc192f7f01eceab27b343d9965c9f26@voidlinux.eu',
#          'name': 'Enno Boland'},
#         'distinct': True,
#         'message': 'linux4.9: update config, enable CONFIG_PAGE_TABLE_ISOLATION.',
#         'sha': 'de0d1260c5f79f6783ad6ffdba9e9d8ada56d07d',
#         'url': 'https://api.github.com/repos/voidlinux/void-packages/commits/de0d1260c5f79f6783ad6ffdba9e9d8ada56d07d'}],
#       'distinct_size': 2,
#       'head': 'de0d1260c5f79f6783ad6ffdba9e9d8ada56d07d',
#       'push_id': 2235018793,
#       'ref': 'refs/heads/master',
#       'size': 2},
#      'repo': {'id': 2060910, 'name': 'voidlinux/void-packages'},
#      'type': 'PushEvent'},
#     '_type': 'data'},
#    {'_id': '7159430949',
#     '_index': 'github',
#     '_score': 29.451185,
#     '_source': {'actor': {'id': 139},
#      'created_at': '2018-01-27T13:41:09Z',
#      'id': '7159430949',
#      'payload': {'before': 'b90eaa9026b26a6c1a22c0b63eb3524af831990f',
#       'commits': [{'author': {'email': 'd11242e3e7972fee41ed62707d0a0654cb81c15b@vuxu.org',
#          'name': 'Leah Neukirchen'},
#         'distinct': True,
#         'message': 'linux4.14: rebuild with gcc 7.3.0.',
#         'sha': 'fe296b233512d2286dd15b7bed127f93aa34614a',
#         'url': 'https://api.github.com/repos/voidlinux/void-packages/commits/fe296b233512d2286dd15b7bed127f93aa34614a'},
#        {'author': {'email': 'd11242e3e7972fee41ed62707d0a0654cb81c15b@vuxu.org',
#          'name': 'Leah Neukirchen'},
#         'distinct': True,
#         'message': 'linux4.9: update to 4.9.78.',
#         'sha': 'b9f7fa2838d36158cfdd3fd925a8929d76e77cee',
#         'url': 'https://api.github.com/repos/voidlinux/void-packages/commits/b9f7fa2838d36158cfdd3fd925a8929d76e77cee'}],
#       'distinct_size': 2,
#       'head': 'b9f7fa2838d36158cfdd3fd925a8929d76e77cee',
#       'push_id': 2285802473,
#       'ref': 'refs/heads/master',
#       'size': 2},
#      'repo': {'id': 2060910, 'name': 'voidlinux/void-packages'},
#      'type': 'PushEvent'},
#     '_type': 'data'},
#    {'_id': '5126511909',
#     '_index': 'github',
#     '_score': 28.009214,
#     '_source': {'actor': {'id': 827131},
#      'created_at': '2017-01-10T02:17:22Z',
#      'id': '5126511909',
#      'payload': {'before': '8d66acbef0d28553cf375ae2f6a92aa8671076ea',
#       'commits': [{'author': {'email': '3f1326dff4d85ad4ec938fb33f64575ace96db26@docker.com',
#          'name': 'Tibor Vass'},
#         'distinct': True,
#         'message': "plugins: restructure devices\n\n- Add Type, Major, Minor to Linux.Devices struct and don't make it\nsettable\n- Add Linux.DeviceCgroups to access a range of devices by major, minor,\n  type\n- Remove Linux.DeviceCreation because redundant with more powerful DeviceCgroups\n\nSigned-off-by: Tibor Vass <tibor@docker.com>",
#         'sha': 'b733b90d07f855c1a71cd83c492004d6422058d3',
#         'url': 'https://api.github.com/repos/tiborvass/docker/commits/b733b90d07f855c1a71cd83c492004d6422058d3'}],
#       'distinct_size': 1,
#       'head': 'b733b90d07f855c1a71cd83c492004d6422058d3',
#       'push_id': 1492073834,
#       'ref': 'refs/heads/plugin-devices-redone-master',
#       'size': 1},
#      'repo': {'id': 16678776, 'name': 'tiborvass/docker'},
#      'type': 'PushEvent'},
#     '_type': 'data'},
#    {'_id': '5126510046',
#     '_index': 'github',
#     '_score': 28.009214,
#     '_source': {'actor': {'id': 827131},
#      'created_at': '2017-01-10T02:16:48Z',
#      'id': '5126510046',
#      'payload': {'before': 'e46cd2c0c80e32ac5c17a3c6bcfc093554877451',
#       'commits': [{'author': {'email': '3f1326dff4d85ad4ec938fb33f64575ace96db26@docker.com',
#          'name': 'Tibor Vass'},
#         'distinct': True,
#         'message': "plugins: restructure devices\n\n- Add Type, Major, Minor to Linux.Devices struct and don't make it\nsettable\n- Add Linux.DeviceCgroups to access a range of devices by major, minor,\n  type\n- Remove Linux.DeviceCreation because redundant with more powerful DeviceCgroups\n\nSigned-off-by: Tibor Vass <tibor@docker.com>",
#         'sha': '8d66acbef0d28553cf375ae2f6a92aa8671076ea',
#         'url': 'https://api.github.com/repos/tiborvass/docker/commits/8d66acbef0d28553cf375ae2f6a92aa8671076ea'}],
#       'distinct_size': 1,
#       'head': '8d66acbef0d28553cf375ae2f6a92aa8671076ea',
#       'push_id': 1492073226,
#       'ref': 'refs/heads/plugin-devices-redone-master',
#       'size': 1},
#      'repo': {'id': 16678776, 'name': 'tiborvass/docker'},
#      'type': 'PushEvent'},
#     '_type': 'data'}],
#   'max_score': 41.493835,
#   'total': 73736},
#  'timed_out': False,
#  'took': 3645}

# %%
requests.get(database + '/_search?',headers=headers, data=json.dumps(
{
 "query": {
                    "bool": {
                        #"minimum_should_match": "75%",
                        "must": {
                            "multi_match" : {
                                "query": "Python", 
                                "fields": [
                                    "payload.pull_request.base.repo.language"
                                ],
       
                            }
                        }                       
                    }
                }
    ,"size":10    
    ,"_source":["type","created_at","id","repo.id","repo.name","actor.id","payload.pull_request.base.repo.language"]
} 
)
            ).json()
# Out:
# {'_shards': {'failed': 0, 'skipped': 0, 'successful': 1, 'total': 1},
#  'hits': {'hits': [{'_id': '5124568017',
#     '_index': 'github',
#     '_score': 2.1427596,
#     '_source': {'actor': {'id': 21140558},
#      'created_at': '2017-01-09T19:30:01Z',
#      'id': '5124568017',
#      'payload': {'pull_request': {'base': {'repo': {'language': 'Python'}}}},
#      'repo': {'id': 56726838,
#       'name': 'cornelius-keller/ansible-coreos-kubernetes'},
#      'type': 'PullRequestEvent'},
#     '_type': 'data'},
#    {'_id': '5124569274',
#     '_index': 'github',
#     '_score': 2.1427596,
#     '_source': {'actor': {'id': 219043},
#      'created_at': '2017-01-09T19:30:13Z',
#      'id': '5124569274',
#      'payload': {'pull_request': {'base': {'repo': {'language': 'Python'}}}},
#      'repo': {'id': 26414388, 'name': 'commontk/ctk-cli'},
#      'type': 'PullRequestEvent'},
#     '_type': 'data'},
#    {'_id': '5124569737',
#     '_index': 'github',
#     '_score': 2.1427596,
#     '_source': {'actor': {'id': 2945708},
#      'created_at': '2017-01-09T19:30:17Z',
#      'id': '5124569737',
#      'payload': {'pull_request': {'base': {'repo': {'language': 'Python'}}}},
#      'repo': {'id': 71516397, 'name': 'Cloud-CV/EvalAI'},
#      'type': 'PullRequestReviewCommentEvent'},
#     '_type': 'data'},
#    {'_id': '5124569757',
#     '_index': 'github',
#     '_score': 2.1427596,
#     '_source': {'actor': {'id': 127133},
#      'created_at': '2017-01-09T19:30:17Z',
#      'id': '5124569757',
#      'payload': {'pull_request': {'base': {'repo': {'language': 'Python'}}}},
#      'repo': {'id': 69488186, 'name': 'endlessm/endless-ndn'},
#      'type': 'PullRequestReviewCommentEvent'},
#     '_type': 'data'},
#    {'_id': '5124570339',
#     '_index': 'github',
#     '_score': 2.1427596,
#     '_source': {'actor': {'id': 2367539},
#      'created_at': '2017-01-09T19:30:24Z',
#      'id': '5124570339',
#      'payload': {'pull_request': {'base': {'repo': {'language': 'Python'}}}},
#      'repo': {'id': 247278, 'name': 'dimagi/commcare-hq'},
#      'type': 'PullRequestEvent'},
#     '_type': 'data'},
#    {'_id': '5124570415',
#     '_index': 'github',
#     '_score': 2.1427596,
#     '_source': {'actor': {'id': 23183498},
#      'created_at': '2017-01-09T19:30:25Z',
#      'id': '5124570415',
#      'payload': {'pull_request': {'base': {'repo': {'language': 'Python'}}}},
#      'repo': {'id': 53360534, 'name': 'avinetworks/sdk'},
#      'type': 'PullRequestEvent'},
#     '_type': 'data'},
#    {'_id': '5124570549',
#     '_index': 'github',
#     '_score': 2.1427596,
#     '_source': {'actor': {'id': 21351096},
#      'created_at': '2017-01-09T19:30:26Z',
#      'id': '5124570549',
#      'payload': {'pull_request': {'base': {'repo': {'language': 'Python'}}}},
#      'repo': {'id': 67767104, 'name': 'nicknomo/local_addons_odoo'},
#      'type': 'PullRequestEvent'},
#     '_type': 'data'},
#    {'_id': '5124571125',
#     '_index': 'github',
#     '_score': 2.1427596,
#     '_source': {'actor': {'id': 21351096},
#      'created_at': '2017-01-09T19:30:31Z',
#      'id': '5124571125',
#      'payload': {'pull_request': {'base': {'repo': {'language': 'Python'}}}},
#      'repo': {'id': 67767104, 'name': 'nicknomo/local_addons_odoo'},
#      'type': 'PullRequestEvent'},
#     '_type': 'data'},
#    {'_id': '5124571185',
#     '_index': 'github',
#     '_score': 2.1427596,
#     '_source': {'actor': {'id': 16739208},
#      'created_at': '2017-01-09T19:30:32Z',
#      'id': '5124571185',
#      'payload': {'pull_request': {'base': {'repo': {'language': 'Python'}}}},
#      'repo': {'id': 17908989, 'name': 'KitwareMedical/pyLAR'},
#      'type': 'PullRequestEvent'},
#     '_type': 'data'},
#    {'_id': '5124571983',
#     '_index': 'github',
#     '_score': 2.1427596,
#     '_source': {'actor': {'id': 346587},
#      'created_at': '2017-01-09T19:30:40Z',
#      'id': '5124571983',
#      'payload': {'pull_request': {'base': {'repo': {'language': 'Python'}}}},
#      'repo': {'id': 61641622, 'name': 'dotastro/hacks-collector'},
#      'type': 'PullRequestEvent'},
#     '_type': 'data'}],
#   'max_score': 2.1427596,
#   'total': 369613},
#  'timed_out': False,
#  'took': 2202}

# %%
xres3=requests.get(database + '/_search?',headers=headers, data=json.dumps(
{
  "query": {
    "function_score": {
      "query": {
        "match_all": {}
      },
      "functions": [
        {
          "random_score": {}
        }
      ]
    }
  }

    ,"size":1000    ,"_source":["type","created_at","id","repo.id","repo.name","actor.id","payload.comment.commit_id","payload.commits.message" ]
}    

)).json()

# %%
pd.DataFrame(xres3['hits']['hits'])
# Out:
#             _id  _index    _score  \
# 0    7067358132  github  1.000000
# 1    5113737188  github  1.000000
# 2    5122428165  github  1.000000
# 3    7071338041  github  1.000000
# 4    7097961580  github  1.000000
# 5    7095116372  github  1.000000
# 6    7082982095  github  1.000000
# 7    7076559875  github  1.000000
# 8    7160719216  github  1.000000
# 9    7089617330  github  1.000000
# 10   7103218980  github  1.000000
# 11   7111309903  github  1.000000
# 12   7119871132  github  1.000000
# 13   7125771892  github  1.000000
# 14   7127051203  github  1.000000
# 15   7148948950  github  1.000000
# 16   7139910034  github  1.000000
# 17   7137701292  github  1.000000
# 18   7153258707  github  1.000000
# 19   7169461196  github  1.000000
# 20   5172466611  github  1.000000
# 21   7169709731  github  1.000000
# 22   7165547760  github  1.000000
# 23   7063563134  github  0.999999
# 24   5118767513  github  0.999999
# 25   7064011467  github  0.999999
# 26   7068747454  github  0.999999
# 27   7095994107  github  0.999999
# 28   7092773796  github  0.999999
# 29   7083127863  github  0.999999
# ..          ...     ...       ...
# 970  7124365308  github  0.999981
# 971  7114498455  github  0.999981
# 972  7125413948  github  0.999981
# 973  5153807691  github  0.999981
# 974  7128250760  github  0.999981
# 975  7146991256  github  0.999981
# 976  7141142014  github  0.999981
# 977  7142362995  github  0.999981
# 978  7137226663  github  0.999981
# 979  7148250330  github  0.999981
# 980  7163337145  github  0.999981
# 981  7152898861  github  0.999981
# 982  7156236348  github  0.999981
# 983  7158579262  github  0.999981
# 984  5149621270  github  0.999981
# 985  5152154709  github  0.999981
# 986  7161074494  github  0.999981
# 987  7159982723  github  0.999981
# 988  7166732586  github  0.999981
# 989  7168766803  github  0.999981
# 990  7164274927  github  0.999981
# 991  7166101979  github  0.999981
# 992  5166516586  github  0.999981
# 993  7180970111  github  0.999981
# 994  5116764190  github  0.999980
# 995  7058403913  github  0.999980
# 996  7064921198  github  0.999980
# 997  7071741771  github  0.999980
# 998  7100265967  github  0.999980
# 999  7091666141  github  0.999980
#
#                                                _source _type
# 0    {'actor': {'id': 29607371}, 'payload': {'commi...  data
# 1    {'actor': {'id': 8656788}, 'payload': {'commit...  data
# 2    {'actor': {'id': 19617700}, 'repo': {'name': '...  data
# 3    {'actor': {'id': 17437789}, 'payload': {'commi...  data
# 4    {'actor': {'id': 2705860}, 'repo': {'name': 'm...  data
# 5    {'actor': {'id': 380816}, 'repo': {'name': 'em...  data
# 6    {'actor': {'id': 29139614}, 'payload': {'commi...  data
# 7    {'actor': {'id': 123951}, 'payload': {'commits...  data
# 8    {'actor': {'id': 4778485}, 'repo': {'name': 't...  data
# 9    {'actor': {'id': 33857496}, 'payload': {'commi...  data
# 10   {'actor': {'id': 30585466}, 'payload': {'commi...  data
# 11   {'actor': {'id': 16133320}, 'repo': {'name': '...  data
# 12   {'actor': {'id': 1042445}, 'repo': {'name': 'a...  data
# 13   {'actor': {'id': 16934066}, 'repo': {'name': '...  data
# 14   {'actor': {'id': 31182295}, 'payload': {'commi...  data
# 15   {'actor': {'id': 32764315}, 'repo': {'name': '...  data
# 16   {'actor': {'id': 28762106}, 'repo': {'name': '...  data
# 17   {'actor': {'id': 686247}, 'repo': {'name': 'pr...  data
# 18   {'actor': {'id': 307049}, 'repo': {'name': 'do...  data
# 19   {'actor': {'id': 17991461}, 'payload': {'commi...  data
# 20   {'actor': {'id': 4216574}, 'payload': {'commit...  data
# 21   {'actor': {'id': 9927080}, 'repo': {'name': 'T...  data
# 22   {'actor': {'id': 51265}, 'payload': {'comment'...  data
# 23   {'actor': {'id': 16723349}, 'payload': {'commi...  data
# 24   {'actor': {'id': 23665947}, 'payload': {'commi...  data
# 25   {'actor': {'id': 14175800}, 'payload': {'commi...  data
# 26   {'actor': {'id': 3502741}, 'repo': {'name': 'e...  data
# 27   {'actor': {'id': 656739}, 'repo': {'name': 'pr...  data
# 28   {'actor': {'id': 4711480}, 'repo': {'name': 'j...  data
# 29   {'actor': {'id': 1686556}, 'payload': {'commit...  data
# ..                                                 ...   ...
# 970  {'actor': {'id': 7640693}, 'repo': {'name': 'n...  data
# 971  {'actor': {'id': 28941271}, 'repo': {'name': '...  data
# 972  {'actor': {'id': 32054652}, 'payload': {'commi...  data
# 973  {'actor': {'id': 160078}, 'payload': {'commits...  data
# 974  {'actor': {'id': 17859844}, 'repo': {'name': '...  data
# 975  {'actor': {'id': 25781788}, 'payload': {'commi...  data
# 976  {'actor': {'id': 4700817}, 'payload': {'commit...  data
# 977  {'actor': {'id': 3425702}, 'repo': {'name': 'n...  data
# 978  {'actor': {'id': 9041370}, 'payload': {'commit...  data
# 979  {'actor': {'id': 35626411}, 'repo': {'name': '...  data
# 980  {'actor': {'id': 15681491}, 'payload': {'commi...  data
# 981  {'actor': {'id': 1255037}, 'repo': {'name': 'c...  data
# 982  {'actor': {'id': 4370550}, 'repo': {'name': 'd...  data
# 983  {'actor': {'id': 8337409}, 'repo': {'name': 'd...  data
# 984  {'actor': {'id': 10059507}, 'payload': {'commi...  data
# 985  {'actor': {'id': 20230450}, 'payload': {'commi...  data
# 986  {'actor': {'id': 158862}, 'repo': {'name': 'ar...  data
# 987  {'actor': {'id': 1589480}, 'payload': {'commit...  data
# 988  {'actor': {'id': 323385}, 'payload': {'commits...  data
# 989  {'actor': {'id': 8546787}, 'payload': {'commit...  data
# 990  {'actor': {'id': 29216624}, 'repo': {'name': '...  data
# 991  {'actor': {'id': 8078968}, 'payload': {'commen...  data
# 992  {'actor': {'id': 8770962}, 'repo': {'name': 'u...  data
# 993  {'actor': {'id': 18696528}, 'repo': {'name': '...  data
# 994  {'actor': {'id': 1175888}, 'repo': {'name': 'e...  data
# 995  {'actor': {'id': 22189186}, 'payload': {'commi...  data
# 996  {'actor': {'id': 32674674}, 'payload': {'commi...  data
# 997  {'actor': {'id': 3019665}, 'payload': {'commit...  data
# 998  {'actor': {'id': 17463361}, 'repo': {'name': '...  data
# 999  {'actor': {'id': 30829071}, 'payload': {'commi...  data
#
# [1000 rows x 5 columns]

# %%
xres3['hits']
# Out:
# {'hits': [{'_id': '7067358132',
#    '_index': 'github',
#    '_score': 0.9999999,
#    '_source': {'actor': {'id': 29607371},
#     'created_at': '2018-01-07T22:04:35Z',
#     'id': '7067358132',
#     'payload': {'commits': [{'message': 'visage moyen en cours'},
#       {'message': 'visage moyen marche'}]},
#     'repo': {'id': 114908151, 'name': 'Hellyon/Faceties'},
#     'type': 'PushEvent'},
#    '_type': 'data'},
#   {'_id': '5113737188',
#    '_index': 'github',
#    '_score': 0.9999999,
#    '_source': {'actor': {'id': 8656788},
#     'created_at': '2017-01-06T16:14:38Z',
#     'id': '5113737188',
#     'payload': {'commits': [{'message': 'BFS with level tracking working'}]},
#     'repo': {'id': 78219720, 'name': 'KevinDalleau/graph2vec'},
#     'type': 'PushEvent'},
#    '_type': 'data'},
#   {'_id': '5122428165',
#    '_index': 'github',
#    '_score': 0.9999999,
#    '_source': {'actor': {'id': 19617700},
#     'created_at': '2017-01-09T13:28:37Z',
#     'id': '5122428165',
#     'repo': {'id': 45979262, 'name': 'MichaelRow/Lyrics'},
#     'type': 'WatchEvent'},
#    '_type': 'data'},
#   {'_id': '7071338041',
#    '_index': 'github',
#    '_score': 0.9999999,
#    '_source': {'actor': {'id': 17437789},
#     'created_at': '2018-01-08T19:39:51Z',
#     'id': '7071338041',
#     'payload': {'commits': [{'message': 'lcl_progress to global'}]},
#     'repo': {'id': 88505824, 'name': 'christianguenter2/abapGit'},
#     'type': 'PushEvent'},
#    '_type': 'data'},
#   {'_id': '7097961580',
#    '_index': 'github',
#    '_score': 0.9999999,
#    '_source': {'actor': {'id': 2705860},
#     'created_at': '2018-01-15T01:07:07Z',
#     'id': '7097961580',
#     'repo': {'id': 109106298,
#      'name': 'matteocng/storybook-fetch-messages-task-example'},
#     'type': 'DeleteEvent'},
#    '_type': 'data'},
#   {'_id': '7095116372',
#    '_index': 'github',
#    '_score': 0.9999999,
#    '_source': {'actor': {'id': 380816},
#     'created_at': '2018-01-13T13:15:11Z',
#     'id': '7095116372',
#     'repo': {'id': 95909196, 'name': 'em-casa/re-frontend'},
#     'type': 'DeleteEvent'},
#    '_type': 'data'},
#   {'_id': '7082982095',
#    '_index': 'github',
#    '_score': 0.9999999,
#    '_source': {'actor': {'id': 29139614},
#     'created_at': '2018-01-10T22:09:58Z',
#     'id': '7082982095',
#     'payload': {'commits': [{'message': 'chore(deps): update dependency tslint to v5.9.0'}]},
#     'repo': {'id': 92611177, 'name': 'ikatyang/tsconfig-extends'},
#     'type': 'PushEvent'},
#    '_type': 'data'},
#   {'_id': '7076559875',
#    '_index': 'github',
#    '_score': 0.9999999,
#    '_source': {'actor': {'id': 123951},
#     'created_at': '2018-01-09T18:37:32Z',
#     'id': '7076559875',
#     'payload': {'commits': [{'message': 'Mirroring from Micro.blog.'}]},
#     'repo': {'id': 98114596, 'name': 'adamprocter/microblog'},
#     'type': 'PushEvent'},
#    '_type': 'data'},
#   {'_id': '7160719216',
#    '_index': 'github',
#    '_score': 0.9999999,
#    '_source': {'actor': {'id': 4778485},
#     'created_at': '2018-01-28T04:35:36Z',
#     'id': '7160719216',
#     'repo': {'id': 18928344, 'name': 'thelinmichael/spotify-web-api-java'},
#     'type': 'ReleaseEvent'},
#    '_type': 'data'},
#   {'_id': '7089617330',
#    '_index': 'github',
#    '_score': 0.9999999,
#    '_source': {'actor': {'id': 33857496},
#     'created_at': '2018-01-12T03:56:48Z',
#     'id': '7089617330',
#     'payload': {'commits': [{'message': 'Made changes'},
#       {'message': "Merge remote-tracking branch 'origin/master'\n\n# Conflicts:\n#\tapp/src/main/java/com/agro/agrocrm/util/URLRequest.java"}]},
#     'repo': {'id': 115075610, 'name': 'gwilliam187/agro-crm-app'},
#     'type': 'PushEvent'},
#    '_type': 'data'},
#   {'_id': '7103218980',
#    '_index': 'github',
#    '_score': 0.9999999,
#    '_source': {'actor': {'id': 30585466},
#     'created_at': '2018-01-16T03:24:30Z',
#     'id': '7103218980',
#     'payload': {'commits': [{'message': 'タイムオブジェクト削除\n落ちるブロックの「ステージ５ボスを倒したときに初期位置に瞬時に戻す」仕様を「倒したとき、ブロックを初期位置まで上昇させる」仕様に変更しました。'}]},
#     'repo': {'id': 98849727, 'name': 'TsudaD/teamcreate'},
#     'type': 'PushEvent'},
#    '_type': 'data'},
#   {'_id': '7111309903',
#    '_index': 'github',
#    '_score': 0.9999999,
#    '_source': {'actor': {'id': 16133320},
#     'created_at': '2018-01-17T13:51:21Z',
#     'id': '7111309903',
#     'repo': {'id': 84476389, 'name': 'thejameskyle/react-loadable'},
#     'type': 'WatchEvent'},
#    '_type': 'data'},
#   {'_id': '7119871132',
#    '_index': 'github',
#    '_score': 0.9999999,
#    '_source': {'actor': {'id': 1042445},
#     'created_at': '2018-01-18T22:27:01Z',
#     'id': '7119871132',
#     'repo': {'id': 118045683, 'name': 'arcVyas/jenkins-docs'},
#     'type': 'CreateEvent'},
#    '_type': 'data'},
#   {'_id': '7125771892',
#    '_index': 'github',
#    '_score': 0.9999999,
#    '_source': {'actor': {'id': 16934066},
#     'created_at': '2018-01-20T01:24:00Z',
#     'id': '7125771892',
#     'repo': {'id': 118197016, 'name': 'sieunkr/design-patterns'},
#     'type': 'CreateEvent'},
#    '_type': 'data'},
#   {'_id': '7127051203',
#    '_index': 'github',
#    '_score': 0.9999999,
#    '_source': {'actor': {'id': 31182295},
#     'created_at': '2018-01-20T17:24:21Z',
#     'id': '7127051203',
#     'payload': {'commits': [{'message': 'A'}]},
#     'repo': {'id': 107002666, 'name': 'plt-laboratory/plt'},
#     'type': 'PushEvent'},
#    '_type': 'data'},
#   {'_id': '7148948950',
#    '_index': 'github',
#    '_score': 0.9999999,
#    '_source': {'actor': {'id': 32764315},
#     'created_at': '2018-01-25T09:13:48Z',
#     'id': '7148948950',
#     'repo': {'id': 106801355, 'name': 'Smartling-test/test'},
#     'type': 'DeleteEvent'},
#    '_type': 'data'},
#   {'_id': '7139910034',
#    '_index': 'github',
#    '_score': 0.9999999,
#    '_source': {'actor': {'id': 28762106},
#     'created_at': '2018-01-23T18:49:39Z',
#     'id': '7139910034',
#     'repo': {'id': 92620036,
#      'name': 'dipper-github-lhr-yul-sfo-icn/test-python-sample'},
#     'type': 'CreateEvent'},
#    '_type': 'data'},
#   {'_id': '7137701292',
#    '_index': 'github',
#    '_score': 0.9999999,
#    '_source': {'actor': {'id': 686247},
#     'created_at': '2018-01-23T11:59:45Z',
#     'id': '7137701292',
#     'repo': {'id': 49767244, 'name': 'primefaces/primeng'},
#     'type': 'IssuesEvent'},
#    '_type': 'data'},
#   {'_id': '7153258707',
#    '_index': 'github',
#    '_score': 0.9999999,
#    '_source': {'actor': {'id': 307049},
#     'created_at': '2018-01-26T00:41:05Z',
#     'id': '7153258707',
#     'repo': {'id': 117670548, 'name': 'dotclear/clearbricks'},
#     'type': 'PushEvent'},
#    '_type': 'data'},
#   {'_id': '7169461196',
#    '_index': 'github',
#    '_score': 0.9999999,
#    '_source': {'actor': {'id': 17991461},
#     'created_at': '2018-01-30T06:36:10Z',
#     'id': '7169461196',
#     'payload': {'commits': [{'message': 'Added the read me file to the repo\n\nThis is just an template for the readme'}]},
#     'repo': {'id': 110939007, 'name': 'heshanpadmasiri/Robot-Controller'},
#     'type': 'PushEvent'},
#    '_type': 'data'},
#   {'_id': '5172466611',
#    '_index': 'github',
#    '_score': 0.9999999,
#    '_source': {'actor': {'id': 4216574},
#     'created_at': '2017-01-18T13:39:11Z',
#     'id': '5172466611',
#     'payload': {'commits': [{'message': '对于当前的贴图，边界限制应该是u重复，v限定。\n（以后自己实现mipmap的时候怎么办？）'}]},
#     'repo': {'id': 76718001, 'name': 'guozhaokui/threejspbr'},
#     'type': 'PushEvent'},
#    '_type': 'data'},
#   {'_id': '7169709731',
#    '_index': 'github',
#    '_score': 0.9999999,
#    '_source': {'actor': {'id': 9927080},
#     'created_at': '2018-01-30T07:51:21Z',
#     'id': '7169709731',
#     'repo': {'id': 27179591, 'name': 'T5750/poi'},
#     'type': 'CreateEvent'},
#    '_type': 'data'},
#   {'_id': '7165547760',
#    '_index': 'github',
#    '_score': 0.9999999,
#    '_source': {'actor': {'id': 51265},
#     'created_at': '2018-01-29T14:13:04Z',
#     'id': '7165547760',
#     'payload': {'comment': {'commit_id': '34af1ad9be9c6c369f7c57a21dd09c1648bc05f1'}},
#     'repo': {'id': 113197161, 'name': 'openshift/cluster-operator'},
#     'type': 'PullRequestReviewCommentEvent'},
#    '_type': 'data'},
#   {'_id': '7063563134',
#    '_index': 'github',
#    '_score': 0.99999946,
#    '_source': {'actor': {'id': 16723349},
#     'created_at': '2018-01-05T22:11:10Z',
#     'id': '7063563134',
#     'payload': {'commits': [{'message': 'Initial changes\n\nInitial changes.'}]},
#     'repo': {'id': 116416329, 'name': 'rulesninja/domain-modeler'},
#     'type': 'PushEvent'},
#    '_type': 'data'},
#   {'_id': '5118767513',
#    '_index': 'github',
#    '_score': 0.99999946,
#    '_source': {'actor': {'id': 23665947},
#     'created_at': '2017-01-08T10:33:59Z',
#     'id': '5118767513',
#     'payload': {'commits': [{'message': 'Remove materialize, add bootstrap'},
#       {'message': 'html markup index'},
#       {'message': 'Markup index.html'},
#       {'message': 'index.html working'},
#       {'message': 'Build test'},
#       {'message': 'Build test 2'},
#       {'message': 'gulpfile'},
#       {'message': 'Build task ready'}]},
#     'repo': {'id': 77447347, 'name': 'RamizIb/DeepAqua'},
#     'type': 'PushEvent'},
#    '_type': 'data'},
#   {'_id': '7064011467',
#    '_index': 'github',
#    '_score': 0.99999946,
#    '_source': {'actor': {'id': 14175800},
#     'created_at': '2018-01-06T01:08:08Z',
#     'id': '7064011467',
#     'payload': {'commits': [{'message': 'add test handback xliff files'}]},
#     'repo': {'id': 82270896,
#      'name': 'OpenLocalizationTestOrg/ol-test3-handback'},
#     'type': 'PushEvent'},
#    '_type': 'data'},
#   {'_id': '7068747454',
#    '_index': 'github',
#    '_score': 0.99999946,
#    '_source': {'actor': {'id': 3502741},
#     'created_at': '2018-01-08T09:53:40Z',
#     'id': '7068747454',
#     'repo': {'id': 116659139, 'name': 'erikll/consignment'},
#     'type': 'CreateEvent'},
#    '_type': 'data'},
#   {'_id': '7095994107',
#    '_index': 'github',
#    '_score': 0.99999946,
#    '_source': {'actor': {'id': 656739},
#     'created_at': '2018-01-13T23:38:49Z',
#     'id': '7095994107',
#     'repo': {'id': 112615188, 'name': 'project-cx/pbx-group-security'},
#     'type': 'IssueCommentEvent'},
#    '_type': 'data'},
#   {'_id': '7092773796',
#    '_index': 'github',
#    '_score': 0.99999946,
#    '_source': {'actor': {'id': 4711480},
#     'created_at': '2018-01-12T17:51:37Z',
#     'id': '7092773796',
#     'repo': {'id': 117128377, 'name': 'jakent/tree-of-life'},
#     'type': 'CreateEvent'},
#    '_type': 'data'},
#   {'_id': '7083127863',
#    '_index': 'github',
#    '_score': 0.99999946,
#    '_source': {'actor': {'id': 1686556},
#     'created_at': '2018-01-10T22:47:02Z',
#     'id': '7083127863',
#     'payload': {'commits': [{'message': 'directory restructure'}]},
#     'repo': {'id': 79676108, 'name': 'patrickkunka/tome'},
#     'type': 'PushEvent'},
#    '_type': 'data'},
#   {'_id': '7078617779',
#    '_index': 'github',
#    '_score': 0.99999946,
#    '_source': {'actor': {'id': 11293084},
#     'created_at': '2018-01-10T05:13:47Z',
#     'id': '7078617779',
#     'repo': {'id': 109843059, 'name': 'leusonmario/cron-utils'},
#     'type': 'CreateEvent'},
#    '_type': 'data'},
#   {'_id': '7177929788',
#    '_index': 'github',
#    '_score': 0.99999946,
#    '_source': {'actor': {'id': 12693984},
#     'created_at': '2018-01-31T15:07:51Z',
#     'id': '7177929788',
#     'payload': {'commits': [{'message': '200 OK http://wolesi.website/pve/showdoc.aspx?Id=1887'}]},
#     'repo': {'id': 42310621,
#      'name': 'everypolitician-scrapers/afghanistan-assembly'},
#     'type': 'PushEvent'},
#    '_type': 'data'},
#   {'_id': '7090790060',
#    '_index': 'github',
#    '_score': 0.99999946,
#    '_source': {'actor': {'id': 29726686},
#     'created_at': '2018-01-12T10:21:18Z',
#     'id': '7090790060',
#     'repo': {'id': 111383521, 'name': 'difi/jenkins-pipeline'},
#     'type': 'DeleteEvent'},
#    '_type': 'data'},
#   {'_id': '7106691800',
#    '_index': 'github',
#    '_score': 0.99999946,
#    '_source': {'actor': {'id': 313721},
#     'created_at': '2018-01-16T17:23:02Z',
#     'id': '7106691800',
#     'repo': {'id': 45061433, 'name': 'cmu-phil/tetrad'},
#     'type': 'IssueCommentEvent'},
#    '_type': 'data'},
#   {'_id': '7109095729',
#    '_index': 'github',
#    '_score': 0.99999946,
#    '_source': {'actor': {'id': 630673},
#     'created_at': '2018-01-17T03:56:40Z',
#     'id': '7109095729',
#     'payload': {'commits': [{'message': 'Update multiple files\n\nChange service to ContactSensor for doors and windows'},
#       {'message': 'Merge pull request #54 from schmittx/door-window-sensor-fix\n\nFix service for door and window sensors'},
#       {'message': 'Bumped version to 1.5.9'},
#       {'message': 'Remove deprecated services from cached accessories'},
#       {'message': 'Bumped version to 1.6.0'},
#       {'message': "Remove the Android app's Client ID and secret"},
#       {'message': 'Config is validated upon startup\n\nWill raise an error when when client_id or client_secret are missing'},
#       {'message': 'Update binary_switch.js\n\nAdded support for leakSMART valve by checking for state.opened.\nAdded config option for outlets and switches. Modified state.consumption (consumption only exists for Quirky Outlinks)'},
#       {'message': 'Added support for doorbell motion sensors'},
#       {'message': 'Updated dependencies'},
#       {'message': 'Bumped version to 1.7.0'},
#       {'message': 'Fixed #69'},
#       {'message': 'Bumped version to 1.7.1'},
#       {'message': 'Fixed typo in readme'},
#       {'message': 'Added a mention of Chamberlain MyQ® Home Bridge to README'},
#       {'message': 'Updated dependencies'},
#       {'message': 'Docs'},
#       {'message': 'Bumped version to 1.8.0'},
#       {'message': 'Fixed enums in sensor_pod.js'},
#       {'message': 'Added ability to expose binary switches as outlets or switches. Fixes #58'}]},
#     'repo': {'id': 106365403, 'name': 'schmittx/homebridge-wink3'},
#     'type': 'PushEvent'},
#    '_type': 'data'},
#   {'_id': '7118087577',
#    '_index': 'github',
#    '_score': 0.99999946,
#    '_source': {'actor': {'id': 32717724},
#     'created_at': '2018-01-18T16:21:08Z',
#     'id': '7118087577',
#     'payload': {'commits': [{'message': 'automatically backed up by learn'}]},
#     'repo': {'id': 118004785,
#      'name': 'jshwa/js-ajax-ajax-and-callbacks-lab-v-000'},
#     'type': 'PushEvent'},
#    '_type': 'data'},
#   {'_id': '7123383501',
#    '_index': 'github',
#    '_score': 0.99999946,
#    '_source': {'actor': {'id': 10077243},
#     'created_at': '2018-01-19T15:15:11Z',
#     'id': '7123383501',
#     'payload': {'commits': [{'message': ''}]},
#     'repo': {'id': 113460766, 'name': 'avtomon/PQFormBuilder'},
#     'type': 'PushEvent'},
#    '_type': 'data'},
#   {'_id': '7161943149',
#    '_index': 'github',
#    '_score': 0.99999946,
#    '_source': {'actor': {'id': 24826908},
#     'created_at': '2018-01-28T18:58:04Z',
#     'id': '7161943149',
#     'repo': {'id': 119279799, 'name': 'Plajer/Village_Defense'},
#     'type': 'CreateEvent'},
#    '_type': 'data'},
#   {'_id': '7127636020',
#    '_index': 'github',
#    '_score': 0.99999946,
#    '_source': {'actor': {'id': 8517910},
#     'created_at': '2018-01-21T00:06:58Z',
#     'id': '7127636020',
#     'repo': {'id': 46629356,
#      'name': 'Lombiq/Orchard-Scripting-Extensions-PHP'},
#     'type': 'PushEvent'},
#    '_type': 'data'},
#   {'_id': '7151376821',
#    '_index': 'github',
#    '_score': 0.99999946,
#    '_source': {'actor': {'id': 1282050},
#     'created_at': '2018-01-25T17:18:19Z',
#     'id': '7151376821',
#     'payload': {'commits': [{'message': 'Deployed c6a2c00 with MkDocs version: 0.17.2'}]},
#     'repo': {'id': 116691622, 'name': 'Yichuans/iucn-hand-over'},
#     'type': 'PushEvent'},
#    '_type': 'data'},
#   {'_id': '7140674334',
#    '_index': 'github',
#    '_score': 0.99999946,
#    '_source': {'actor': {'id': 4951803},
#     'created_at': '2018-01-23T21:25:05Z',
#     'id': '7140674334',
#     'repo': {'id': 80638907, 'name': 'birm/gh-funstats'},
#     'type': 'IssuesEvent'},
#    '_type': 'data'},
#   {'_id': '7130634606',
#    '_index': 'github',
#    '_score': 0.99999946,
#    '_source': {'actor': {'id': 13191938},
#     'created_at': '2018-01-22T07:44:55Z',
#     'id': '7130634606',
#     'payload': {'commits': [{'message': 'update'}]},
#     'repo': {'id': 118422266, 'name': 'mutex73/LeetCode'},
#     'type': 'PushEvent'},
#    '_type': 'data'},
#   {'_id': '7168151553',
#    '_index': 'github',
#    '_score': 0.99999946,
#    '_source': {'actor': {'id': 10729230},
#     'created_at': '2018-01-29T23:07:46Z',
#     'id': '7168151553',
#     'payload': {'commits': [{'message': 'automatically backed up by learn'}]},
#     'repo': {'id': 119306543,
#      'name': 'sherryptk/sinatra-fwitter-group-project-v-000'},
#     'type': 'PushEvent'},
#    '_type': 'data'},
#   {'_id': '5142971472',
#    '_index': 'github',
#    '_score': 0.99999946,
#    '_source': {'actor': {'id': 16478785},
#     'created_at': '2017-01-12T14:51:11Z',
#     'id': '5142971472',
#     'payload': {'commits': [{'message': 'Fix Upadate'},
#       {'message': 'FIX BUG'},
#       {'message': 'FIX REBASE ;)'},
#       {'message': 'add lib locally'},
#       {'message': 'Print CSV\n\nwith System.out.prinln'},
#       {'message': 'commit 1'},
#       {'message': 'Fix toString()\n\nfix toStirng()'},
#       {'message': 'dell lines'},
#       {'message': 'fix CSVtoObject \n\n;)'},
#       {'message': 'refresh ;)'}]},
#     'repo': {'id': 75382517, 'name': 'Bakhah/Godsavethebibine'},
#     'type': 'PushEvent'},
#    '_type': 'data'},
#   {'_id': '7163775771',
#    '_index': 'github',
#    '_score': 0.99999946,
#    '_source': {'actor': {'id': 35590162},
#     'created_at': '2018-01-29T08:54:18Z',
#     'id': '7163775771',
#     'repo': {'id': 118083636, 'name': 'unitydemo2/Docworks'},
#     'type': 'PushEvent'},
#    '_type': 'data'},
#   {'_id': '7173078026',
#    '_index': 'github',
#    '_score': 0.99999946,
#    '_source': {'actor': {'id': 233},
#     'created_at': '2018-01-30T18:45:21Z',
#     'id': '7173078026',
#     'payload': {'commits': [{'message': 'Resolve Haml 5 warnings (#2149)'}]},
#     'repo': {'id': 261943, 'name': 'middleman/middleman'},
#     'type': 'PushEvent'},
#    '_type': 'data'},
#   {'_id': '7162214909',
#    '_index': 'github',
#    '_score': 0.99999946,
#    '_source': {'actor': {'id': 16711277},
#     'created_at': '2018-01-28T21:35:52Z',
#     'id': '7162214909',
#     'payload': {'commits': [{'message': 'cleaning'}]},
#     'repo': {'id': 113304584, 'name': 'Sachka/Tolkienizer'},
#     'type': 'PushEvent'},
#    '_type': 'data'},
#   {'_id': '5173060005',
#    '_index': 'github',
#    '_score': 0.99999946,
#    '_source': {'actor': {'id': 13338419},
#     'created_at': '2017-01-18T15:12:54Z',
#     'id': '5173060005',
#     'repo': {'id': 79352018, 'name': 'Dezodev/verbose-pancake'},
#     'type': 'CreateEvent'},
#    '_type': 'data'},
#   {'_id': '5128228169',
#    '_index': 'github',
#    '_score': 0.9999993,
#    '_source': {'actor': {'id': 3624877},
#     'created_at': '2017-01-10T10:44:17Z',
#     'id': '5128228169',
#     'repo': {'id': 15348522, 'name': 'googleads/googleads-php-lib'},
#     'type': 'IssueCommentEvent'},
#    '_type': 'data'},
#   {'_id': '5127331197',
#    '_index': 'github',
#    '_score': 0.9999993,
#    '_source': {'actor': {'id': 22745312},
#     'created_at': '2017-01-10T07:16:48Z',
#     'id': '5127331197',
#     'repo': {'id': 78507943, 'name': 'RuoChen95/coursera-test'},
#     'type': 'CreateEvent'},
#    '_type': 'data'},
#   {'_id': '7060842488',
#    '_index': 'github',
#    '_score': 0.9999993,
#    '_source': {'actor': {'id': 4701338},
#     'created_at': '2018-01-05T10:33:36Z',
#     'id': '7060842488',
#     'repo': {'id': 15634981, 'name': 'godotengine/godot'},
#     'type': 'IssueCommentEvent'},
#    '_type': 'data'},
#   {'_id': '5120547590',
#    '_index': 'github',
#    '_score': 0.9999993,
#    '_source': {'actor': {'id': 24231314},
#     'created_at': '2017-01-09T04:21:30Z',
#     'id': '5120547590',
#     'payload': {'commits': [{'message': 'tomo'}]},
#     'repo': {'id': 78305198, 'name': 'Bigsam82/prouno'},
#     'type': 'PushEvent'},
#    '_type': 'data'},
#   {'_id': '7070666318',
#    '_index': 'github',
#    '_score': 0.9999993,
#    '_source': {'actor': {'id': 14952196},
#     'created_at': '2018-01-08T17:06:40Z',
#     'id': '7070666318',
#     'repo': {'id': 116704123, 'name': 'orlov-dev/fenix'},
#     'type': 'CreateEvent'},
#    '_type': 'data'},
#   {'_id': '7100000214',
#    '_index': 'github',
#    '_score': 0.9999993,
#    '_source': {'actor': {'id': 33111559},
#     'created_at': '2018-01-15T12:32:49Z',
#     'id': '7100000214',
#     'payload': {'commits': [{'message': 'Site updated: 2018-01-15 12:32:39'}]},
#     'repo': {'id': 108649285, 'name': 'geyan666/geyan666.github.io'},
#     'type': 'PushEvent'},
#    '_type': 'data'},
#   {'_id': '7098922940',
#    '_index': 'github',
#    '_score': 0.9999993,
#    '_source': {'actor': {'id': 15936115},
#     'created_at': '2018-01-15T08:16:57Z',
#     'id': '7098922940',
#     'repo': {'id': 51924293,
#      'name': 'PHPfox-Official/phpfox-v4-feature-requests'},
#     'type': 'IssueCommentEvent'},
#    '_type': 'data'},
#   {'_id': '7095759880',
#    '_index': 'github',
#    '_score': 0.9999993,
#    '_source': {'actor': {'id': 418747},
#     'created_at': '2018-01-13T20:40:17Z',
#     'id': '7095759880',
#     'payload': {'commits': [{'message': 'Add Ruby code to create basic robots.txt file'}]},
#     'repo': {'id': 116636265, 'name': 'jbampton/charts'},
#     'type': 'PushEvent'},
#    '_type': 'data'},
#   {'_id': '7084458077',
#    '_index': 'github',
#    '_score': 0.9999993,
#    '_source': {'actor': {'id': 8517910},
#     'created_at': '2018-01-11T06:59:25Z',
#     'id': '7084458077',
#     'repo': {'id': 46566064, 'name': 'Lombiq/Combinator'},
#     'type': 'PushEvent'},
#    '_type': 'data'},
#   {'_id': '7074719354',
#    '_index': 'github',
#    '_score': 0.9999993,
#    '_source': {'actor': {'id': 3455449},
#     'created_at': '2018-01-09T12:27:28Z',
#     'id': '7074719354',
#     'repo': {'id': 92093628, 'name': 'Didstopia/SDL'},
#     'type': 'PushEvent'},
#    '_type': 'data'},
#   {'_id': '7162430479',
#    '_index': 'github',
#    '_score': 0.9999993,
#    '_source': {'actor': {'id': 363388},
#     'created_at': '2018-01-28T23:45:30Z',
#     'id': '7162430479',
#     'repo': {'id': 118678476, 'name': 'SomethingWithHorizons/mailserver'},
#     'type': 'GollumEvent'},
#    '_type': 'data'},
#   {'_id': '5170566239',
#    '_index': 'github',
#    '_score': 0.9999993,
#    '_source': {'actor': {'id': 979929},
#     'created_at': '2017-01-18T06:54:45Z',
#     'id': '5170566239',
#     'repo': {'id': 26677107, 'name': 'jedireza/hapi-node-postgres'},
#     'type': 'PullRequestEvent'},
#    '_type': 'data'},
#   {'_id': '7088921209',
#    '_index': 'github',
#    '_score': 0.9999993,
#    '_source': {'actor': {'id': 16406727},
#     'created_at': '2018-01-11T23:34:06Z',
#     'id': '7088921209',
#     'repo': {'id': 49035474, 'name': 'NOAA-PMEL/LAS'},
#     'type': 'IssueCommentEvent'},
#    '_type': 'data'},
#   {'_id': '7101450645',
#    '_index': 'github',
#    '_score': 0.9999993,
#    '_source': {'actor': {'id': 5014119},
#     'created_at': '2018-01-15T17:33:29Z',
#     'id': '7101450645',
#     'payload': {'commits': [{'message': 'I18n: Update translation uk (100%).\n\n28 translated messages.\n\nTransifex (https://www.transifex.com/xfce/public/).'}]},
#     'repo': {'id': 28493731, 'name': 'xfce-mirror/xfce4-verve-plugin'},
#     'type': 'PushEvent'},
#    '_type': 'data'},
#   {'_id': '7111049746',
#    '_index': 'github',
#    '_score': 0.9999993,
#    '_source': {'actor': {'id': 2412177},
#     'created_at': '2018-01-17T12:58:13Z',
#     'id': '7111049746',
#     'repo': {'id': 104457964,
#      'name': 'loevgaard/dandomain-foundation-entities'},
#     'type': 'CreateEvent'},
#    '_type': 'data'},
#   {'_id': '7114129327',
#    '_index': 'github',
#    '_score': 0.9999993,
#    '_source': {'actor': {'id': 1288694},
#     'created_at': '2018-01-17T23:05:16Z',
#     'id': '7114129327',
#     'payload': {'commits': [{'message': '2.1.1'},
#       {'message': 'Prepare next development version'}]},
#     'repo': {'id': 115447167, 'name': 'wKovacs64/meetup-raffle-web'},
#     'type': 'PushEvent'},
#    '_type': 'data'},
#   {'_id': '7124694839',
#    '_index': 'github',
#    '_score': 0.9999993,
#    '_source': {'actor': {'id': 32944990},
#     'created_at': '2018-01-19T19:52:16Z',
#     'id': '7124694839',
#     'repo': {'id': 118171210, 'name': 'AbhirajSidhu/hello-world'},
#     'type': 'CreateEvent'},
#    '_type': 'data'},
#   {'_id': '7126631465',
#    '_index': 'github',
#    '_score': 0.9999993,
#    '_source': {'actor': {'id': 5219415},
#     'created_at': '2018-01-20T12:48:30Z',
#     'id': '7126631465',
#     'payload': {'commits': [{'message': '📦 Game Update 20.01.2018 (3.3 MB)'}]},
#     'repo': {'id': 52203133, 'name': 'frk1/hazedumper'},
#     'type': 'PushEvent'},
#    '_type': 'data'},
#   {'_id': '7152392745',
#    '_index': 'github',
#    '_score': 0.9999993,
#    '_source': {'actor': {'id': 29377728},
#     'created_at': '2018-01-25T20:52:18Z',
#     'id': '7152392745',
#     'payload': {'commits': [{'message': 'added home page table'}]},
#     'repo': {'id': 118670262, 'name': 'landonwshields/sla-db'},
#     'type': 'PushEvent'},
#    '_type': 'data'},
#   {'_id': '7143570966',
#    '_index': 'github',
#    '_score': 0.9999993,
#    '_source': {'actor': {'id': 7017740},
#     'created_at': '2018-01-24T11:16:10Z',
#     'id': '7143570966',
#     'payload': {'commits': [{'message': 'Rename carrot-cake.md to _my_recipes/carrot-cake.md'}]},
#     'repo': {'id': 89935632, 'name': 'trianglegirl/recipes'},
#     'type': 'PushEvent'},
#    '_type': 'data'},
#   {'_id': '7131475372',
#    '_index': 'github',
#    '_score': 0.9999993,
#    '_source': {'actor': {'id': 3446885},
#     'created_at': '2018-01-22T11:07:45Z',
#     'id': '7131475372',
#     'repo': {'id': 18780056, 'name': 'xxorde/librekinect'},
#     'type': 'WatchEvent'},
#    '_type': 'data'},
#   {'_id': '5147405214',
#    '_index': 'github',
#    '_score': 0.9999993,
#    '_source': {'actor': {'id': 111481},
#     'created_at': '2017-01-13T07:05:49Z',
#     'id': '5147405214',
#     'repo': {'id': 72848828, 'name': 'xorock/zend-service-recaptcha-v2'},
#     'type': 'IssueCommentEvent'},
#    '_type': 'data'},
#   {'_id': '5155803176',
#    '_index': 'github',
#    '_score': 0.9999993,
#    '_source': {'actor': {'id': 810762},
#     'created_at': '2017-01-15T16:36:03Z',
#     'id': '5155803176',
#     'repo': {'id': 12084976, 'name': 'modesttree/Zenject'},
#     'type': 'IssueCommentEvent'},
#    '_type': 'data'},
#   {'_id': '7170598465',
#    '_index': 'github',
#    '_score': 0.9999993,
#    '_source': {'actor': {'id': 33541658},
#     'created_at': '2018-01-30T11:00:05Z',
#     'id': '7170598465',
#     'repo': {'id': 112326848, 'name': 'Community-Tech/admin'},
#     'type': 'IssueCommentEvent'},
#    '_type': 'data'},
#   {'_id': '5161735839',
#    '_index': 'github',
#    '_score': 0.9999993,
#    '_source': {'actor': {'id': 16896769},
#     'created_at': '2017-01-16T21:26:28Z',
#     'id': '5161735839',
#     'payload': {'commits': [{'message': 'Add all commit'}]},
#     'repo': {'id': 50422059,
#      'name': 'FGtatsuroWork3/TestForStaticFileSharing2'},
#     'type': 'PushEvent'},
#    '_type': 'data'},
#   {'_id': '7179854114',
#    '_index': 'github',
#    '_score': 0.9999993,
#    '_source': {'actor': {'id': 11655766},
#     'created_at': '2018-01-31T21:07:47Z',
#     'id': '7179854114',
#     'repo': {'id': 107575570, 'name': 'blackbaud/skyux-lib-testing'},
#     'type': 'PullRequestEvent'},
#    '_type': 'data'},
#   {'_id': '7066176087',
#    '_index': 'github',
#    '_score': 0.999999,
#    '_source': {'actor': {'id': 35184566},
#     'created_at': '2018-01-07T07:18:32Z',
#     'id': '7066176087',
#     'payload': {'commits': [{'message': 'commit'}]},
#     'repo': {'id': 116545082, 'name': 'qxdys6bm/qxdys6bm.github.io'},
#     'type': 'PushEvent'},
#    '_type': 'data'},
#   {'_id': '7060348209',
#    '_index': 'github',
#    '_score': 0.999999,
#    '_source': {'actor': {'id': 275871},
#     'created_at': '2018-01-05T08:18:28Z',
#     'id': '7060348209',
#     'repo': {'id': 27193779, 'name': 'nodejs/node'},
#     'type': 'IssueCommentEvent'},
#    '_type': 'data'},
#   {'_id': '5119713653',
#    '_index': 'github',
#    '_score': 0.999999,
#    '_source': {'actor': {'id': 16382930},
#     'created_at': '2017-01-08T20:36:44Z',
#     'id': '5119713653',
#     'payload': {'commits': [{'message': 'debug'}]},
#     'repo': {'id': 70310108, 'name': 'fpasquer/21sh'},
#     'type': 'PushEvent'},
#    '_type': 'data'},
#   {'_id': '7072869978',
#    '_index': 'github',
#    '_score': 0.999999,
#    '_source': {'actor': {'id': 35247092},
#     'created_at': '2018-01-09T03:16:38Z',
#     'id': '7072869978',
#     'repo': {'id': 116759712, 'name': 'ljs6874521/HelloWord'},
#     'type': 'CreateEvent'},
#    '_type': 'data'},
#   {'_id': '7097512499',
#    '_index': 'github',
#    '_score': 0.999999,
#    '_source': {'actor': {'id': 17279765},
#     'created_at': '2018-01-14T20:06:11Z',
#     'id': '7097512499',
#     'repo': {'id': 50256891, 'name': 'pret/pokeruby'},
#     'type': 'PullRequestEvent'},
#    '_type': 'data'},
#   {'_id': '7094051840',
#    '_index': 'github',
#    '_score': 0.999999,
#    '_source': {'actor': {'id': 28762106},
#     'created_at': '2018-01-12T23:30:21Z',
#     'id': '7094051840',
#     'repo': {'id': 92620036,
#      'name': 'dipper-github-lhr-yul-sfo-icn/test-python-sample'},
#     'type': 'CreateEvent'},
#    '_type': 'data'},
#   {'_id': '7079771879',
#    '_index': 'github',
#    '_score': 0.999999,
#    '_source': {'actor': {'id': 28945567},
#     'created_at': '2018-01-10T10:53:45Z',
#     'id': '7079771879',
#     'repo': {'id': 116944189, 'name': 'kammavamsi/sample-react-application'},
#     'type': 'CreateEvent'},
#    '_type': 'data'},
#   {'_id': '7074394700',
#    '_index': 'github',
#    '_score': 0.999999,
#    '_source': {'actor': {'id': 123951},
#     'created_at': '2018-01-09T11:07:12Z',
#     'id': '7074394700',
#     'payload': {'commits': [{'message': 'Mirroring from Micro.blog.'}]},
#     'repo': {'id': 98114596, 'name': 'adamprocter/microblog'},
#     'type': 'PushEvent'},
#    '_type': 'data'},
#   {'_id': '5142236250',
#    '_index': 'github',
#    '_score': 0.999999,
#    '_source': {'actor': {'id': 17688012},
#     'created_at': '2017-01-12T12:37:25Z',
#     'id': '5142236250',
#     'repo': {'id': 51830024, 'name': 'popcorn-official/popcorn-desktop'},
#     'type': 'IssueCommentEvent'},
#    '_type': 'data'},
#   {'_id': '7086997101',
#    '_index': 'github',
#    '_score': 0.999999,
#    '_source': {'actor': {'id': 35341807},
#     'created_at': '2018-01-11T16:25:52Z',
#     'id': '7086997101',
#     'repo': {'id': 117123930, 'name': 'sheminaz/DemoTest'},
#     'type': 'CreateEvent'},
#    '_type': 'data'},
#   {'_id': '7101638565',
#    '_index': 'github',
#    '_score': 0.999999,
#    '_source': {'actor': {'id': 7769313},
#     'created_at': '2018-01-15T18:23:44Z',
#     'id': '7101638565',
#     'payload': {'commits': [{'message': 'placeholder for queue name for htcondor'}]},
#     'repo': {'id': 86180687, 'name': 'TGAC/grassroots-core'},
#     'type': 'PushEvent'},
#    '_type': 'data'},
#   {'_id': '7109947378',
#    '_index': 'github',
#    '_score': 0.999999,
#    '_source': {'actor': {'id': 35522968},
#     'created_at': '2018-01-17T08:54:24Z',
#     'id': '7109947378',
#     'repo': {'id': 117810494, 'name': 'yzwia/vision'},
#     'type': 'CreateEvent'},
#    '_type': 'data'},
#   {'_id': '7116249922',
#    '_index': 'github',
#    '_score': 0.999999,
#    '_source': {'actor': {'id': 207405},
#     'created_at': '2018-01-18T10:19:57Z',
#     'id': '7116249922',
#     'payload': {'commits': [{'message': 'auto publish 2018-01-18 10:19:54+00:00'}]},
#     'repo': {'id': 36236297, 'name': 'sagemath/planet'},
#     'type': 'PushEvent'},
#    '_type': 'data'},
#   {'_id': '7122313398',
#    '_index': 'github',
#    '_score': 0.999999,
#    '_source': {'actor': {'id': 9824023},
#     'created_at': '2018-01-19T11:16:35Z',
#     'id': '7122313398',
#     'payload': {'commits': [{'message': 'sql: Disable asserts for release builds\n\nMacro SQLITE_DEBUG was set unconditionally, so both release build\nmodes had debugging enabled, including all asserts() and TESTCASE().\nMove this macro definition under check if mode is Debug and fix all\nwarning which arised after disabling asserts().\nMost of them are unused variables.'},
#       {'message': 'sql: Enable asserts for box/sql.c\n\nSince asserts were always disbled in src/box/sql.c, number\nof issues were hidden. This patch enables asserts for mentioned\nfile by disabling set of NDEBUG in box/src/sqliteInt.h.\nAlso this patch fixes incorrect assertions about strlen() and\nassertion that fieldno should always be less than format->field_count.\nThis assert is not always hold, e.g. for _schema space where max_id\nis stored behind formatted fields.\n\nCloses #3057'}]},
#     'repo': {'id': 911980, 'name': 'tarantool/tarantool'},
#     'type': 'PushEvent'},
#    '_type': 'data'},
#   {'_id': '7161160056',
#    '_index': 'github',
#    '_score': 0.999999,
#    '_source': {'actor': {'id': 2992398},
#     'created_at': '2018-01-28T10:53:12Z',
#     'id': '7161160056',
#     'payload': {'commits': [{'message': 'Ajout forRoot'}]},
#     'repo': {'id': 112198184, 'name': 'Agesse/NGAgesse'},
#     'type': 'PushEvent'},
#    '_type': 'data'},
#   {'_id': '7128370422',
#    '_index': 'github',
#    '_score': 0.999999,
#    '_source': {'actor': {'id': 19528094},
#     'created_at': '2018-01-21T11:12:32Z',
#     'id': '7128370422',
#     'payload': {'commits': [{'message': 'Update data.json'}]},
#     'repo': {'id': 59465493, 'name': 'shenzhouzd/update'},
#     'type': 'PushEvent'},
#    '_type': 'data'},
#   {'_id': '7145312263',
#    '_index': 'github',
#    '_score': 0.999999,
#    '_source': {'actor': {'id': 35577041},
#     'created_at': '2018-01-24T16:50:12Z',
#     'id': '7145312263',
#     'payload': {'commits': [{'message': 'Update index.html'}]},
#     'repo': {'id': 118027131, 'name': 'Jmb1922/jmb1922.github.io'},
#     'type': 'PushEvent'},
#    '_type': 'data'},
#   {'_id': '5131817850',
#    '_index': 'github',
#    '_score': 0.999999,
#    '_source': {'actor': {'id': 19152466},
#     'created_at': '2017-01-10T21:09:38Z',
#     'id': '5131817850',
#     'payload': {'commits': [{'message': 'Final ver.'}]},
#     'repo': {'id': 78215780, 'name': 'catSalem/KPI-Files'},
#     'type': 'PushEvent'},
#    '_type': 'data'},
#   {'_id': '7142247221',
#    '_index': 'github',
#    '_score': 0.999999,
#    '_source': {'actor': {'id': 23658480},
#     'created_at': '2018-01-24T05:36:51Z',
#     'id': '7142247221',
#     'payload': {'commits': [{'message': 'small change'}]},
#     'repo': {'id': 117473450, 'name': 'Yujia-Wang/yujia-wang.github.io'},
#     'type': 'PushEvent'},
#    '_type': 'data'},
#   {'_id': '7136107484',
#    '_index': 'github',
#    '_score': 0.999999,
#    '_source': {'actor': {'id': 22823376},
#     'created_at': '2018-01-23T05:04:59Z',
#     'id': '7136107484',
#     'payload': {'commits': [{'message': 'Add measurement measurements/circuit/2018-01-23T05:04:58.084289.json.'}]},
#     'repo': {'id': 70839104, 'name': 'StanfordLegion/perf-data'},
#     'type': 'PushEvent'},
#    '_type': 'data'},
#   {'_id': '5134491342',
#    '_index': 'github',
#    '_score': 0.999999,
#    '_source': {'actor': {'id': 4760551},
#     'created_at': '2017-01-11T09:12:22Z',
#     'id': '5134491342',
#     'payload': {'commits': [{'message': "- fixed the railgun's spiral duration was set incorrectly."}]},
#     'repo': {'id': 10879376, 'name': 'coelckers/gzdoom'},
#     'type': 'PushEvent'},
#    '_type': 'data'},
#   {'_id': '7163076261',
#    '_index': 'github',
#    '_score': 0.999999,
#    '_source': {'actor': {'id': 35910504},
#     'created_at': '2018-01-29T05:05:16Z',
#     'id': '7163076261',
#     'repo': {'id': 119334060, 'name': 'linhtetpaing9/hello-world'},
#     'type': 'CreateEvent'},
#    '_type': 'data'},
#   {'_id': '5139262258',
#    '_index': 'github',
#    '_score': 0.999999,
#    '_source': {'actor': {'id': 1504464},
#     'created_at': '2017-01-11T23:10:39Z',
#     'id': '5139262258',
#     'payload': {'commits': [{'message': 'brats/brats-staticfile-edge build 8 unclaiming: edge-1.buildpacks.ci'}]},
#     'repo': {'id': 34543204, 'name': 'cloudfoundry/buildpacks-ci'},
#     'type': 'PushEvent'},
#    '_type': 'data'},
#   {'_id': '5145933966',
#    '_index': 'github',
#    '_score': 0.999999,
#    '_source': {'actor': {'id': 2874596},
#     'created_at': '2017-01-12T23:06:16Z',
#     'id': '5145933966',
#     'payload': {'commits': [{'message': 'Update README.md'}]},
#     'repo': {'id': 78784569, 'name': 'pablovilla83/do-cdmx-nginx'},
#     'type': 'PushEvent'},
#    '_type': 'data'},
#   {'_id': '5143181206',
#    '_index': 'github',
#    '_score': 0.999999,
#    '_source': {'actor': {'id': 20407524},
#     'created_at': '2017-01-12T15:22:46Z',
#     'id': '5143181206',
#     'repo': {'id': 20580498, 'name': 'kubernetes/kubernetes'},
#     'type': 'IssueCommentEvent'},
#    '_type': 'data'},
#   {'_id': '7159005846',
#    '_index': 'github',
#    '_score': 0.999999,
#    '_source': {'actor': {'id': 14920103},
#     'created_at': '2018-01-27T07:52:56Z',
#     'id': '7159005846',
#     'payload': {'commits': [{'message': '获取用户信息接口修改'}]},
#     'repo': {'id': 115163628, 'name': 'Andy-Yin/XinDaSchoolAPI'},
#     'type': 'PushEvent'},
#    '_type': 'data'},
#   {'_id': '7160312662',
#    '_index': 'github',
#    '_score': 0.999999,
#    '_source': {'actor': {'id': 3906539},
#     'created_at': '2018-01-27T22:59:39Z',
#     'id': '7160312662',
#     'repo': {'id': 42519441, 'name': 'chiuan/TTUIFramework'},
#     'type': 'WatchEvent'},
#    '_type': 'data'},
#   {'_id': '7161308379',
#    '_index': 'github',
#    '_score': 0.999999,
#    '_source': {'actor': {'id': 35888182},
#     'created_at': '2018-01-28T12:40:16Z',
#     'id': '7161308379',
#     'repo': {'id': 119257070, 'name': 'yusuke-j0728/sample'},
#     'type': 'CreateEvent'},
#    '_type': 'data'},
#   {'_id': '5150807757',
#    '_index': 'github',
#    '_score': 0.999999,
#    '_source': {'actor': {'id': 11401319},
#     'created_at': '2017-01-13T19:06:22Z',
#     'id': '5150807757',
#     'payload': {'commits': [{'message': 'uploading project'}]},
#     'repo': {'id': 78876321, 'name': 'stone-pagamentos/demo-sdk-android'},
#     'type': 'PushEvent'},
#    '_type': 'data'},
#   {'_id': '7166842610',
#    '_index': 'github',
#    '_score': 0.999999,
#    '_source': {'actor': {'id': 5539247},
#     'created_at': '2018-01-29T18:33:11Z',
#     'id': '7166842610',
#     'payload': {'commits': [{'message': 'Removed .DS_Store file from repository'}]},
#     'repo': {'id': 108033929, 'name': 'jdelcastillo1/Pythium_Pop'},
#     'type': 'PushEvent'},
#    '_type': 'data'},
#   {'_id': '5162998187',
#    '_index': 'github',
#    '_score': 0.999999,
#    '_source': {'actor': {'id': 24291069},
#     'created_at': '2017-01-17T03:58:21Z',
#     'id': '5162998187',
#     'payload': {'commits': [{'message': 'Update huanxingtu.html'}]},
#     'repo': {'id': 77388549, 'name': 'likailun6/likailun6.github.io'},
#     'type': 'PushEvent'},
#    '_type': 'data'},
#   {'_id': '5154983935',
#    '_index': 'github',
#    '_score': 0.999999,
#    '_source': {'actor': {'id': 1060},
#     'created_at': '2017-01-15T06:45:29Z',
#     'id': '5154983935',
#     'repo': {'id': 46619651, 'name': 'librariesio/sentinel'},
#     'type': 'IssuesEvent'},
#    '_type': 'data'},
#   {'_id': '5172629697',
#    '_index': 'github',
#    '_score': 0.999999,
#    '_source': {'actor': {'id': 431261},
#     'created_at': '2017-01-18T14:07:21Z',
#     'id': '5172629697',
#     'repo': {'id': 17143026, 'name': 'jarcoal/httpmock'},
#     'type': 'MemberEvent'},
#    '_type': 'data'},
#   {'_id': '7174712747',
#    '_index': 'github',
#    '_score': 0.999999,
#    '_source': {'actor': {'id': 33104488},
#     'created_at': '2018-01-31T01:03:14Z',
#     'id': '7174712747',
#     'repo': {'id': 108593869,
#      'name': 'dipper-github-fra-sin-syd-nrt/test-python-sample'},
#     'type': 'CreateEvent'},
#    '_type': 'data'},
#   {'_id': '5177467656',
#    '_index': 'github',
#    '_score': 0.999999,
#    '_source': {'actor': {'id': 2328242},
#     'created_at': '2017-01-19T06:14:01Z',
#     'id': '5177467656',
#     'payload': {'comment': {'commit_id': 'df5752f03030a5e03cfc4c74c5914abb59ea42da'}},
#     'repo': {'id': 57415761, 'name': 'gereeter/crossbeam'},
#     'type': 'PullRequestReviewCommentEvent'},
#    '_type': 'data'},
#   {'_id': '7065861304',
#    '_index': 'github',
#    '_score': 0.99999887,
#    '_source': {'actor': {'id': 5384588},
#     'created_at': '2018-01-07T02:03:17Z',
#     'id': '7065861304',
#     'repo': {'id': 98467418, 'name': 'google-test/signcla-probe-repo'},
#     'type': 'IssueCommentEvent'},
#    '_type': 'data'},
#   {'_id': '7062015788',
#    '_index': 'github',
#    '_score': 0.99999887,
#    '_source': {'actor': {'id': 536803},
#     'created_at': '2018-01-05T15:41:16Z',
#     'id': '7062015788',
#     'repo': {'id': 17803236, 'name': 'ncw/rclone'},
#     'type': 'IssuesEvent'},
#    '_type': 'data'},
#   {'_id': '5120619939',
#    '_index': 'github',
#    '_score': 0.99999887,
#    '_source': {'actor': {'id': 24999509},
#     'created_at': '2017-01-09T04:59:44Z',
#     'id': '5120619939',
#     'repo': {'id': 78395316, 'name': 'ItsRaw/ExoticBans'},
#     'type': 'CreateEvent'},
#    '_type': 'data'},
#   {'_id': '7068805513',
#    '_index': 'github',
#    '_score': 0.99999887,
#    '_source': {'actor': {'id': 8314092},
#     'created_at': '2018-01-08T10:07:58Z',
#     'id': '7068805513',
#     'payload': {'commits': [{'message': 'Updated: archive.md'}]},
#     'repo': {'id': 109661188, 'name': 'unconfigured/unconfigured.github.io'},
#     'type': 'PushEvent'},
#    '_type': 'data'},
#   {'_id': '7096235012',
#    '_index': 'github',
#    '_score': 0.99999887,
#    '_source': {'actor': {'id': 13212452},
#     'created_at': '2018-01-14T03:31:03Z',
#     'id': '7096235012',
#     'payload': {'commits': [{'message': 'attempt at css'},
#       {'message': "Merge remote-tracking branch 'refs/remotes/origin/master'"},
#       {'message': 'actual success at css'}]},
#     'repo': {'id': 117327898, 'name': 'Noodlebrain/parent-to-parent'},
#     'type': 'PushEvent'},
#    '_type': 'data'},
#   {'_id': '7092500669',
#    '_index': 'github',
#    '_score': 0.99999887,
#    '_source': {'actor': {'id': 2394803},
#     'created_at': '2018-01-12T16:47:26Z',
#     'id': '7092500669',
#     'repo': {'id': 99376350, 'name': 'fcaldas/fcaldas.github.com'},
#     'type': 'CreateEvent'},
#    '_type': 'data'},
#   {'_id': '7083741044',
#    '_index': 'github',
#    '_score': 0.99999887,
#    '_source': {'actor': {'id': 7055107},
#     'created_at': '2018-01-11T02:09:26Z',
#     'id': '7083741044',
#     'repo': {'id': 117037099, 'name': 'fanybook/Nestjs30Days'},
#     'type': 'WatchEvent'},
#    '_type': 'data'},
#   {'_id': '7079035151',
#    '_index': 'github',
#    '_score': 0.99999887,
#    '_source': {'actor': {'id': 17794532},
#     'created_at': '2018-01-10T07:49:52Z',
#     'id': '7079035151',
#     'repo': {'id': 116924730, 'name': 'maisya/pro_monitoring'},
#     'type': 'ForkEvent'},
#    '_type': 'data'},
#   {'_id': '5171532919',
#    '_index': 'github',
#    '_score': 0.99999887,
#    '_source': {'actor': {'id': 15478059},
#     'created_at': '2017-01-18T10:38:02Z',
#     'id': '5171532919',
#     'payload': {'commits': [{'message': 'TenderProcessTest as Base class'},
#       {'message': 'create Base classes for import'}]},
#     'repo': {'id': 79254723, 'name': 'yarsanich/openprocurement.api'},
#     'type': 'PushEvent'},
#    '_type': 'data'},
#   {'_id': '7090857027',
#    '_index': 'github',
#    '_score': 0.99999887,
#    '_source': {'actor': {'id': 18685509},
#     'created_at': '2018-01-12T10:36:08Z',
#     'id': '7090857027',
#     'payload': {'commits': [{'message': 'Compile C plugins'}]},
#     'repo': {'id': 117227863, 'name': 'GBedenko/Opspack-Template-Test'},
#     'type': 'PushEvent'},
#    '_type': 'data'},
#   {'_id': '7107010696',
#    '_index': 'github',
#    '_score': 0.99999887,
#    '_source': {'actor': {'id': 7308528},
#     'created_at': '2018-01-16T18:28:01Z',
#     'id': '7107010696',
#     'repo': {'id': 4095811, 'name': 'Hexxeh/rpi-firmware'},
#     'type': 'IssueCommentEvent'},
#    '_type': 'data'},
#   {'_id': '7108924975',
#    '_index': 'github',
#    '_score': 0.99999887,
#    '_source': {'actor': {'id': 6749661},
#     'created_at': '2018-01-17T02:51:36Z',
#     'id': '7108924975',
#     'payload': {'commits': [{'message': 'test commit'}]},
#     'repo': {'id': 73416557, 'name': 'test987987/test14'},
#     'type': 'PushEvent'},
#    '_type': 'data'},
#   {'_id': '7117636049',
#    '_index': 'github',
#    '_score': 0.99999887,
#    '_source': {'actor': {'id': 1262548},
#     'created_at': '2018-01-18T15:07:44Z',
#     'id': '7117636049',
#     'repo': {'id': 105260268, 'name': 'doudz/pyqtdeploy'},
#     'type': 'PushEvent'},
#    '_type': 'data'},
#   {'_id': '7123247235',
#    '_index': 'github',
#    '_score': 0.99999887,
#    '_source': {'actor': {'id': 3929002},
#     'created_at': '2018-01-19T14:50:51Z',
#     'id': '7123247235',
#     'payload': {'commits': [{'message': 'Adjusted consensus construction method'}]},
#     'repo': {'id': 96222552, 'name': 'Feathergunner/DebruijnGraphBuilder'},
#     'type': 'PushEvent'},
#    '_type': 'data'},
#   {'_id': '5154487741',
#    '_index': 'github',
#    '_score': 0.99999887,
#    '_source': {'actor': {'id': 16198293},
#     'created_at': '2017-01-14T23:29:34Z',
#     'id': '5154487741',
#     'payload': {'commits': [{'message': 'Added new file'}]},
#     'repo': {'id': 67168356, 'name': 'cf-container-networking/toque-stats'},
#     'type': 'PushEvent'},
#    '_type': 'data'},
#   {'_id': '7126520078',
#    '_index': 'github',
#    '_score': 0.99999887,
#    '_source': {'actor': {'id': 8517910},
#     'created_at': '2018-01-20T11:22:50Z',
#     'id': '7126520078',
#     'repo': {'id': 46595756,
#      'name': 'Lombiq/Combinator-CoffeeScript-Preprocessor'},
#     'type': 'PushEvent'},
#    '_type': 'data'},
#   {'_id': '7151441106',
#    '_index': 'github',
#    '_score': 0.99999887,
#    '_source': {'actor': {'id': 12717194},
#     'created_at': '2018-01-25T17:31:12Z',
#     'id': '7151441106',
#     'payload': {'commits': [{'message': 'Add missing params'}]},
#     'repo': {'id': 114301229, 'name': 'rackerlabs/cc-api-tests'},
#     'type': 'PushEvent'},
#    '_type': 'data'},
#   {'_id': '7140948577',
#    '_index': 'github',
#    '_score': 0.99999887,
#    '_source': {'actor': {'id': 21337531},
#     'created_at': '2018-01-23T22:23:09Z',
#     'id': '7140948577',
#     'payload': {'commits': [{'message': 'Update.'}]},
#     'repo': {'id': 118677515, 'name': 'csapersson/Firebase-with-Node'},
#     'type': 'PushEvent'},
#    '_type': 'data'},
#   {'_id': '7131128487',
#    '_index': 'github',
#    '_score': 0.99999887,
#    '_source': {'actor': {'id': 15829493},
#     'created_at': '2018-01-22T09:52:37Z',
#     'id': '7131128487',
#     'repo': {'id': 116167731, 'name': 'yuzu-emu/yuzu'},
#     'type': 'WatchEvent'},
#    '_type': 'data'},
#   {'_id': '7167709828',
#    '_index': 'github',
#    '_score': 0.99999887,
#    '_source': {'actor': {'id': 35590162},
#     'created_at': '2018-01-29T21:29:56Z',
#     'id': '7167709828',
#     'repo': {'id': 118083636, 'name': 'unitydemo2/Docworks'},
#     'type': 'PushEvent'},
#    '_type': 'data'},
#   {'_id': '5146906274',
#    '_index': 'github',
#    '_score': 0.99999887,
#    '_source': {'actor': {'id': 4001789},
#     'created_at': '2017-01-13T03:48:59Z',
#     'id': '5146906274',
#     'payload': {'commits': [{'message': 'Update coverage from 4.2 to 4.3'},
#       {'message': 'Merge pull request #87 from aio-libs/pyup-update-coverage-4.2-to-4.3\n\nUpdate coverage to 4.3'},
#       {'message': 'Update coverage from 4.3 to 4.3.1'},
#       {'message': 'ensure requests to verify ssl by verify value of client'},
#       {'message': 'Merge pull request #91 from sunghyunzz/master\n\nfix endpoint to pass verify argument to aiohttp connector'},
#       {'message': 'Merge pull request #89 from aio-libs/pyup-update-coverage-4.3-to-4.3.1\n\nUpdate coverage to 4.3.1'},
#       {'message': "Merge remote-tracking branch 'aio-libs/master'"}]},
#     'repo': {'id': 76943116, 'name': 'vharitonsky/aiobotocore'},
#     'type': 'PushEvent'},
#    '_type': 'data'},
#   {'_id': '5155532871',
#    '_index': 'github',
#    '_score': 0.99999887,
#    '_source': {'actor': {'id': 12096477},
#     'created_at': '2017-01-15T13:55:59Z',
#     'id': '5155532871',
#     'repo': {'id': 34507229, 'name': 'oknosoft/windowbuilder'},
#     'type': 'GollumEvent'},
#    '_type': 'data'},
#   {'_id': '7173434486',
#    '_index': 'github',
#    '_score': 0.99999887,
#    '_source': {'actor': {'id': 19914705},
#     'created_at': '2018-01-30T19:55:52Z',
#     'id': '7173434486',
#     'repo': {'id': 52027975, 'name': 'mongodb/docs-bi-connector'},
#     'type': 'PullRequestEvent'},
#    '_type': 'data'},
#   {'_id': '5154698002',
#    '_index': 'github',
#    '_score': 0.99999887,
#    '_source': {'actor': {'id': 4210342},
#     'created_at': '2017-01-15T02:20:45Z',
#     'id': '5154698002',
#     'payload': {'commits': [{'message': 'Revamp auto-completion logic'}]},
#     'repo': {'id': 77369463, 'name': 'James-Yu/LaTeX-Workshop'},
#     'type': 'PushEvent'},
#    '_type': 'data'},
#   {'_id': '5173510943',
#    '_index': 'github',
#    '_score': 0.99999887,
#    '_source': {'actor': {'id': 25062122},
#     'created_at': '2017-01-18T16:15:33Z',
# ...
#     'type': 'DeleteEvent'},
#    '_type': 'data'},
#   {'_id': '7181685107',
#    '_index': 'github',
#    '_score': 0.99998176,
#    '_source': {'actor': {'id': 5545912},
#     'created_at': '2018-02-01T06:34:53Z',
#     'id': '7181685107',
#     'repo': {'id': 109123719,
#      'name': 'shenliuyang/appsugar-web-archetypes-kotlin'},
#     'type': 'CreateEvent'},
#    '_type': 'data'},
#   {'_id': '5123918997',
#    '_index': 'github',
#    '_score': 0.9999813,
#    '_source': {'actor': {'id': 15897474},
#     'created_at': '2017-01-09T17:35:19Z',
#     'id': '5123918997',
#     'payload': {'commits': [{'message': 'Added config file'}]},
#     'repo': {'id': 78452037,
#      'name': 'samanthamolnar/samanthamolnar.github.io'},
#     'type': 'PushEvent'},
#    '_type': 'data'},
#   {'_id': '7060092886',
#    '_index': 'github',
#    '_score': 0.9999813,
#    '_source': {'actor': {'id': 29476255},
#     'created_at': '2018-01-05T06:43:07Z',
#     'id': '7060092886',
#     'payload': {'commits': [{'message': 'test uterance'},
#       {'message': 'test utternace'}]},
#     'repo': {'id': 113029064, 'name': 'KenrickV-Hexaware/WakefieldPoC'},
#     'type': 'PushEvent'},
#    '_type': 'data'},
#   {'_id': '7063025028',
#    '_index': 'github',
#    '_score': 0.9999813,
#    '_source': {'actor': {'id': 3131232},
#     'created_at': '2018-01-05T19:42:23Z',
#     'id': '7063025028',
#     'repo': {'id': 12082924, 'name': 'dyve/django-bootstrap3'},
#     'type': 'WatchEvent'},
#    '_type': 'data'},
#   {'_id': '7072619326',
#    '_index': 'github',
#    '_score': 0.9999813,
#    '_source': {'actor': {'id': 12693984},
#     'created_at': '2018-01-09T01:41:09Z',
#     'id': '7072619326',
#     'payload': {'commits': [{'message': '200 OK http://wolesi.website/pve/showdoc.aspx?Id=1782'}]},
#     'repo': {'id': 42310621,
#      'name': 'everypolitician-scrapers/afghanistan-assembly'},
#     'type': 'PushEvent'},
#    '_type': 'data'},
#   {'_id': '7096848814',
#    '_index': 'github',
#    '_score': 0.9999813,
#    '_source': {'actor': {'id': 35422361},
#     'created_at': '2018-01-14T12:59:11Z',
#     'id': '7096848814',
#     'payload': {'commits': [{'message': '123\n\n123'}]},
#     'repo': {'id': 117428168, 'name': 'KeshaWarden/123'},
#     'type': 'PushEvent'},
#    '_type': 'data'},
#   {'_id': '7095596376',
#    '_index': 'github',
#    '_score': 0.9999813,
#    '_source': {'actor': {'id': 2511168},
#     'created_at': '2018-01-13T18:45:22Z',
#     'id': '7095596376',
#     'payload': {'commits': [{'message': 'GIT CloneShare Commit'}]},
#     'repo': {'id': 117347799, 'name': 'amaximus/JamesBond'},
#     'type': 'PushEvent'},
#    '_type': 'data'},
#   {'_id': '7084540758',
#    '_index': 'github',
#    '_score': 0.9999813,
#    '_source': {'actor': {'id': 35326208},
#     'created_at': '2018-01-11T07:26:18Z',
#     'id': '7084540758',
#     'payload': {'commits': [{'message': 'Add files via upload'}]},
#     'repo': {'id': 117065133, 'name': 'AdhetyaPutra/PerancanganWeb'},
#     'type': 'PushEvent'},
#    '_type': 'data'},
#   {'_id': '7075372249',
#    '_index': 'github',
#    '_score': 0.9999813,
#    '_source': {'actor': {'id': 22060658},
#     'created_at': '2018-01-09T14:46:45Z',
#     'id': '7075372249',
#     'payload': {'commits': [{'message': 'Delete .gitignore~'}]},
#     'repo': {'id': 114273918, 'name': 'konopac/MovieListApp'},
#     'type': 'PushEvent'},
#    '_type': 'data'},
#   {'_id': '7153856956',
#    '_index': 'github',
#    '_score': 0.9999813,
#    '_source': {'actor': {'id': 3455798},
#     'created_at': '2018-01-26T04:36:20Z',
#     'id': '7153856956',
#     'repo': {'id': 94298220, 'name': 'alibaba/react-intl-universal'},
#     'type': 'IssueCommentEvent'},
#    '_type': 'data'},
#   {'_id': '7087899765',
#    '_index': 'github',
#    '_score': 0.9999813,
#    '_source': {'actor': {'id': 13518195},
#     'created_at': '2018-01-11T19:29:18Z',
#     'id': '7087899765',
#     'repo': {'id': 116836845, 'name': 'DavidJonDiana/sugar-rush'},
#     'type': 'PullRequestEvent'},
#    '_type': 'data'},
#   {'_id': '7102407328',
#    '_index': 'github',
#    '_score': 0.9999813,
#    '_source': {'actor': {'id': 7333583},
#     'created_at': '2018-01-15T22:05:47Z',
#     'id': '7102407328',
#     'repo': {'id': 117598844, 'name': 'hytung/hytung.github.io'},
#     'type': 'PullRequestEvent'},
#    '_type': 'data'},
#   {'_id': '7108038101',
#    '_index': 'github',
#    '_score': 0.9999813,
#    '_source': {'actor': {'id': 10270330},
#     'created_at': '2018-01-16T22:13:22Z',
#     'id': '7108038101',
#     'payload': {'commits': [{'message': 'Update'}]},
#     'repo': {'id': 114691623, 'name': 'yuchingho/university'},
#     'type': 'PushEvent'},
#    '_type': 'data'},
#   {'_id': '7124365308',
#    '_index': 'github',
#    '_score': 0.9999813,
#    '_source': {'actor': {'id': 7640693},
#     'created_at': '2018-01-19T18:36:19Z',
#     'id': '7124365308',
#     'repo': {'id': 118163451,
#      'name': 'ngesa254/Digital-Outputs-with-Rainbow-Hat-LEDs'},
#     'type': 'CreateEvent'},
#    '_type': 'data'},
#   {'_id': '7114498455',
#    '_index': 'github',
#    '_score': 0.9999813,
#    '_source': {'actor': {'id': 28941271},
#     'created_at': '2018-01-18T01:04:09Z',
#     'id': '7114498455',
#     'repo': {'id': 109101070, 'name': 'ouzhrm/useGithubByDeveloper'},
#     'type': 'WatchEvent'},
#    '_type': 'data'},
#   {'_id': '7125413948',
#    '_index': 'github',
#    '_score': 0.9999813,
#    '_source': {'actor': {'id': 32054652},
#     'created_at': '2018-01-19T22:55:54Z',
#     'id': '7125413948',
#     'payload': {'commits': [{'message': 'Update documentation'}]},
#     'repo': {'id': 117305331, 'name': 'VizRI/vizri.github.io'},
#     'type': 'PushEvent'},
#    '_type': 'data'},
#   {'_id': '5153807691',
#    '_index': 'github',
#    '_score': 0.9999813,
#    '_source': {'actor': {'id': 160078},
#     'created_at': '2017-01-14T16:14:08Z',
#     'id': '5153807691',
#     'payload': {'commits': [{'message': 'Minor fix.'}]},
#     'repo': {'id': 72878106, 'name': 'brettkromkamp/story_engine'},
#     'type': 'PushEvent'},
#    '_type': 'data'},
#   {'_id': '7128250760',
#    '_index': 'github',
#    '_score': 0.9999813,
#    '_source': {'actor': {'id': 17859844},
#     'created_at': '2018-01-21T09:36:03Z',
#     'id': '7128250760',
#     'repo': {'id': 76328745, 'name': 'mananapr/dotfiles'},
#     'type': 'WatchEvent'},
#    '_type': 'data'},
#   {'_id': '7146991256',
#    '_index': 'github',
#    '_score': 0.9999813,
#    '_source': {'actor': {'id': 25781788},
#     'created_at': '2018-01-24T22:35:53Z',
#     'id': '7146991256',
#     'payload': {'commits': [{'message': 'fixed layout problem temporarly until more style changes made'},
#       {'message': 'changes to the css and the color pattern of the website'}]},
#     'repo': {'id': 118637698, 'name': 'ErikaDib/SmartCheckoutProject'},
#     'type': 'PushEvent'},
#    '_type': 'data'},
#   {'_id': '7141142014',
#    '_index': 'github',
#    '_score': 0.9999813,
#    '_source': {'actor': {'id': 4700817},
#     'created_at': '2018-01-23T23:08:18Z',
#     'id': '7141142014',
#     'payload': {'commits': [{'message': 'adds name'}]},
#     'repo': {'id': 78133698, 'name': 'hbahamonde/Comparative_Politics_UGRAD'},
#     'type': 'PushEvent'},
#    '_type': 'data'},
#   {'_id': '7142362995',
#    '_index': 'github',
#    '_score': 0.9999813,
#    '_source': {'actor': {'id': 3425702},
#     'created_at': '2018-01-24T06:20:25Z',
#     'id': '7142362995',
#     'repo': {'id': 3100121, 'name': 'nwjs/nw.js'},
#     'type': 'WatchEvent'},
#    '_type': 'data'},
#   {'_id': '7137226663',
#    '_index': 'github',
#    '_score': 0.9999813,
#    '_source': {'actor': {'id': 9041370},
#     'created_at': '2018-01-23T10:15:37Z',
#     'id': '7137226663',
#     'payload': {'commits': [{'message': 'Add issue template'},
#       {'message': 'Add pull request template'},
#       {'message': 'Merge pull request #1 from dan1elhughes/feature/github-template-integration\n\nGitHub template integration'}]},
#     'repo': {'id': 118454607, 'name': 'HeathWallace/ethereum-pos'},
#     'type': 'PushEvent'},
#    '_type': 'data'},
#   {'_id': '7148250330',
#    '_index': 'github',
#    '_score': 0.9999813,
#    '_source': {'actor': {'id': 35626411},
#     'created_at': '2018-01-25T05:45:16Z',
#     'id': '7148250330',
#     'repo': {'id': 118866564, 'name': 'RashikaMishra95/DemoNode'},
#     'type': 'PullRequestEvent'},
#    '_type': 'data'},
#   {'_id': '7163337145',
#    '_index': 'github',
#    '_score': 0.9999813,
#    '_source': {'actor': {'id': 15681491},
#     'created_at': '2018-01-29T06:48:21Z',
#     'id': '7163337145',
#     'payload': {'commits': [{'message': '简单的restful服务'}]},
#     'repo': {'id': 119325090, 'name': 'yejunyu/spring-boot-practise2'},
#     'type': 'PushEvent'},
#    '_type': 'data'},
#   {'_id': '7152898861',
#    '_index': 'github',
#    '_score': 0.9999813,
#    '_source': {'actor': {'id': 1255037},
#     'created_at': '2018-01-25T22:48:52Z',
#     'id': '7152898861',
#     'repo': {'id': 1377159, 'name': 'coq/coq'},
#     'type': 'IssueCommentEvent'},
#    '_type': 'data'},
#   {'_id': '7156236348',
#    '_index': 'github',
#    '_score': 0.9999813,
#    '_source': {'actor': {'id': 4370550},
#     'created_at': '2018-01-26T15:39:50Z',
#     'id': '7156236348',
#     'repo': {'id': 1257084, 'name': 'dlang/phobos'},
#     'type': 'PullRequestEvent'},
#    '_type': 'data'},
#   {'_id': '7158579262',
#    '_index': 'github',
#    '_score': 0.9999813,
#    '_source': {'actor': {'id': 8337409},
#     'created_at': '2018-01-27T02:03:11Z',
#     'id': '7158579262',
#     'repo': {'id': 119123533, 'name': 'deikatsuo/btc-id'},
#     'type': 'CreateEvent'},
#    '_type': 'data'},
#   {'_id': '5149621270',
#    '_index': 'github',
#    '_score': 0.9999813,
#    '_source': {'actor': {'id': 10059507},
#     'created_at': '2017-01-13T15:19:28Z',
#     'id': '5149621270',
#     'payload': {'commits': [{'message': 'Update manifest.jps'}]},
#     'repo': {'id': 78859254, 'name': 'yulchitaj/lets-encrypt'},
#     'type': 'PushEvent'},
#    '_type': 'data'},
#   {'_id': '5152154709',
#    '_index': 'github',
#    '_score': 0.9999813,
#    '_source': {'actor': {'id': 20230450},
#     'created_at': '2017-01-13T23:50:42Z',
#     'id': '5152154709',
#     'payload': {'commits': [{'message': 'Update README.md'}]},
#     'repo': {'id': 78525453, 'name': 'MrHDR/Sun-Moon_ShinyCalc'},
#     'type': 'PushEvent'},
#    '_type': 'data'},
#   {'_id': '7161074494',
#    '_index': 'github',
#    '_score': 0.9999813,
#    '_source': {'actor': {'id': 158862},
#     'created_at': '2018-01-28T09:46:42Z',
#     'id': '7161074494',
#     'repo': {'id': 110998941, 'name': 'arlac77/local-repository-provider'},
#     'type': 'DeleteEvent'},
#    '_type': 'data'},
#   {'_id': '7159982723',
#    '_index': 'github',
#    '_score': 0.9999813,
#    '_source': {'actor': {'id': 1589480},
#     'created_at': '2018-01-27T19:29:22Z',
#     'id': '7159982723',
#     'payload': {'commits': [{'message': 'ranger: fix homepage'},
#       {'message': 'ranger: update 1.8.1 bottle.'}]},
#     'repo': {'id': 53493223, 'name': 'BrewTestBot/homebrew-core'},
#     'type': 'PushEvent'},
#    '_type': 'data'},
#   {'_id': '7166732586',
#    '_index': 'github',
#    '_score': 0.9999813,
#    '_source': {'actor': {'id': 323385},
#     'created_at': '2018-01-29T18:10:50Z',
#     'id': '7166732586',
#     'payload': {'commits': [{'message': 'Revert "Release of eeacms/apache-eea-www:5.0"\n\nThis reverts commit fb59357534a9ab31fad98f78783152c7e17b2dc2.'},
#       {'message': 'Revert "Prepare for release of eeacms/apache-eea-www:5.0"\n\nThis reverts commit 3f9d10842f75dd75229549b7fc93d1128f4c8cf4.'}]},
#     'repo': {'id': 48365759, 'name': 'eea/eea.rancher.catalog'},
#     'type': 'PushEvent'},
#    '_type': 'data'},
#   {'_id': '7168766803',
#    '_index': 'github',
#    '_score': 0.9999813,
#    '_source': {'actor': {'id': 8546787},
#     'created_at': '2018-01-30T02:17:24Z',
#     'id': '7168766803',
#     'payload': {'commits': [{'message': 'key now must be one of the cache names'}]},
#     'repo': {'id': 101675455, 'name': 'databio/shinyLOLA'},
#     'type': 'PushEvent'},
#    '_type': 'data'},
#   {'_id': '7164274927',
#    '_index': 'github',
#    '_score': 0.9999813,
#    '_source': {'actor': {'id': 29216624},
#     'created_at': '2018-01-29T10:38:43Z',
#     'id': '7164274927',
#     'repo': {'id': 114521849, 'name': 'Mouris1/SpotterProps'},
#     'type': 'IssuesEvent'},
#    '_type': 'data'},
#   {'_id': '7166101979',
#    '_index': 'github',
#    '_score': 0.9999813,
#    '_source': {'actor': {'id': 8078968},
#     'created_at': '2018-01-29T16:16:20Z',
#     'id': '7166101979',
#     'payload': {'comment': {'commit_id': '9558dc9e1507e7fcc83d1de0010c41fb31970c5c'}},
#     'repo': {'id': 858127, 'name': 'pandas-dev/pandas'},
#     'type': 'PullRequestReviewCommentEvent'},
#    '_type': 'data'},
#   {'_id': '5166516586',
#    '_index': 'github',
#    '_score': 0.9999813,
#    '_source': {'actor': {'id': 8770962},
#     'created_at': '2017-01-17T16:24:46Z',
#     'id': '5166516586',
#     'repo': {'id': 5427753, 'name': 'unitedstates/python-us'},
#     'type': 'IssuesEvent'},
#    '_type': 'data'},
#   {'_id': '7180970111',
#    '_index': 'github',
#    '_score': 0.9999813,
#    '_source': {'actor': {'id': 18696528},
#     'created_at': '2018-02-01T02:04:05Z',
#     'id': '7180970111',
#     'repo': {'id': 113098524, 'name': 'DufourVictor/openannuaire'},
#     'type': 'PullRequestEvent'},
#    '_type': 'data'},
#   {'_id': '5116764190',
#    '_index': 'github',
#    '_score': 0.9999803,
#    '_source': {'actor': {'id': 1175888},
#     'created_at': '2017-01-07T08:10:17Z',
#     'id': '5116764190',
#     'repo': {'id': 24656814, 'name': 'elyase/geotext'},
#     'type': 'IssueCommentEvent'},
#    '_type': 'data'},
#   {'_id': '7058403913',
#    '_index': 'github',
#    '_score': 0.9999803,
#    '_source': {'actor': {'id': 22189186},
#     'created_at': '2018-01-04T20:14:23Z',
#     'id': '7058403913',
#     'payload': {'commits': [{'message': 'Изменены параметры теней текста и блока'},
#       {'message': 'Создана структура и настроены стили для шапки сайта с помощью flexbox'},
#       {'message': 'Скрытие панели поиска при малых разрешениях'},
#       {'message': 'Добавлены альтернативные цвета'}]},
#     'repo': {'id': 114562496, 'name': 'dimavz/dev_proj'},
#     'type': 'PushEvent'},
#    '_type': 'data'},
#   {'_id': '7064921198',
#    '_index': 'github',
#    '_score': 0.9999803,
#    '_source': {'actor': {'id': 32674674},
#     'created_at': '2018-01-06T13:45:03Z',
#     'id': '7064921198',
#     'payload': {'commits': [{'message': 'Update Census special variable'}]},
#     'repo': {'id': 106039066, 'name': 'NYCPlanning/labs-nyc-factfinder'},
#     'type': 'PushEvent'},
#    '_type': 'data'},
#   {'_id': '7071741771',
#    '_index': 'github',
#    '_score': 0.9999803,
#    '_source': {'actor': {'id': 3019665},
#     'created_at': '2018-01-08T21:15:09Z',
#     'id': '7071741771',
#     'payload': {'commits': [{'message': 'Provide option to publish releases to GitHub\n\nIn order to upload artifacts, we need a preexisting release on GitHub.\nThat release can be a prerelease or not. So provide an option in the\n`release.py` script to publish a prerelease or a final release. In\norder to make this work smoothly with pushing and handle changing the\nrelease type, allow the remote to be specified independently of whether\nto push or not.\n\n[skip appveyor]\n[appveyor skip]'},
#       {'message': 'Pass `--tag` to `release.py` tests\n\nNow that `--tag` must be explicitly passed (due to the GitHub release\npublishing process), add that to the CircleCI tests.\n\n[skip appveyor]\n[appveyor skip]'},
#       {'message': 'Merge pull request #26 from jakirkham/release_publish_gh\n\nPublish GitHub Release'}]},
#     'repo': {'id': 115889434, 'name': 'jakirkham/miniforge'},
#     'type': 'PushEvent'},
#    '_type': 'data'},
#   {'_id': '7100265967',
#    '_index': 'github',
#    '_score': 0.9999803,
#    '_source': {'actor': {'id': 17463361},
#     'created_at': '2018-01-15T13:34:17Z',
#     'id': '7100265967',
#     'repo': {'id': 50881110, 'name': 'aimacode/aima-python'},
#     'type': 'IssueCommentEvent'},
#    '_type': 'data'},
#   {'_id': '7091666141',
#    '_index': 'github',
#    '_score': 0.9999803,
#    '_source': {'actor': {'id': 30829071},
#     'created_at': '2018-01-12T13:58:56Z',
#     'id': '7091666141',
#     'payload': {'commits': [{'message': 'first chapter'}]},
#     'repo': {'id': 117092761, 'name': 'PanMartinez/Django_Tut'},
#     'type': 'PushEvent'},
#    '_type': 'data'}],
#  'max_score': 0.9999999,
#  'total': 48898125}

# %%
type(xres3['hits']['hits'])
xres3['hits']['hits']
# Out:
# [{'_id': '7067358132',
#   '_index': 'github',
#   '_score': 0.9999999,
#   '_source': {'actor': {'id': 29607371},
#    'created_at': '2018-01-07T22:04:35Z',
#    'id': '7067358132',
#    'payload': {'commits': [{'message': 'visage moyen en cours'},
#      {'message': 'visage moyen marche'}]},
#    'repo': {'id': 114908151, 'name': 'Hellyon/Faceties'},
#    'type': 'PushEvent'},
#   '_type': 'data'},
#  {'_id': '5113737188',
#   '_index': 'github',
#   '_score': 0.9999999,
#   '_source': {'actor': {'id': 8656788},
#    'created_at': '2017-01-06T16:14:38Z',
#    'id': '5113737188',
#    'payload': {'commits': [{'message': 'BFS with level tracking working'}]},
#    'repo': {'id': 78219720, 'name': 'KevinDalleau/graph2vec'},
#    'type': 'PushEvent'},
#   '_type': 'data'},
#  {'_id': '5122428165',
#   '_index': 'github',
#   '_score': 0.9999999,
#   '_source': {'actor': {'id': 19617700},
#    'created_at': '2017-01-09T13:28:37Z',
#    'id': '5122428165',
#    'repo': {'id': 45979262, 'name': 'MichaelRow/Lyrics'},
#    'type': 'WatchEvent'},
#   '_type': 'data'},
#  {'_id': '7071338041',
#   '_index': 'github',
#   '_score': 0.9999999,
#   '_source': {'actor': {'id': 17437789},
#    'created_at': '2018-01-08T19:39:51Z',
#    'id': '7071338041',
#    'payload': {'commits': [{'message': 'lcl_progress to global'}]},
#    'repo': {'id': 88505824, 'name': 'christianguenter2/abapGit'},
#    'type': 'PushEvent'},
#   '_type': 'data'},
#  {'_id': '7097961580',
#   '_index': 'github',
#   '_score': 0.9999999,
#   '_source': {'actor': {'id': 2705860},
#    'created_at': '2018-01-15T01:07:07Z',
#    'id': '7097961580',
#    'repo': {'id': 109106298,
#     'name': 'matteocng/storybook-fetch-messages-task-example'},
#    'type': 'DeleteEvent'},
#   '_type': 'data'},
#  {'_id': '7095116372',
#   '_index': 'github',
#   '_score': 0.9999999,
#   '_source': {'actor': {'id': 380816},
#    'created_at': '2018-01-13T13:15:11Z',
#    'id': '7095116372',
#    'repo': {'id': 95909196, 'name': 'em-casa/re-frontend'},
#    'type': 'DeleteEvent'},
#   '_type': 'data'},
#  {'_id': '7082982095',
#   '_index': 'github',
#   '_score': 0.9999999,
#   '_source': {'actor': {'id': 29139614},
#    'created_at': '2018-01-10T22:09:58Z',
#    'id': '7082982095',
#    'payload': {'commits': [{'message': 'chore(deps): update dependency tslint to v5.9.0'}]},
#    'repo': {'id': 92611177, 'name': 'ikatyang/tsconfig-extends'},
#    'type': 'PushEvent'},
#   '_type': 'data'},
#  {'_id': '7076559875',
#   '_index': 'github',
#   '_score': 0.9999999,
#   '_source': {'actor': {'id': 123951},
#    'created_at': '2018-01-09T18:37:32Z',
#    'id': '7076559875',
#    'payload': {'commits': [{'message': 'Mirroring from Micro.blog.'}]},
#    'repo': {'id': 98114596, 'name': 'adamprocter/microblog'},
#    'type': 'PushEvent'},
#   '_type': 'data'},
#  {'_id': '7160719216',
#   '_index': 'github',
#   '_score': 0.9999999,
#   '_source': {'actor': {'id': 4778485},
#    'created_at': '2018-01-28T04:35:36Z',
#    'id': '7160719216',
#    'repo': {'id': 18928344, 'name': 'thelinmichael/spotify-web-api-java'},
#    'type': 'ReleaseEvent'},
#   '_type': 'data'},
#  {'_id': '7089617330',
#   '_index': 'github',
#   '_score': 0.9999999,
#   '_source': {'actor': {'id': 33857496},
#    'created_at': '2018-01-12T03:56:48Z',
#    'id': '7089617330',
#    'payload': {'commits': [{'message': 'Made changes'},
#      {'message': "Merge remote-tracking branch 'origin/master'\n\n# Conflicts:\n#\tapp/src/main/java/com/agro/agrocrm/util/URLRequest.java"}]},
#    'repo': {'id': 115075610, 'name': 'gwilliam187/agro-crm-app'},
#    'type': 'PushEvent'},
#   '_type': 'data'},
#  {'_id': '7103218980',
#   '_index': 'github',
#   '_score': 0.9999999,
#   '_source': {'actor': {'id': 30585466},
#    'created_at': '2018-01-16T03:24:30Z',
#    'id': '7103218980',
#    'payload': {'commits': [{'message': 'タイムオブジェクト削除\n落ちるブロックの「ステージ５ボスを倒したときに初期位置に瞬時に戻す」仕様を「倒したとき、ブロックを初期位置まで上昇させる」仕様に変更しました。'}]},
#    'repo': {'id': 98849727, 'name': 'TsudaD/teamcreate'},
#    'type': 'PushEvent'},
#   '_type': 'data'},
#  {'_id': '7111309903',
#   '_index': 'github',
#   '_score': 0.9999999,
#   '_source': {'actor': {'id': 16133320},
#    'created_at': '2018-01-17T13:51:21Z',
#    'id': '7111309903',
#    'repo': {'id': 84476389, 'name': 'thejameskyle/react-loadable'},
#    'type': 'WatchEvent'},
#   '_type': 'data'},
#  {'_id': '7119871132',
#   '_index': 'github',
#   '_score': 0.9999999,
#   '_source': {'actor': {'id': 1042445},
#    'created_at': '2018-01-18T22:27:01Z',
#    'id': '7119871132',
#    'repo': {'id': 118045683, 'name': 'arcVyas/jenkins-docs'},
#    'type': 'CreateEvent'},
#   '_type': 'data'},
#  {'_id': '7125771892',
#   '_index': 'github',
#   '_score': 0.9999999,
#   '_source': {'actor': {'id': 16934066},
#    'created_at': '2018-01-20T01:24:00Z',
#    'id': '7125771892',
#    'repo': {'id': 118197016, 'name': 'sieunkr/design-patterns'},
#    'type': 'CreateEvent'},
#   '_type': 'data'},
#  {'_id': '7127051203',
#   '_index': 'github',
#   '_score': 0.9999999,
#   '_source': {'actor': {'id': 31182295},
#    'created_at': '2018-01-20T17:24:21Z',
#    'id': '7127051203',
#    'payload': {'commits': [{'message': 'A'}]},
#    'repo': {'id': 107002666, 'name': 'plt-laboratory/plt'},
#    'type': 'PushEvent'},
#   '_type': 'data'},
#  {'_id': '7148948950',
#   '_index': 'github',
#   '_score': 0.9999999,
#   '_source': {'actor': {'id': 32764315},
#    'created_at': '2018-01-25T09:13:48Z',
#    'id': '7148948950',
#    'repo': {'id': 106801355, 'name': 'Smartling-test/test'},
#    'type': 'DeleteEvent'},
#   '_type': 'data'},
#  {'_id': '7139910034',
#   '_index': 'github',
#   '_score': 0.9999999,
#   '_source': {'actor': {'id': 28762106},
#    'created_at': '2018-01-23T18:49:39Z',
#    'id': '7139910034',
#    'repo': {'id': 92620036,
#     'name': 'dipper-github-lhr-yul-sfo-icn/test-python-sample'},
#    'type': 'CreateEvent'},
#   '_type': 'data'},
#  {'_id': '7137701292',
#   '_index': 'github',
#   '_score': 0.9999999,
#   '_source': {'actor': {'id': 686247},
#    'created_at': '2018-01-23T11:59:45Z',
#    'id': '7137701292',
#    'repo': {'id': 49767244, 'name': 'primefaces/primeng'},
#    'type': 'IssuesEvent'},
#   '_type': 'data'},
#  {'_id': '7153258707',
#   '_index': 'github',
#   '_score': 0.9999999,
#   '_source': {'actor': {'id': 307049},
#    'created_at': '2018-01-26T00:41:05Z',
#    'id': '7153258707',
#    'repo': {'id': 117670548, 'name': 'dotclear/clearbricks'},
#    'type': 'PushEvent'},
#   '_type': 'data'},
#  {'_id': '7169461196',
#   '_index': 'github',
#   '_score': 0.9999999,
#   '_source': {'actor': {'id': 17991461},
#    'created_at': '2018-01-30T06:36:10Z',
#    'id': '7169461196',
#    'payload': {'commits': [{'message': 'Added the read me file to the repo\n\nThis is just an template for the readme'}]},
#    'repo': {'id': 110939007, 'name': 'heshanpadmasiri/Robot-Controller'},
#    'type': 'PushEvent'},
#   '_type': 'data'},
#  {'_id': '5172466611',
#   '_index': 'github',
#   '_score': 0.9999999,
#   '_source': {'actor': {'id': 4216574},
#    'created_at': '2017-01-18T13:39:11Z',
#    'id': '5172466611',
#    'payload': {'commits': [{'message': '对于当前的贴图，边界限制应该是u重复，v限定。\n（以后自己实现mipmap的时候怎么办？）'}]},
#    'repo': {'id': 76718001, 'name': 'guozhaokui/threejspbr'},
#    'type': 'PushEvent'},
#   '_type': 'data'},
#  {'_id': '7169709731',
#   '_index': 'github',
#   '_score': 0.9999999,
#   '_source': {'actor': {'id': 9927080},
#    'created_at': '2018-01-30T07:51:21Z',
#    'id': '7169709731',
#    'repo': {'id': 27179591, 'name': 'T5750/poi'},
#    'type': 'CreateEvent'},
#   '_type': 'data'},
#  {'_id': '7165547760',
#   '_index': 'github',
#   '_score': 0.9999999,
#   '_source': {'actor': {'id': 51265},
#    'created_at': '2018-01-29T14:13:04Z',
#    'id': '7165547760',
#    'payload': {'comment': {'commit_id': '34af1ad9be9c6c369f7c57a21dd09c1648bc05f1'}},
#    'repo': {'id': 113197161, 'name': 'openshift/cluster-operator'},
#    'type': 'PullRequestReviewCommentEvent'},
#   '_type': 'data'},
#  {'_id': '7063563134',
#   '_index': 'github',
#   '_score': 0.99999946,
#   '_source': {'actor': {'id': 16723349},
#    'created_at': '2018-01-05T22:11:10Z',
#    'id': '7063563134',
#    'payload': {'commits': [{'message': 'Initial changes\n\nInitial changes.'}]},
#    'repo': {'id': 116416329, 'name': 'rulesninja/domain-modeler'},
#    'type': 'PushEvent'},
#   '_type': 'data'},
#  {'_id': '5118767513',
#   '_index': 'github',
#   '_score': 0.99999946,
#   '_source': {'actor': {'id': 23665947},
#    'created_at': '2017-01-08T10:33:59Z',
#    'id': '5118767513',
#    'payload': {'commits': [{'message': 'Remove materialize, add bootstrap'},
#      {'message': 'html markup index'},
#      {'message': 'Markup index.html'},
#      {'message': 'index.html working'},
#      {'message': 'Build test'},
#      {'message': 'Build test 2'},
#      {'message': 'gulpfile'},
#      {'message': 'Build task ready'}]},
#    'repo': {'id': 77447347, 'name': 'RamizIb/DeepAqua'},
#    'type': 'PushEvent'},
#   '_type': 'data'},
#  {'_id': '7064011467',
#   '_index': 'github',
#   '_score': 0.99999946,
#   '_source': {'actor': {'id': 14175800},
#    'created_at': '2018-01-06T01:08:08Z',
#    'id': '7064011467',
#    'payload': {'commits': [{'message': 'add test handback xliff files'}]},
#    'repo': {'id': 82270896,
#     'name': 'OpenLocalizationTestOrg/ol-test3-handback'},
#    'type': 'PushEvent'},
#   '_type': 'data'},
#  {'_id': '7068747454',
#   '_index': 'github',
#   '_score': 0.99999946,
#   '_source': {'actor': {'id': 3502741},
#    'created_at': '2018-01-08T09:53:40Z',
#    'id': '7068747454',
#    'repo': {'id': 116659139, 'name': 'erikll/consignment'},
#    'type': 'CreateEvent'},
#   '_type': 'data'},
#  {'_id': '7095994107',
#   '_index': 'github',
#   '_score': 0.99999946,
#   '_source': {'actor': {'id': 656739},
#    'created_at': '2018-01-13T23:38:49Z',
#    'id': '7095994107',
#    'repo': {'id': 112615188, 'name': 'project-cx/pbx-group-security'},
#    'type': 'IssueCommentEvent'},
#   '_type': 'data'},
#  {'_id': '7092773796',
#   '_index': 'github',
#   '_score': 0.99999946,
#   '_source': {'actor': {'id': 4711480},
#    'created_at': '2018-01-12T17:51:37Z',
#    'id': '7092773796',
#    'repo': {'id': 117128377, 'name': 'jakent/tree-of-life'},
#    'type': 'CreateEvent'},
#   '_type': 'data'},
#  {'_id': '7083127863',
#   '_index': 'github',
#   '_score': 0.99999946,
#   '_source': {'actor': {'id': 1686556},
#    'created_at': '2018-01-10T22:47:02Z',
#    'id': '7083127863',
#    'payload': {'commits': [{'message': 'directory restructure'}]},
#    'repo': {'id': 79676108, 'name': 'patrickkunka/tome'},
#    'type': 'PushEvent'},
#   '_type': 'data'},
#  {'_id': '7078617779',
#   '_index': 'github',
#   '_score': 0.99999946,
#   '_source': {'actor': {'id': 11293084},
#    'created_at': '2018-01-10T05:13:47Z',
#    'id': '7078617779',
#    'repo': {'id': 109843059, 'name': 'leusonmario/cron-utils'},
#    'type': 'CreateEvent'},
#   '_type': 'data'},
#  {'_id': '7177929788',
#   '_index': 'github',
#   '_score': 0.99999946,
#   '_source': {'actor': {'id': 12693984},
#    'created_at': '2018-01-31T15:07:51Z',
#    'id': '7177929788',
#    'payload': {'commits': [{'message': '200 OK http://wolesi.website/pve/showdoc.aspx?Id=1887'}]},
#    'repo': {'id': 42310621,
#     'name': 'everypolitician-scrapers/afghanistan-assembly'},
#    'type': 'PushEvent'},
#   '_type': 'data'},
#  {'_id': '7090790060',
#   '_index': 'github',
#   '_score': 0.99999946,
#   '_source': {'actor': {'id': 29726686},
#    'created_at': '2018-01-12T10:21:18Z',
#    'id': '7090790060',
#    'repo': {'id': 111383521, 'name': 'difi/jenkins-pipeline'},
#    'type': 'DeleteEvent'},
#   '_type': 'data'},
#  {'_id': '7106691800',
#   '_index': 'github',
#   '_score': 0.99999946,
#   '_source': {'actor': {'id': 313721},
#    'created_at': '2018-01-16T17:23:02Z',
#    'id': '7106691800',
#    'repo': {'id': 45061433, 'name': 'cmu-phil/tetrad'},
#    'type': 'IssueCommentEvent'},
#   '_type': 'data'},
#  {'_id': '7109095729',
#   '_index': 'github',
#   '_score': 0.99999946,
#   '_source': {'actor': {'id': 630673},
#    'created_at': '2018-01-17T03:56:40Z',
#    'id': '7109095729',
#    'payload': {'commits': [{'message': 'Update multiple files\n\nChange service to ContactSensor for doors and windows'},
#      {'message': 'Merge pull request #54 from schmittx/door-window-sensor-fix\n\nFix service for door and window sensors'},
#      {'message': 'Bumped version to 1.5.9'},
#      {'message': 'Remove deprecated services from cached accessories'},
#      {'message': 'Bumped version to 1.6.0'},
#      {'message': "Remove the Android app's Client ID and secret"},
#      {'message': 'Config is validated upon startup\n\nWill raise an error when when client_id or client_secret are missing'},
#      {'message': 'Update binary_switch.js\n\nAdded support for leakSMART valve by checking for state.opened.\nAdded config option for outlets and switches. Modified state.consumption (consumption only exists for Quirky Outlinks)'},
#      {'message': 'Added support for doorbell motion sensors'},
#      {'message': 'Updated dependencies'},
#      {'message': 'Bumped version to 1.7.0'},
#      {'message': 'Fixed #69'},
#      {'message': 'Bumped version to 1.7.1'},
#      {'message': 'Fixed typo in readme'},
#      {'message': 'Added a mention of Chamberlain MyQ® Home Bridge to README'},
#      {'message': 'Updated dependencies'},
#      {'message': 'Docs'},
#      {'message': 'Bumped version to 1.8.0'},
#      {'message': 'Fixed enums in sensor_pod.js'},
#      {'message': 'Added ability to expose binary switches as outlets or switches. Fixes #58'}]},
#    'repo': {'id': 106365403, 'name': 'schmittx/homebridge-wink3'},
#    'type': 'PushEvent'},
#   '_type': 'data'},
#  {'_id': '7118087577',
#   '_index': 'github',
#   '_score': 0.99999946,
#   '_source': {'actor': {'id': 32717724},
#    'created_at': '2018-01-18T16:21:08Z',
#    'id': '7118087577',
#    'payload': {'commits': [{'message': 'automatically backed up by learn'}]},
#    'repo': {'id': 118004785,
#     'name': 'jshwa/js-ajax-ajax-and-callbacks-lab-v-000'},
#    'type': 'PushEvent'},
#   '_type': 'data'},
#  {'_id': '7123383501',
#   '_index': 'github',
#   '_score': 0.99999946,
#   '_source': {'actor': {'id': 10077243},
#    'created_at': '2018-01-19T15:15:11Z',
#    'id': '7123383501',
#    'payload': {'commits': [{'message': ''}]},
#    'repo': {'id': 113460766, 'name': 'avtomon/PQFormBuilder'},
#    'type': 'PushEvent'},
#   '_type': 'data'},
#  {'_id': '7161943149',
#   '_index': 'github',
#   '_score': 0.99999946,
#   '_source': {'actor': {'id': 24826908},
#    'created_at': '2018-01-28T18:58:04Z',
#    'id': '7161943149',
#    'repo': {'id': 119279799, 'name': 'Plajer/Village_Defense'},
#    'type': 'CreateEvent'},
#   '_type': 'data'},
#  {'_id': '7127636020',
#   '_index': 'github',
#   '_score': 0.99999946,
#   '_source': {'actor': {'id': 8517910},
#    'created_at': '2018-01-21T00:06:58Z',
#    'id': '7127636020',
#    'repo': {'id': 46629356, 'name': 'Lombiq/Orchard-Scripting-Extensions-PHP'},
#    'type': 'PushEvent'},
#   '_type': 'data'},
#  {'_id': '7151376821',
#   '_index': 'github',
#   '_score': 0.99999946,
#   '_source': {'actor': {'id': 1282050},
#    'created_at': '2018-01-25T17:18:19Z',
#    'id': '7151376821',
#    'payload': {'commits': [{'message': 'Deployed c6a2c00 with MkDocs version: 0.17.2'}]},
#    'repo': {'id': 116691622, 'name': 'Yichuans/iucn-hand-over'},
#    'type': 'PushEvent'},
#   '_type': 'data'},
#  {'_id': '7140674334',
#   '_index': 'github',
#   '_score': 0.99999946,
#   '_source': {'actor': {'id': 4951803},
#    'created_at': '2018-01-23T21:25:05Z',
#    'id': '7140674334',
#    'repo': {'id': 80638907, 'name': 'birm/gh-funstats'},
#    'type': 'IssuesEvent'},
#   '_type': 'data'},
#  {'_id': '7130634606',
#   '_index': 'github',
#   '_score': 0.99999946,
#   '_source': {'actor': {'id': 13191938},
#    'created_at': '2018-01-22T07:44:55Z',
#    'id': '7130634606',
#    'payload': {'commits': [{'message': 'update'}]},
#    'repo': {'id': 118422266, 'name': 'mutex73/LeetCode'},
#    'type': 'PushEvent'},
#   '_type': 'data'},
#  {'_id': '7168151553',
#   '_index': 'github',
#   '_score': 0.99999946,
#   '_source': {'actor': {'id': 10729230},
#    'created_at': '2018-01-29T23:07:46Z',
#    'id': '7168151553',
#    'payload': {'commits': [{'message': 'automatically backed up by learn'}]},
#    'repo': {'id': 119306543,
#     'name': 'sherryptk/sinatra-fwitter-group-project-v-000'},
#    'type': 'PushEvent'},
#   '_type': 'data'},
#  {'_id': '5142971472',
#   '_index': 'github',
#   '_score': 0.99999946,
#   '_source': {'actor': {'id': 16478785},
#    'created_at': '2017-01-12T14:51:11Z',
#    'id': '5142971472',
#    'payload': {'commits': [{'message': 'Fix Upadate'},
#      {'message': 'FIX BUG'},
#      {'message': 'FIX REBASE ;)'},
#      {'message': 'add lib locally'},
#      {'message': 'Print CSV\n\nwith System.out.prinln'},
#      {'message': 'commit 1'},
#      {'message': 'Fix toString()\n\nfix toStirng()'},
#      {'message': 'dell lines'},
#      {'message': 'fix CSVtoObject \n\n;)'},
#      {'message': 'refresh ;)'}]},
#    'repo': {'id': 75382517, 'name': 'Bakhah/Godsavethebibine'},
#    'type': 'PushEvent'},
#   '_type': 'data'},
#  {'_id': '7163775771',
#   '_index': 'github',
#   '_score': 0.99999946,
#   '_source': {'actor': {'id': 35590162},
#    'created_at': '2018-01-29T08:54:18Z',
#    'id': '7163775771',
#    'repo': {'id': 118083636, 'name': 'unitydemo2/Docworks'},
#    'type': 'PushEvent'},
#   '_type': 'data'},
#  {'_id': '7173078026',
#   '_index': 'github',
#   '_score': 0.99999946,
#   '_source': {'actor': {'id': 233},
#    'created_at': '2018-01-30T18:45:21Z',
#    'id': '7173078026',
#    'payload': {'commits': [{'message': 'Resolve Haml 5 warnings (#2149)'}]},
#    'repo': {'id': 261943, 'name': 'middleman/middleman'},
#    'type': 'PushEvent'},
#   '_type': 'data'},
#  {'_id': '7162214909',
#   '_index': 'github',
#   '_score': 0.99999946,
#   '_source': {'actor': {'id': 16711277},
#    'created_at': '2018-01-28T21:35:52Z',
#    'id': '7162214909',
#    'payload': {'commits': [{'message': 'cleaning'}]},
#    'repo': {'id': 113304584, 'name': 'Sachka/Tolkienizer'},
#    'type': 'PushEvent'},
#   '_type': 'data'},
#  {'_id': '5173060005',
#   '_index': 'github',
#   '_score': 0.99999946,
#   '_source': {'actor': {'id': 13338419},
#    'created_at': '2017-01-18T15:12:54Z',
#    'id': '5173060005',
#    'repo': {'id': 79352018, 'name': 'Dezodev/verbose-pancake'},
#    'type': 'CreateEvent'},
#   '_type': 'data'},
#  {'_id': '5128228169',
#   '_index': 'github',
#   '_score': 0.9999993,
#   '_source': {'actor': {'id': 3624877},
#    'created_at': '2017-01-10T10:44:17Z',
#    'id': '5128228169',
#    'repo': {'id': 15348522, 'name': 'googleads/googleads-php-lib'},
#    'type': 'IssueCommentEvent'},
#   '_type': 'data'},
#  {'_id': '5127331197',
#   '_index': 'github',
#   '_score': 0.9999993,
#   '_source': {'actor': {'id': 22745312},
#    'created_at': '2017-01-10T07:16:48Z',
#    'id': '5127331197',
#    'repo': {'id': 78507943, 'name': 'RuoChen95/coursera-test'},
#    'type': 'CreateEvent'},
#   '_type': 'data'},
#  {'_id': '7060842488',
#   '_index': 'github',
#   '_score': 0.9999993,
#   '_source': {'actor': {'id': 4701338},
#    'created_at': '2018-01-05T10:33:36Z',
#    'id': '7060842488',
#    'repo': {'id': 15634981, 'name': 'godotengine/godot'},
#    'type': 'IssueCommentEvent'},
#   '_type': 'data'},
#  {'_id': '5120547590',
#   '_index': 'github',
#   '_score': 0.9999993,
#   '_source': {'actor': {'id': 24231314},
#    'created_at': '2017-01-09T04:21:30Z',
#    'id': '5120547590',
#    'payload': {'commits': [{'message': 'tomo'}]},
#    'repo': {'id': 78305198, 'name': 'Bigsam82/prouno'},
#    'type': 'PushEvent'},
#   '_type': 'data'},
#  {'_id': '7070666318',
#   '_index': 'github',
#   '_score': 0.9999993,
#   '_source': {'actor': {'id': 14952196},
#    'created_at': '2018-01-08T17:06:40Z',
#    'id': '7070666318',
#    'repo': {'id': 116704123, 'name': 'orlov-dev/fenix'},
#    'type': 'CreateEvent'},
#   '_type': 'data'},
#  {'_id': '7100000214',
#   '_index': 'github',
#   '_score': 0.9999993,
#   '_source': {'actor': {'id': 33111559},
#    'created_at': '2018-01-15T12:32:49Z',
#    'id': '7100000214',
#    'payload': {'commits': [{'message': 'Site updated: 2018-01-15 12:32:39'}]},
#    'repo': {'id': 108649285, 'name': 'geyan666/geyan666.github.io'},
#    'type': 'PushEvent'},
#   '_type': 'data'},
#  {'_id': '7098922940',
#   '_index': 'github',
#   '_score': 0.9999993,
#   '_source': {'actor': {'id': 15936115},
#    'created_at': '2018-01-15T08:16:57Z',
#    'id': '7098922940',
#    'repo': {'id': 51924293,
#     'name': 'PHPfox-Official/phpfox-v4-feature-requests'},
#    'type': 'IssueCommentEvent'},
#   '_type': 'data'},
#  {'_id': '7095759880',
#   '_index': 'github',
#   '_score': 0.9999993,
#   '_source': {'actor': {'id': 418747},
#    'created_at': '2018-01-13T20:40:17Z',
#    'id': '7095759880',
#    'payload': {'commits': [{'message': 'Add Ruby code to create basic robots.txt file'}]},
#    'repo': {'id': 116636265, 'name': 'jbampton/charts'},
#    'type': 'PushEvent'},
#   '_type': 'data'},
#  {'_id': '7084458077',
#   '_index': 'github',
#   '_score': 0.9999993,
#   '_source': {'actor': {'id': 8517910},
#    'created_at': '2018-01-11T06:59:25Z',
#    'id': '7084458077',
#    'repo': {'id': 46566064, 'name': 'Lombiq/Combinator'},
#    'type': 'PushEvent'},
#   '_type': 'data'},
#  {'_id': '7074719354',
#   '_index': 'github',
#   '_score': 0.9999993,
#   '_source': {'actor': {'id': 3455449},
#    'created_at': '2018-01-09T12:27:28Z',
#    'id': '7074719354',
#    'repo': {'id': 92093628, 'name': 'Didstopia/SDL'},
#    'type': 'PushEvent'},
#   '_type': 'data'},
#  {'_id': '7162430479',
#   '_index': 'github',
#   '_score': 0.9999993,
#   '_source': {'actor': {'id': 363388},
#    'created_at': '2018-01-28T23:45:30Z',
#    'id': '7162430479',
#    'repo': {'id': 118678476, 'name': 'SomethingWithHorizons/mailserver'},
#    'type': 'GollumEvent'},
#   '_type': 'data'},
#  {'_id': '5170566239',
#   '_index': 'github',
#   '_score': 0.9999993,
#   '_source': {'actor': {'id': 979929},
#    'created_at': '2017-01-18T06:54:45Z',
#    'id': '5170566239',
#    'repo': {'id': 26677107, 'name': 'jedireza/hapi-node-postgres'},
#    'type': 'PullRequestEvent'},
#   '_type': 'data'},
#  {'_id': '7088921209',
#   '_index': 'github',
#   '_score': 0.9999993,
#   '_source': {'actor': {'id': 16406727},
#    'created_at': '2018-01-11T23:34:06Z',
#    'id': '7088921209',
#    'repo': {'id': 49035474, 'name': 'NOAA-PMEL/LAS'},
#    'type': 'IssueCommentEvent'},
#   '_type': 'data'},
#  {'_id': '7101450645',
#   '_index': 'github',
#   '_score': 0.9999993,
#   '_source': {'actor': {'id': 5014119},
#    'created_at': '2018-01-15T17:33:29Z',
#    'id': '7101450645',
#    'payload': {'commits': [{'message': 'I18n: Update translation uk (100%).\n\n28 translated messages.\n\nTransifex (https://www.transifex.com/xfce/public/).'}]},
#    'repo': {'id': 28493731, 'name': 'xfce-mirror/xfce4-verve-plugin'},
#    'type': 'PushEvent'},
#   '_type': 'data'},
#  {'_id': '7111049746',
#   '_index': 'github',
#   '_score': 0.9999993,
#   '_source': {'actor': {'id': 2412177},
#    'created_at': '2018-01-17T12:58:13Z',
#    'id': '7111049746',
#    'repo': {'id': 104457964,
#     'name': 'loevgaard/dandomain-foundation-entities'},
#    'type': 'CreateEvent'},
#   '_type': 'data'},
#  {'_id': '7114129327',
#   '_index': 'github',
#   '_score': 0.9999993,
#   '_source': {'actor': {'id': 1288694},
#    'created_at': '2018-01-17T23:05:16Z',
#    'id': '7114129327',
#    'payload': {'commits': [{'message': '2.1.1'},
#      {'message': 'Prepare next development version'}]},
#    'repo': {'id': 115447167, 'name': 'wKovacs64/meetup-raffle-web'},
#    'type': 'PushEvent'},
#   '_type': 'data'},
#  {'_id': '7124694839',
#   '_index': 'github',
#   '_score': 0.9999993,
#   '_source': {'actor': {'id': 32944990},
#    'created_at': '2018-01-19T19:52:16Z',
#    'id': '7124694839',
#    'repo': {'id': 118171210, 'name': 'AbhirajSidhu/hello-world'},
#    'type': 'CreateEvent'},
#   '_type': 'data'},
#  {'_id': '7126631465',
#   '_index': 'github',
#   '_score': 0.9999993,
#   '_source': {'actor': {'id': 5219415},
#    'created_at': '2018-01-20T12:48:30Z',
#    'id': '7126631465',
#    'payload': {'commits': [{'message': '📦 Game Update 20.01.2018 (3.3 MB)'}]},
#    'repo': {'id': 52203133, 'name': 'frk1/hazedumper'},
#    'type': 'PushEvent'},
#   '_type': 'data'},
#  {'_id': '7152392745',
#   '_index': 'github',
#   '_score': 0.9999993,
#   '_source': {'actor': {'id': 29377728},
#    'created_at': '2018-01-25T20:52:18Z',
#    'id': '7152392745',
#    'payload': {'commits': [{'message': 'added home page table'}]},
#    'repo': {'id': 118670262, 'name': 'landonwshields/sla-db'},
#    'type': 'PushEvent'},
#   '_type': 'data'},
#  {'_id': '7143570966',
#   '_index': 'github',
#   '_score': 0.9999993,
#   '_source': {'actor': {'id': 7017740},
#    'created_at': '2018-01-24T11:16:10Z',
#    'id': '7143570966',
#    'payload': {'commits': [{'message': 'Rename carrot-cake.md to _my_recipes/carrot-cake.md'}]},
#    'repo': {'id': 89935632, 'name': 'trianglegirl/recipes'},
#    'type': 'PushEvent'},
#   '_type': 'data'},
#  {'_id': '7131475372',
#   '_index': 'github',
#   '_score': 0.9999993,
#   '_source': {'actor': {'id': 3446885},
#    'created_at': '2018-01-22T11:07:45Z',
#    'id': '7131475372',
#    'repo': {'id': 18780056, 'name': 'xxorde/librekinect'},
#    'type': 'WatchEvent'},
#   '_type': 'data'},
#  {'_id': '5147405214',
#   '_index': 'github',
#   '_score': 0.9999993,
#   '_source': {'actor': {'id': 111481},
#    'created_at': '2017-01-13T07:05:49Z',
#    'id': '5147405214',
#    'repo': {'id': 72848828, 'name': 'xorock/zend-service-recaptcha-v2'},
#    'type': 'IssueCommentEvent'},
#   '_type': 'data'},
#  {'_id': '5155803176',
#   '_index': 'github',
#   '_score': 0.9999993,
#   '_source': {'actor': {'id': 810762},
#    'created_at': '2017-01-15T16:36:03Z',
#    'id': '5155803176',
#    'repo': {'id': 12084976, 'name': 'modesttree/Zenject'},
#    'type': 'IssueCommentEvent'},
#   '_type': 'data'},
#  {'_id': '7170598465',
#   '_index': 'github',
#   '_score': 0.9999993,
#   '_source': {'actor': {'id': 33541658},
#    'created_at': '2018-01-30T11:00:05Z',
#    'id': '7170598465',
#    'repo': {'id': 112326848, 'name': 'Community-Tech/admin'},
#    'type': 'IssueCommentEvent'},
#   '_type': 'data'},
#  {'_id': '5161735839',
#   '_index': 'github',
#   '_score': 0.9999993,
#   '_source': {'actor': {'id': 16896769},
#    'created_at': '2017-01-16T21:26:28Z',
#    'id': '5161735839',
#    'payload': {'commits': [{'message': 'Add all commit'}]},
#    'repo': {'id': 50422059,
#     'name': 'FGtatsuroWork3/TestForStaticFileSharing2'},
#    'type': 'PushEvent'},
#   '_type': 'data'},
#  {'_id': '7179854114',
#   '_index': 'github',
#   '_score': 0.9999993,
#   '_source': {'actor': {'id': 11655766},
#    'created_at': '2018-01-31T21:07:47Z',
#    'id': '7179854114',
#    'repo': {'id': 107575570, 'name': 'blackbaud/skyux-lib-testing'},
#    'type': 'PullRequestEvent'},
#   '_type': 'data'},
#  {'_id': '7066176087',
#   '_index': 'github',
#   '_score': 0.999999,
#   '_source': {'actor': {'id': 35184566},
#    'created_at': '2018-01-07T07:18:32Z',
#    'id': '7066176087',
#    'payload': {'commits': [{'message': 'commit'}]},
#    'repo': {'id': 116545082, 'name': 'qxdys6bm/qxdys6bm.github.io'},
#    'type': 'PushEvent'},
#   '_type': 'data'},
#  {'_id': '7060348209',
#   '_index': 'github',
#   '_score': 0.999999,
#   '_source': {'actor': {'id': 275871},
#    'created_at': '2018-01-05T08:18:28Z',
#    'id': '7060348209',
#    'repo': {'id': 27193779, 'name': 'nodejs/node'},
#    'type': 'IssueCommentEvent'},
#   '_type': 'data'},
#  {'_id': '5119713653',
#   '_index': 'github',
#   '_score': 0.999999,
#   '_source': {'actor': {'id': 16382930},
#    'created_at': '2017-01-08T20:36:44Z',
#    'id': '5119713653',
#    'payload': {'commits': [{'message': 'debug'}]},
#    'repo': {'id': 70310108, 'name': 'fpasquer/21sh'},
#    'type': 'PushEvent'},
#   '_type': 'data'},
#  {'_id': '7072869978',
#   '_index': 'github',
#   '_score': 0.999999,
#   '_source': {'actor': {'id': 35247092},
#    'created_at': '2018-01-09T03:16:38Z',
#    'id': '7072869978',
#    'repo': {'id': 116759712, 'name': 'ljs6874521/HelloWord'},
#    'type': 'CreateEvent'},
#   '_type': 'data'},
#  {'_id': '7097512499',
#   '_index': 'github',
#   '_score': 0.999999,
#   '_source': {'actor': {'id': 17279765},
#    'created_at': '2018-01-14T20:06:11Z',
#    'id': '7097512499',
#    'repo': {'id': 50256891, 'name': 'pret/pokeruby'},
#    'type': 'PullRequestEvent'},
#   '_type': 'data'},
#  {'_id': '7094051840',
#   '_index': 'github',
#   '_score': 0.999999,
#   '_source': {'actor': {'id': 28762106},
#    'created_at': '2018-01-12T23:30:21Z',
#    'id': '7094051840',
#    'repo': {'id': 92620036,
#     'name': 'dipper-github-lhr-yul-sfo-icn/test-python-sample'},
#    'type': 'CreateEvent'},
#   '_type': 'data'},
#  {'_id': '7079771879',
#   '_index': 'github',
#   '_score': 0.999999,
#   '_source': {'actor': {'id': 28945567},
#    'created_at': '2018-01-10T10:53:45Z',
#    'id': '7079771879',
#    'repo': {'id': 116944189, 'name': 'kammavamsi/sample-react-application'},
#    'type': 'CreateEvent'},
#   '_type': 'data'},
#  {'_id': '7074394700',
#   '_index': 'github',
#   '_score': 0.999999,
#   '_source': {'actor': {'id': 123951},
#    'created_at': '2018-01-09T11:07:12Z',
#    'id': '7074394700',
#    'payload': {'commits': [{'message': 'Mirroring from Micro.blog.'}]},
#    'repo': {'id': 98114596, 'name': 'adamprocter/microblog'},
#    'type': 'PushEvent'},
#   '_type': 'data'},
#  {'_id': '5142236250',
#   '_index': 'github',
#   '_score': 0.999999,
#   '_source': {'actor': {'id': 17688012},
#    'created_at': '2017-01-12T12:37:25Z',
#    'id': '5142236250',
#    'repo': {'id': 51830024, 'name': 'popcorn-official/popcorn-desktop'},
#    'type': 'IssueCommentEvent'},
#   '_type': 'data'},
#  {'_id': '7086997101',
#   '_index': 'github',
#   '_score': 0.999999,
#   '_source': {'actor': {'id': 35341807},
#    'created_at': '2018-01-11T16:25:52Z',
#    'id': '7086997101',
#    'repo': {'id': 117123930, 'name': 'sheminaz/DemoTest'},
#    'type': 'CreateEvent'},
#   '_type': 'data'},
#  {'_id': '7101638565',
#   '_index': 'github',
#   '_score': 0.999999,
#   '_source': {'actor': {'id': 7769313},
#    'created_at': '2018-01-15T18:23:44Z',
#    'id': '7101638565',
#    'payload': {'commits': [{'message': 'placeholder for queue name for htcondor'}]},
#    'repo': {'id': 86180687, 'name': 'TGAC/grassroots-core'},
#    'type': 'PushEvent'},
#   '_type': 'data'},
#  {'_id': '7109947378',
#   '_index': 'github',
#   '_score': 0.999999,
#   '_source': {'actor': {'id': 35522968},
#    'created_at': '2018-01-17T08:54:24Z',
#    'id': '7109947378',
#    'repo': {'id': 117810494, 'name': 'yzwia/vision'},
#    'type': 'CreateEvent'},
#   '_type': 'data'},
#  {'_id': '7116249922',
#   '_index': 'github',
#   '_score': 0.999999,
#   '_source': {'actor': {'id': 207405},
#    'created_at': '2018-01-18T10:19:57Z',
#    'id': '7116249922',
#    'payload': {'commits': [{'message': 'auto publish 2018-01-18 10:19:54+00:00'}]},
#    'repo': {'id': 36236297, 'name': 'sagemath/planet'},
#    'type': 'PushEvent'},
#   '_type': 'data'},
#  {'_id': '7122313398',
#   '_index': 'github',
#   '_score': 0.999999,
#   '_source': {'actor': {'id': 9824023},
#    'created_at': '2018-01-19T11:16:35Z',
#    'id': '7122313398',
#    'payload': {'commits': [{'message': 'sql: Disable asserts for release builds\n\nMacro SQLITE_DEBUG was set unconditionally, so both release build\nmodes had debugging enabled, including all asserts() and TESTCASE().\nMove this macro definition under check if mode is Debug and fix all\nwarning which arised after disabling asserts().\nMost of them are unused variables.'},
#      {'message': 'sql: Enable asserts for box/sql.c\n\nSince asserts were always disbled in src/box/sql.c, number\nof issues were hidden. This patch enables asserts for mentioned\nfile by disabling set of NDEBUG in box/src/sqliteInt.h.\nAlso this patch fixes incorrect assertions about strlen() and\nassertion that fieldno should always be less than format->field_count.\nThis assert is not always hold, e.g. for _schema space where max_id\nis stored behind formatted fields.\n\nCloses #3057'}]},
#    'repo': {'id': 911980, 'name': 'tarantool/tarantool'},
#    'type': 'PushEvent'},
#   '_type': 'data'},
#  {'_id': '7161160056',
#   '_index': 'github',
#   '_score': 0.999999,
#   '_source': {'actor': {'id': 2992398},
#    'created_at': '2018-01-28T10:53:12Z',
#    'id': '7161160056',
#    'payload': {'commits': [{'message': 'Ajout forRoot'}]},
#    'repo': {'id': 112198184, 'name': 'Agesse/NGAgesse'},
#    'type': 'PushEvent'},
#   '_type': 'data'},
#  {'_id': '7128370422',
#   '_index': 'github',
#   '_score': 0.999999,
#   '_source': {'actor': {'id': 19528094},
#    'created_at': '2018-01-21T11:12:32Z',
#    'id': '7128370422',
#    'payload': {'commits': [{'message': 'Update data.json'}]},
#    'repo': {'id': 59465493, 'name': 'shenzhouzd/update'},
#    'type': 'PushEvent'},
#   '_type': 'data'},
#  {'_id': '7145312263',
#   '_index': 'github',
#   '_score': 0.999999,
#   '_source': {'actor': {'id': 35577041},
#    'created_at': '2018-01-24T16:50:12Z',
#    'id': '7145312263',
#    'payload': {'commits': [{'message': 'Update index.html'}]},
#    'repo': {'id': 118027131, 'name': 'Jmb1922/jmb1922.github.io'},
#    'type': 'PushEvent'},
#   '_type': 'data'},
#  {'_id': '5131817850',
#   '_index': 'github',
#   '_score': 0.999999,
#   '_source': {'actor': {'id': 19152466},
#    'created_at': '2017-01-10T21:09:38Z',
#    'id': '5131817850',
#    'payload': {'commits': [{'message': 'Final ver.'}]},
#    'repo': {'id': 78215780, 'name': 'catSalem/KPI-Files'},
#    'type': 'PushEvent'},
#   '_type': 'data'},
#  {'_id': '7142247221',
#   '_index': 'github',
#   '_score': 0.999999,
#   '_source': {'actor': {'id': 23658480},
#    'created_at': '2018-01-24T05:36:51Z',
#    'id': '7142247221',
#    'payload': {'commits': [{'message': 'small change'}]},
#    'repo': {'id': 117473450, 'name': 'Yujia-Wang/yujia-wang.github.io'},
#    'type': 'PushEvent'},
#   '_type': 'data'},
#  {'_id': '7136107484',
#   '_index': 'github',
#   '_score': 0.999999,
#   '_source': {'actor': {'id': 22823376},
#    'created_at': '2018-01-23T05:04:59Z',
#    'id': '7136107484',
#    'payload': {'commits': [{'message': 'Add measurement measurements/circuit/2018-01-23T05:04:58.084289.json.'}]},
#    'repo': {'id': 70839104, 'name': 'StanfordLegion/perf-data'},
#    'type': 'PushEvent'},
#   '_type': 'data'},
#  {'_id': '5134491342',
#   '_index': 'github',
#   '_score': 0.999999,
#   '_source': {'actor': {'id': 4760551},
#    'created_at': '2017-01-11T09:12:22Z',
#    'id': '5134491342',
#    'payload': {'commits': [{'message': "- fixed the railgun's spiral duration was set incorrectly."}]},
#    'repo': {'id': 10879376, 'name': 'coelckers/gzdoom'},
#    'type': 'PushEvent'},
#   '_type': 'data'},
#  {'_id': '7163076261',
#   '_index': 'github',
#   '_score': 0.999999,
#   '_source': {'actor': {'id': 35910504},
#    'created_at': '2018-01-29T05:05:16Z',
#    'id': '7163076261',
#    'repo': {'id': 119334060, 'name': 'linhtetpaing9/hello-world'},
#    'type': 'CreateEvent'},
#   '_type': 'data'},
#  {'_id': '5139262258',
#   '_index': 'github',
#   '_score': 0.999999,
#   '_source': {'actor': {'id': 1504464},
#    'created_at': '2017-01-11T23:10:39Z',
#    'id': '5139262258',
#    'payload': {'commits': [{'message': 'brats/brats-staticfile-edge build 8 unclaiming: edge-1.buildpacks.ci'}]},
#    'repo': {'id': 34543204, 'name': 'cloudfoundry/buildpacks-ci'},
#    'type': 'PushEvent'},
#   '_type': 'data'},
#  {'_id': '5145933966',
#   '_index': 'github',
#   '_score': 0.999999,
#   '_source': {'actor': {'id': 2874596},
#    'created_at': '2017-01-12T23:06:16Z',
#    'id': '5145933966',
#    'payload': {'commits': [{'message': 'Update README.md'}]},
#    'repo': {'id': 78784569, 'name': 'pablovilla83/do-cdmx-nginx'},
#    'type': 'PushEvent'},
#   '_type': 'data'},
#  {'_id': '5143181206',
#   '_index': 'github',
#   '_score': 0.999999,
#   '_source': {'actor': {'id': 20407524},
#    'created_at': '2017-01-12T15:22:46Z',
#    'id': '5143181206',
#    'repo': {'id': 20580498, 'name': 'kubernetes/kubernetes'},
#    'type': 'IssueCommentEvent'},
#   '_type': 'data'},
#  {'_id': '7159005846',
#   '_index': 'github',
#   '_score': 0.999999,
#   '_source': {'actor': {'id': 14920103},
#    'created_at': '2018-01-27T07:52:56Z',
#    'id': '7159005846',
#    'payload': {'commits': [{'message': '获取用户信息接口修改'}]},
#    'repo': {'id': 115163628, 'name': 'Andy-Yin/XinDaSchoolAPI'},
#    'type': 'PushEvent'},
#   '_type': 'data'},
#  {'_id': '7160312662',
#   '_index': 'github',
#   '_score': 0.999999,
#   '_source': {'actor': {'id': 3906539},
#    'created_at': '2018-01-27T22:59:39Z',
#    'id': '7160312662',
#    'repo': {'id': 42519441, 'name': 'chiuan/TTUIFramework'},
#    'type': 'WatchEvent'},
#   '_type': 'data'},
#  {'_id': '7161308379',
#   '_index': 'github',
#   '_score': 0.999999,
#   '_source': {'actor': {'id': 35888182},
#    'created_at': '2018-01-28T12:40:16Z',
#    'id': '7161308379',
#    'repo': {'id': 119257070, 'name': 'yusuke-j0728/sample'},
#    'type': 'CreateEvent'},
#   '_type': 'data'},
#  {'_id': '5150807757',
#   '_index': 'github',
#   '_score': 0.999999,
#   '_source': {'actor': {'id': 11401319},
#    'created_at': '2017-01-13T19:06:22Z',
#    'id': '5150807757',
#    'payload': {'commits': [{'message': 'uploading project'}]},
#    'repo': {'id': 78876321, 'name': 'stone-pagamentos/demo-sdk-android'},
#    'type': 'PushEvent'},
#   '_type': 'data'},
#  {'_id': '7166842610',
#   '_index': 'github',
#   '_score': 0.999999,
#   '_source': {'actor': {'id': 5539247},
#    'created_at': '2018-01-29T18:33:11Z',
#    'id': '7166842610',
#    'payload': {'commits': [{'message': 'Removed .DS_Store file from repository'}]},
#    'repo': {'id': 108033929, 'name': 'jdelcastillo1/Pythium_Pop'},
#    'type': 'PushEvent'},
#   '_type': 'data'},
#  {'_id': '5162998187',
#   '_index': 'github',
#   '_score': 0.999999,
#   '_source': {'actor': {'id': 24291069},
#    'created_at': '2017-01-17T03:58:21Z',
#    'id': '5162998187',
#    'payload': {'commits': [{'message': 'Update huanxingtu.html'}]},
#    'repo': {'id': 77388549, 'name': 'likailun6/likailun6.github.io'},
#    'type': 'PushEvent'},
#   '_type': 'data'},
#  {'_id': '5154983935',
#   '_index': 'github',
#   '_score': 0.999999,
#   '_source': {'actor': {'id': 1060},
#    'created_at': '2017-01-15T06:45:29Z',
#    'id': '5154983935',
#    'repo': {'id': 46619651, 'name': 'librariesio/sentinel'},
#    'type': 'IssuesEvent'},
#   '_type': 'data'},
#  {'_id': '5172629697',
#   '_index': 'github',
#   '_score': 0.999999,
#   '_source': {'actor': {'id': 431261},
#    'created_at': '2017-01-18T14:07:21Z',
#    'id': '5172629697',
#    'repo': {'id': 17143026, 'name': 'jarcoal/httpmock'},
#    'type': 'MemberEvent'},
#   '_type': 'data'},
#  {'_id': '7174712747',
#   '_index': 'github',
#   '_score': 0.999999,
#   '_source': {'actor': {'id': 33104488},
#    'created_at': '2018-01-31T01:03:14Z',
#    'id': '7174712747',
#    'repo': {'id': 108593869,
#     'name': 'dipper-github-fra-sin-syd-nrt/test-python-sample'},
#    'type': 'CreateEvent'},
#   '_type': 'data'},
#  {'_id': '5177467656',
#   '_index': 'github',
#   '_score': 0.999999,
#   '_source': {'actor': {'id': 2328242},
#    'created_at': '2017-01-19T06:14:01Z',
#    'id': '5177467656',
#    'payload': {'comment': {'commit_id': 'df5752f03030a5e03cfc4c74c5914abb59ea42da'}},
#    'repo': {'id': 57415761, 'name': 'gereeter/crossbeam'},
#    'type': 'PullRequestReviewCommentEvent'},
#   '_type': 'data'},
#  {'_id': '7065861304',
#   '_index': 'github',
#   '_score': 0.99999887,
#   '_source': {'actor': {'id': 5384588},
#    'created_at': '2018-01-07T02:03:17Z',
#    'id': '7065861304',
#    'repo': {'id': 98467418, 'name': 'google-test/signcla-probe-repo'},
#    'type': 'IssueCommentEvent'},
#   '_type': 'data'},
#  {'_id': '7062015788',
#   '_index': 'github',
#   '_score': 0.99999887,
#   '_source': {'actor': {'id': 536803},
#    'created_at': '2018-01-05T15:41:16Z',
#    'id': '7062015788',
#    'repo': {'id': 17803236, 'name': 'ncw/rclone'},
#    'type': 'IssuesEvent'},
#   '_type': 'data'},
#  {'_id': '5120619939',
#   '_index': 'github',
#   '_score': 0.99999887,
#   '_source': {'actor': {'id': 24999509},
#    'created_at': '2017-01-09T04:59:44Z',
#    'id': '5120619939',
#    'repo': {'id': 78395316, 'name': 'ItsRaw/ExoticBans'},
#    'type': 'CreateEvent'},
#   '_type': 'data'},
#  {'_id': '7068805513',
#   '_index': 'github',
#   '_score': 0.99999887,
#   '_source': {'actor': {'id': 8314092},
#    'created_at': '2018-01-08T10:07:58Z',
#    'id': '7068805513',
#    'payload': {'commits': [{'message': 'Updated: archive.md'}]},
#    'repo': {'id': 109661188, 'name': 'unconfigured/unconfigured.github.io'},
#    'type': 'PushEvent'},
#   '_type': 'data'},
#  {'_id': '7096235012',
#   '_index': 'github',
#   '_score': 0.99999887,
#   '_source': {'actor': {'id': 13212452},
#    'created_at': '2018-01-14T03:31:03Z',
#    'id': '7096235012',
#    'payload': {'commits': [{'message': 'attempt at css'},
#      {'message': "Merge remote-tracking branch 'refs/remotes/origin/master'"},
#      {'message': 'actual success at css'}]},
#    'repo': {'id': 117327898, 'name': 'Noodlebrain/parent-to-parent'},
#    'type': 'PushEvent'},
#   '_type': 'data'},
#  {'_id': '7092500669',
#   '_index': 'github',
#   '_score': 0.99999887,
#   '_source': {'actor': {'id': 2394803},
#    'created_at': '2018-01-12T16:47:26Z',
#    'id': '7092500669',
#    'repo': {'id': 99376350, 'name': 'fcaldas/fcaldas.github.com'},
#    'type': 'CreateEvent'},
#   '_type': 'data'},
#  {'_id': '7083741044',
#   '_index': 'github',
#   '_score': 0.99999887,
#   '_source': {'actor': {'id': 7055107},
#    'created_at': '2018-01-11T02:09:26Z',
#    'id': '7083741044',
#    'repo': {'id': 117037099, 'name': 'fanybook/Nestjs30Days'},
#    'type': 'WatchEvent'},
#   '_type': 'data'},
#  {'_id': '7079035151',
#   '_index': 'github',
#   '_score': 0.99999887,
#   '_source': {'actor': {'id': 17794532},
#    'created_at': '2018-01-10T07:49:52Z',
#    'id': '7079035151',
#    'repo': {'id': 116924730, 'name': 'maisya/pro_monitoring'},
#    'type': 'ForkEvent'},
#   '_type': 'data'},
#  {'_id': '5171532919',
#   '_index': 'github',
#   '_score': 0.99999887,
#   '_source': {'actor': {'id': 15478059},
#    'created_at': '2017-01-18T10:38:02Z',
#    'id': '5171532919',
#    'payload': {'commits': [{'message': 'TenderProcessTest as Base class'},
#      {'message': 'create Base classes for import'}]},
#    'repo': {'id': 79254723, 'name': 'yarsanich/openprocurement.api'},
#    'type': 'PushEvent'},
#   '_type': 'data'},
#  {'_id': '7090857027',
#   '_index': 'github',
#   '_score': 0.99999887,
#   '_source': {'actor': {'id': 18685509},
#    'created_at': '2018-01-12T10:36:08Z',
#    'id': '7090857027',
#    'payload': {'commits': [{'message': 'Compile C plugins'}]},
#    'repo': {'id': 117227863, 'name': 'GBedenko/Opspack-Template-Test'},
#    'type': 'PushEvent'},
#   '_type': 'data'},
#  {'_id': '7107010696',
#   '_index': 'github',
#   '_score': 0.99999887,
#   '_source': {'actor': {'id': 7308528},
#    'created_at': '2018-01-16T18:28:01Z',
#    'id': '7107010696',
#    'repo': {'id': 4095811, 'name': 'Hexxeh/rpi-firmware'},
#    'type': 'IssueCommentEvent'},
#   '_type': 'data'},
#  {'_id': '7108924975',
#   '_index': 'github',
#   '_score': 0.99999887,
#   '_source': {'actor': {'id': 6749661},
#    'created_at': '2018-01-17T02:51:36Z',
#    'id': '7108924975',
#    'payload': {'commits': [{'message': 'test commit'}]},
#    'repo': {'id': 73416557, 'name': 'test987987/test14'},
#    'type': 'PushEvent'},
#   '_type': 'data'},
#  {'_id': '7117636049',
#   '_index': 'github',
#   '_score': 0.99999887,
#   '_source': {'actor': {'id': 1262548},
#    'created_at': '2018-01-18T15:07:44Z',
#    'id': '7117636049',
#    'repo': {'id': 105260268, 'name': 'doudz/pyqtdeploy'},
#    'type': 'PushEvent'},
#   '_type': 'data'},
#  {'_id': '7123247235',
#   '_index': 'github',
#   '_score': 0.99999887,
#   '_source': {'actor': {'id': 3929002},
#    'created_at': '2018-01-19T14:50:51Z',
#    'id': '7123247235',
#    'payload': {'commits': [{'message': 'Adjusted consensus construction method'}]},
#    'repo': {'id': 96222552, 'name': 'Feathergunner/DebruijnGraphBuilder'},
#    'type': 'PushEvent'},
#   '_type': 'data'},
#  {'_id': '5154487741',
#   '_index': 'github',
#   '_score': 0.99999887,
#   '_source': {'actor': {'id': 16198293},
#    'created_at': '2017-01-14T23:29:34Z',
#    'id': '5154487741',
#    'payload': {'commits': [{'message': 'Added new file'}]},
#    'repo': {'id': 67168356, 'name': 'cf-container-networking/toque-stats'},
#    'type': 'PushEvent'},
#   '_type': 'data'},
#  {'_id': '7126520078',
#   '_index': 'github',
#   '_score': 0.99999887,
#   '_source': {'actor': {'id': 8517910},
#    'created_at': '2018-01-20T11:22:50Z',
#    'id': '7126520078',
#    'repo': {'id': 46595756,
#     'name': 'Lombiq/Combinator-CoffeeScript-Preprocessor'},
#    'type': 'PushEvent'},
#   '_type': 'data'},
#  {'_id': '7151441106',
#   '_index': 'github',
#   '_score': 0.99999887,
#   '_source': {'actor': {'id': 12717194},
#    'created_at': '2018-01-25T17:31:12Z',
#    'id': '7151441106',
#    'payload': {'commits': [{'message': 'Add missing params'}]},
#    'repo': {'id': 114301229, 'name': 'rackerlabs/cc-api-tests'},
#    'type': 'PushEvent'},
#   '_type': 'data'},
#  {'_id': '7140948577',
#   '_index': 'github',
#   '_score': 0.99999887,
#   '_source': {'actor': {'id': 21337531},
#    'created_at': '2018-01-23T22:23:09Z',
#    'id': '7140948577',
#    'payload': {'commits': [{'message': 'Update.'}]},
#    'repo': {'id': 118677515, 'name': 'csapersson/Firebase-with-Node'},
#    'type': 'PushEvent'},
#   '_type': 'data'},
#  {'_id': '7131128487',
#   '_index': 'github',
#   '_score': 0.99999887,
#   '_source': {'actor': {'id': 15829493},
#    'created_at': '2018-01-22T09:52:37Z',
#    'id': '7131128487',
#    'repo': {'id': 116167731, 'name': 'yuzu-emu/yuzu'},
#    'type': 'WatchEvent'},
#   '_type': 'data'},
#  {'_id': '7167709828',
#   '_index': 'github',
#   '_score': 0.99999887,
#   '_source': {'actor': {'id': 35590162},
#    'created_at': '2018-01-29T21:29:56Z',
#    'id': '7167709828',
#    'repo': {'id': 118083636, 'name': 'unitydemo2/Docworks'},
#    'type': 'PushEvent'},
#   '_type': 'data'},
#  {'_id': '5146906274',
#   '_index': 'github',
#   '_score': 0.99999887,
#   '_source': {'actor': {'id': 4001789},
#    'created_at': '2017-01-13T03:48:59Z',
#    'id': '5146906274',
#    'payload': {'commits': [{'message': 'Update coverage from 4.2 to 4.3'},
#      {'message': 'Merge pull request #87 from aio-libs/pyup-update-coverage-4.2-to-4.3\n\nUpdate coverage to 4.3'},
#      {'message': 'Update coverage from 4.3 to 4.3.1'},
#      {'message': 'ensure requests to verify ssl by verify value of client'},
#      {'message': 'Merge pull request #91 from sunghyunzz/master\n\nfix endpoint to pass verify argument to aiohttp connector'},
#      {'message': 'Merge pull request #89 from aio-libs/pyup-update-coverage-4.3-to-4.3.1\n\nUpdate coverage to 4.3.1'},
#      {'message': "Merge remote-tracking branch 'aio-libs/master'"}]},
#    'repo': {'id': 76943116, 'name': 'vharitonsky/aiobotocore'},
#    'type': 'PushEvent'},
#   '_type': 'data'},
#  {'_id': '5155532871',
#   '_index': 'github',
#   '_score': 0.99999887,
#   '_source': {'actor': {'id': 12096477},
#    'created_at': '2017-01-15T13:55:59Z',
#    'id': '5155532871',
#    'repo': {'id': 34507229, 'name': 'oknosoft/windowbuilder'},
#    'type': 'GollumEvent'},
#   '_type': 'data'},
#  {'_id': '7173434486',
#   '_index': 'github',
#   '_score': 0.99999887,
#   '_source': {'actor': {'id': 19914705},
#    'created_at': '2018-01-30T19:55:52Z',
#    'id': '7173434486',
#    'repo': {'id': 52027975, 'name': 'mongodb/docs-bi-connector'},
#    'type': 'PullRequestEvent'},
#   '_type': 'data'},
#  {'_id': '5154698002',
#   '_index': 'github',
#   '_score': 0.99999887,
#   '_source': {'actor': {'id': 4210342},
#    'created_at': '2017-01-15T02:20:45Z',
#    'id': '5154698002',
#    'payload': {'commits': [{'message': 'Revamp auto-completion logic'}]},
#    'repo': {'id': 77369463, 'name': 'James-Yu/LaTeX-Workshop'},
#    'type': 'PushEvent'},
#   '_type': 'data'},
#  {'_id': '5173510943',
#   '_index': 'github',
#   '_score': 0.99999887,
#   '_source': {'actor': {'id': 25062122},
#    'created_at': '2017-01-18T16:15:33Z',
#    'id': '5173510943',
#    'repo': {'id': 79358253, 'name': 'lucasmschy/AgencyXRef'},
#    'type': 'CreateEvent'},
#   '_type': 'data'},
#  {'_id': '7065070781',
#   '_index': 'github',
#   '_score': 0.9999986,
#   '_source': {'actor': {'id': 16819916},
#    'created_at': '2018-01-06T15:36:59Z',
#    'id': '7065070781',
#    'payload': {'commits': [{'message': '...'}]},
#    'repo': {'id': 116478559, 'name': 'gongzhaopeng/spmia-unique'},
#    'type': 'PushEvent'},
#   '_type': 'data'},
#  {'_id': '7058718018',
#   '_index': 'github',
#   '_score': 0.9999986,
#   '_source': {'actor': {'id': 8517910},
#    'created_at': '2018-01-04T21:34:34Z',
#    'id': '7058718018',
#    'repo': {'id': 107332601, 'name': 'Lombiq/NGM.Favorite'},
#    'type': 'PushEvent'},
#   '_type': 'data'},
#  {'_id': '7068300736',
#   '_index': 'github',
#   '_score': 0.9999986,
#   '_source': {'actor': {'id': 2544108},
#    'created_at': '2018-01-08T07:34:53Z',
#    'id': '7068300736',
#    'repo': {'id': 86281053, 'name': 'third774/ng-bootstrap-form-validation'},
#    'type': 'IssuesEvent'},
#   '_type': 'data'},
#  {'_id': '7114018778',
#   '_index': 'github',
#   '_score': 0.9999986,
#   '_source': {'actor': {'id': 30142993},
#    'created_at': '2018-01-17T22:37:02Z',
#    'id': '7114018778',
#    'repo': {'id': 117901220, 'name': 'BEOSMO/Tp_Sir_Oslane'},
#    'type': 'CreateEvent'},
#   '_type': 'data'},
#  {'_id': '5138511655',
# ...
#   '_source': {'actor': {'id': 31295242},
#    'created_at': '2018-01-31T23:23:47Z',
#    'id': '7180459807',
#    'repo': {'id': 85220489, 'name': 'unicef/etools-partner-reporting-portal'},
#    'type': 'GollumEvent'},
#   '_type': 'data'},
#  {'_id': '5175574952',
#   '_index': 'github',
#   '_score': 0.99998176,
#   '_source': {'actor': {'id': 5438359},
#    'created_at': '2017-01-18T21:45:28Z',
#    'id': '5175574952',
#    'repo': {'id': 79366953, 'name': 'WhistleLabs/terraform-aws-openvpn'},
#    'type': 'DeleteEvent'},
#   '_type': 'data'},
#  {'_id': '7181685107',
#   '_index': 'github',
#   '_score': 0.99998176,
#   '_source': {'actor': {'id': 5545912},
#    'created_at': '2018-02-01T06:34:53Z',
#    'id': '7181685107',
#    'repo': {'id': 109123719,
#     'name': 'shenliuyang/appsugar-web-archetypes-kotlin'},
#    'type': 'CreateEvent'},
#   '_type': 'data'},
#  {'_id': '5123918997',
#   '_index': 'github',
#   '_score': 0.9999813,
#   '_source': {'actor': {'id': 15897474},
#    'created_at': '2017-01-09T17:35:19Z',
#    'id': '5123918997',
#    'payload': {'commits': [{'message': 'Added config file'}]},
#    'repo': {'id': 78452037, 'name': 'samanthamolnar/samanthamolnar.github.io'},
#    'type': 'PushEvent'},
#   '_type': 'data'},
#  {'_id': '7060092886',
#   '_index': 'github',
#   '_score': 0.9999813,
#   '_source': {'actor': {'id': 29476255},
#    'created_at': '2018-01-05T06:43:07Z',
#    'id': '7060092886',
#    'payload': {'commits': [{'message': 'test uterance'},
#      {'message': 'test utternace'}]},
#    'repo': {'id': 113029064, 'name': 'KenrickV-Hexaware/WakefieldPoC'},
#    'type': 'PushEvent'},
#   '_type': 'data'},
#  {'_id': '7063025028',
#   '_index': 'github',
#   '_score': 0.9999813,
#   '_source': {'actor': {'id': 3131232},
#    'created_at': '2018-01-05T19:42:23Z',
#    'id': '7063025028',
#    'repo': {'id': 12082924, 'name': 'dyve/django-bootstrap3'},
#    'type': 'WatchEvent'},
#   '_type': 'data'},
#  {'_id': '7072619326',
#   '_index': 'github',
#   '_score': 0.9999813,
#   '_source': {'actor': {'id': 12693984},
#    'created_at': '2018-01-09T01:41:09Z',
#    'id': '7072619326',
#    'payload': {'commits': [{'message': '200 OK http://wolesi.website/pve/showdoc.aspx?Id=1782'}]},
#    'repo': {'id': 42310621,
#     'name': 'everypolitician-scrapers/afghanistan-assembly'},
#    'type': 'PushEvent'},
#   '_type': 'data'},
#  {'_id': '7096848814',
#   '_index': 'github',
#   '_score': 0.9999813,
#   '_source': {'actor': {'id': 35422361},
#    'created_at': '2018-01-14T12:59:11Z',
#    'id': '7096848814',
#    'payload': {'commits': [{'message': '123\n\n123'}]},
#    'repo': {'id': 117428168, 'name': 'KeshaWarden/123'},
#    'type': 'PushEvent'},
#   '_type': 'data'},
#  {'_id': '7095596376',
#   '_index': 'github',
#   '_score': 0.9999813,
#   '_source': {'actor': {'id': 2511168},
#    'created_at': '2018-01-13T18:45:22Z',
#    'id': '7095596376',
#    'payload': {'commits': [{'message': 'GIT CloneShare Commit'}]},
#    'repo': {'id': 117347799, 'name': 'amaximus/JamesBond'},
#    'type': 'PushEvent'},
#   '_type': 'data'},
#  {'_id': '7084540758',
#   '_index': 'github',
#   '_score': 0.9999813,
#   '_source': {'actor': {'id': 35326208},
#    'created_at': '2018-01-11T07:26:18Z',
#    'id': '7084540758',
#    'payload': {'commits': [{'message': 'Add files via upload'}]},
#    'repo': {'id': 117065133, 'name': 'AdhetyaPutra/PerancanganWeb'},
#    'type': 'PushEvent'},
#   '_type': 'data'},
#  {'_id': '7075372249',
#   '_index': 'github',
#   '_score': 0.9999813,
#   '_source': {'actor': {'id': 22060658},
#    'created_at': '2018-01-09T14:46:45Z',
#    'id': '7075372249',
#    'payload': {'commits': [{'message': 'Delete .gitignore~'}]},
#    'repo': {'id': 114273918, 'name': 'konopac/MovieListApp'},
#    'type': 'PushEvent'},
#   '_type': 'data'},
#  {'_id': '7153856956',
#   '_index': 'github',
#   '_score': 0.9999813,
#   '_source': {'actor': {'id': 3455798},
#    'created_at': '2018-01-26T04:36:20Z',
#    'id': '7153856956',
#    'repo': {'id': 94298220, 'name': 'alibaba/react-intl-universal'},
#    'type': 'IssueCommentEvent'},
#   '_type': 'data'},
#  {'_id': '7087899765',
#   '_index': 'github',
#   '_score': 0.9999813,
#   '_source': {'actor': {'id': 13518195},
#    'created_at': '2018-01-11T19:29:18Z',
#    'id': '7087899765',
#    'repo': {'id': 116836845, 'name': 'DavidJonDiana/sugar-rush'},
#    'type': 'PullRequestEvent'},
#   '_type': 'data'},
#  {'_id': '7102407328',
#   '_index': 'github',
#   '_score': 0.9999813,
#   '_source': {'actor': {'id': 7333583},
#    'created_at': '2018-01-15T22:05:47Z',
#    'id': '7102407328',
#    'repo': {'id': 117598844, 'name': 'hytung/hytung.github.io'},
#    'type': 'PullRequestEvent'},
#   '_type': 'data'},
#  {'_id': '7108038101',
#   '_index': 'github',
#   '_score': 0.9999813,
#   '_source': {'actor': {'id': 10270330},
#    'created_at': '2018-01-16T22:13:22Z',
#    'id': '7108038101',
#    'payload': {'commits': [{'message': 'Update'}]},
#    'repo': {'id': 114691623, 'name': 'yuchingho/university'},
#    'type': 'PushEvent'},
#   '_type': 'data'},
#  {'_id': '7124365308',
#   '_index': 'github',
#   '_score': 0.9999813,
#   '_source': {'actor': {'id': 7640693},
#    'created_at': '2018-01-19T18:36:19Z',
#    'id': '7124365308',
#    'repo': {'id': 118163451,
#     'name': 'ngesa254/Digital-Outputs-with-Rainbow-Hat-LEDs'},
#    'type': 'CreateEvent'},
#   '_type': 'data'},
#  {'_id': '7114498455',
#   '_index': 'github',
#   '_score': 0.9999813,
#   '_source': {'actor': {'id': 28941271},
#    'created_at': '2018-01-18T01:04:09Z',
#    'id': '7114498455',
#    'repo': {'id': 109101070, 'name': 'ouzhrm/useGithubByDeveloper'},
#    'type': 'WatchEvent'},
#   '_type': 'data'},
#  {'_id': '7125413948',
#   '_index': 'github',
#   '_score': 0.9999813,
#   '_source': {'actor': {'id': 32054652},
#    'created_at': '2018-01-19T22:55:54Z',
#    'id': '7125413948',
#    'payload': {'commits': [{'message': 'Update documentation'}]},
#    'repo': {'id': 117305331, 'name': 'VizRI/vizri.github.io'},
#    'type': 'PushEvent'},
#   '_type': 'data'},
#  {'_id': '5153807691',
#   '_index': 'github',
#   '_score': 0.9999813,
#   '_source': {'actor': {'id': 160078},
#    'created_at': '2017-01-14T16:14:08Z',
#    'id': '5153807691',
#    'payload': {'commits': [{'message': 'Minor fix.'}]},
#    'repo': {'id': 72878106, 'name': 'brettkromkamp/story_engine'},
#    'type': 'PushEvent'},
#   '_type': 'data'},
#  {'_id': '7128250760',
#   '_index': 'github',
#   '_score': 0.9999813,
#   '_source': {'actor': {'id': 17859844},
#    'created_at': '2018-01-21T09:36:03Z',
#    'id': '7128250760',
#    'repo': {'id': 76328745, 'name': 'mananapr/dotfiles'},
#    'type': 'WatchEvent'},
#   '_type': 'data'},
#  {'_id': '7146991256',
#   '_index': 'github',
#   '_score': 0.9999813,
#   '_source': {'actor': {'id': 25781788},
#    'created_at': '2018-01-24T22:35:53Z',
#    'id': '7146991256',
#    'payload': {'commits': [{'message': 'fixed layout problem temporarly until more style changes made'},
#      {'message': 'changes to the css and the color pattern of the website'}]},
#    'repo': {'id': 118637698, 'name': 'ErikaDib/SmartCheckoutProject'},
#    'type': 'PushEvent'},
#   '_type': 'data'},
#  {'_id': '7141142014',
#   '_index': 'github',
#   '_score': 0.9999813,
#   '_source': {'actor': {'id': 4700817},
#    'created_at': '2018-01-23T23:08:18Z',
#    'id': '7141142014',
#    'payload': {'commits': [{'message': 'adds name'}]},
#    'repo': {'id': 78133698, 'name': 'hbahamonde/Comparative_Politics_UGRAD'},
#    'type': 'PushEvent'},
#   '_type': 'data'},
#  {'_id': '7142362995',
#   '_index': 'github',
#   '_score': 0.9999813,
#   '_source': {'actor': {'id': 3425702},
#    'created_at': '2018-01-24T06:20:25Z',
#    'id': '7142362995',
#    'repo': {'id': 3100121, 'name': 'nwjs/nw.js'},
#    'type': 'WatchEvent'},
#   '_type': 'data'},
#  {'_id': '7137226663',
#   '_index': 'github',
#   '_score': 0.9999813,
#   '_source': {'actor': {'id': 9041370},
#    'created_at': '2018-01-23T10:15:37Z',
#    'id': '7137226663',
#    'payload': {'commits': [{'message': 'Add issue template'},
#      {'message': 'Add pull request template'},
#      {'message': 'Merge pull request #1 from dan1elhughes/feature/github-template-integration\n\nGitHub template integration'}]},
#    'repo': {'id': 118454607, 'name': 'HeathWallace/ethereum-pos'},
#    'type': 'PushEvent'},
#   '_type': 'data'},
#  {'_id': '7148250330',
#   '_index': 'github',
#   '_score': 0.9999813,
#   '_source': {'actor': {'id': 35626411},
#    'created_at': '2018-01-25T05:45:16Z',
#    'id': '7148250330',
#    'repo': {'id': 118866564, 'name': 'RashikaMishra95/DemoNode'},
#    'type': 'PullRequestEvent'},
#   '_type': 'data'},
#  {'_id': '7163337145',
#   '_index': 'github',
#   '_score': 0.9999813,
#   '_source': {'actor': {'id': 15681491},
#    'created_at': '2018-01-29T06:48:21Z',
#    'id': '7163337145',
#    'payload': {'commits': [{'message': '简单的restful服务'}]},
#    'repo': {'id': 119325090, 'name': 'yejunyu/spring-boot-practise2'},
#    'type': 'PushEvent'},
#   '_type': 'data'},
#  {'_id': '7152898861',
#   '_index': 'github',
#   '_score': 0.9999813,
#   '_source': {'actor': {'id': 1255037},
#    'created_at': '2018-01-25T22:48:52Z',
#    'id': '7152898861',
#    'repo': {'id': 1377159, 'name': 'coq/coq'},
#    'type': 'IssueCommentEvent'},
#   '_type': 'data'},
#  {'_id': '7156236348',
#   '_index': 'github',
#   '_score': 0.9999813,
#   '_source': {'actor': {'id': 4370550},
#    'created_at': '2018-01-26T15:39:50Z',
#    'id': '7156236348',
#    'repo': {'id': 1257084, 'name': 'dlang/phobos'},
#    'type': 'PullRequestEvent'},
#   '_type': 'data'},
#  {'_id': '7158579262',
#   '_index': 'github',
#   '_score': 0.9999813,
#   '_source': {'actor': {'id': 8337409},
#    'created_at': '2018-01-27T02:03:11Z',
#    'id': '7158579262',
#    'repo': {'id': 119123533, 'name': 'deikatsuo/btc-id'},
#    'type': 'CreateEvent'},
#   '_type': 'data'},
#  {'_id': '5149621270',
#   '_index': 'github',
#   '_score': 0.9999813,
#   '_source': {'actor': {'id': 10059507},
#    'created_at': '2017-01-13T15:19:28Z',
#    'id': '5149621270',
#    'payload': {'commits': [{'message': 'Update manifest.jps'}]},
#    'repo': {'id': 78859254, 'name': 'yulchitaj/lets-encrypt'},
#    'type': 'PushEvent'},
#   '_type': 'data'},
#  {'_id': '5152154709',
#   '_index': 'github',
#   '_score': 0.9999813,
#   '_source': {'actor': {'id': 20230450},
#    'created_at': '2017-01-13T23:50:42Z',
#    'id': '5152154709',
#    'payload': {'commits': [{'message': 'Update README.md'}]},
#    'repo': {'id': 78525453, 'name': 'MrHDR/Sun-Moon_ShinyCalc'},
#    'type': 'PushEvent'},
#   '_type': 'data'},
#  {'_id': '7161074494',
#   '_index': 'github',
#   '_score': 0.9999813,
#   '_source': {'actor': {'id': 158862},
#    'created_at': '2018-01-28T09:46:42Z',
#    'id': '7161074494',
#    'repo': {'id': 110998941, 'name': 'arlac77/local-repository-provider'},
#    'type': 'DeleteEvent'},
#   '_type': 'data'},
#  {'_id': '7159982723',
#   '_index': 'github',
#   '_score': 0.9999813,
#   '_source': {'actor': {'id': 1589480},
#    'created_at': '2018-01-27T19:29:22Z',
#    'id': '7159982723',
#    'payload': {'commits': [{'message': 'ranger: fix homepage'},
#      {'message': 'ranger: update 1.8.1 bottle.'}]},
#    'repo': {'id': 53493223, 'name': 'BrewTestBot/homebrew-core'},
#    'type': 'PushEvent'},
#   '_type': 'data'},
#  {'_id': '7166732586',
#   '_index': 'github',
#   '_score': 0.9999813,
#   '_source': {'actor': {'id': 323385},
#    'created_at': '2018-01-29T18:10:50Z',
#    'id': '7166732586',
#    'payload': {'commits': [{'message': 'Revert "Release of eeacms/apache-eea-www:5.0"\n\nThis reverts commit fb59357534a9ab31fad98f78783152c7e17b2dc2.'},
#      {'message': 'Revert "Prepare for release of eeacms/apache-eea-www:5.0"\n\nThis reverts commit 3f9d10842f75dd75229549b7fc93d1128f4c8cf4.'}]},
#    'repo': {'id': 48365759, 'name': 'eea/eea.rancher.catalog'},
#    'type': 'PushEvent'},
#   '_type': 'data'},
#  {'_id': '7168766803',
#   '_index': 'github',
#   '_score': 0.9999813,
#   '_source': {'actor': {'id': 8546787},
#    'created_at': '2018-01-30T02:17:24Z',
#    'id': '7168766803',
#    'payload': {'commits': [{'message': 'key now must be one of the cache names'}]},
#    'repo': {'id': 101675455, 'name': 'databio/shinyLOLA'},
#    'type': 'PushEvent'},
#   '_type': 'data'},
#  {'_id': '7164274927',
#   '_index': 'github',
#   '_score': 0.9999813,
#   '_source': {'actor': {'id': 29216624},
#    'created_at': '2018-01-29T10:38:43Z',
#    'id': '7164274927',
#    'repo': {'id': 114521849, 'name': 'Mouris1/SpotterProps'},
#    'type': 'IssuesEvent'},
#   '_type': 'data'},
#  {'_id': '7166101979',
#   '_index': 'github',
#   '_score': 0.9999813,
#   '_source': {'actor': {'id': 8078968},
#    'created_at': '2018-01-29T16:16:20Z',
#    'id': '7166101979',
#    'payload': {'comment': {'commit_id': '9558dc9e1507e7fcc83d1de0010c41fb31970c5c'}},
#    'repo': {'id': 858127, 'name': 'pandas-dev/pandas'},
#    'type': 'PullRequestReviewCommentEvent'},
#   '_type': 'data'},
#  {'_id': '5166516586',
#   '_index': 'github',
#   '_score': 0.9999813,
#   '_source': {'actor': {'id': 8770962},
#    'created_at': '2017-01-17T16:24:46Z',
#    'id': '5166516586',
#    'repo': {'id': 5427753, 'name': 'unitedstates/python-us'},
#    'type': 'IssuesEvent'},
#   '_type': 'data'},
#  {'_id': '7180970111',
#   '_index': 'github',
#   '_score': 0.9999813,
#   '_source': {'actor': {'id': 18696528},
#    'created_at': '2018-02-01T02:04:05Z',
#    'id': '7180970111',
#    'repo': {'id': 113098524, 'name': 'DufourVictor/openannuaire'},
#    'type': 'PullRequestEvent'},
#   '_type': 'data'},
#  {'_id': '5116764190',
#   '_index': 'github',
#   '_score': 0.9999803,
#   '_source': {'actor': {'id': 1175888},
#    'created_at': '2017-01-07T08:10:17Z',
#    'id': '5116764190',
#    'repo': {'id': 24656814, 'name': 'elyase/geotext'},
#    'type': 'IssueCommentEvent'},
#   '_type': 'data'},
#  {'_id': '7058403913',
#   '_index': 'github',
#   '_score': 0.9999803,
#   '_source': {'actor': {'id': 22189186},
#    'created_at': '2018-01-04T20:14:23Z',
#    'id': '7058403913',
#    'payload': {'commits': [{'message': 'Изменены параметры теней текста и блока'},
#      {'message': 'Создана структура и настроены стили для шапки сайта с помощью flexbox'},
#      {'message': 'Скрытие панели поиска при малых разрешениях'},
#      {'message': 'Добавлены альтернативные цвета'}]},
#    'repo': {'id': 114562496, 'name': 'dimavz/dev_proj'},
#    'type': 'PushEvent'},
#   '_type': 'data'},
#  {'_id': '7064921198',
#   '_index': 'github',
#   '_score': 0.9999803,
#   '_source': {'actor': {'id': 32674674},
#    'created_at': '2018-01-06T13:45:03Z',
#    'id': '7064921198',
#    'payload': {'commits': [{'message': 'Update Census special variable'}]},
#    'repo': {'id': 106039066, 'name': 'NYCPlanning/labs-nyc-factfinder'},
#    'type': 'PushEvent'},
#   '_type': 'data'},
#  {'_id': '7071741771',
#   '_index': 'github',
#   '_score': 0.9999803,
#   '_source': {'actor': {'id': 3019665},
#    'created_at': '2018-01-08T21:15:09Z',
#    'id': '7071741771',
#    'payload': {'commits': [{'message': 'Provide option to publish releases to GitHub\n\nIn order to upload artifacts, we need a preexisting release on GitHub.\nThat release can be a prerelease or not. So provide an option in the\n`release.py` script to publish a prerelease or a final release. In\norder to make this work smoothly with pushing and handle changing the\nrelease type, allow the remote to be specified independently of whether\nto push or not.\n\n[skip appveyor]\n[appveyor skip]'},
#      {'message': 'Pass `--tag` to `release.py` tests\n\nNow that `--tag` must be explicitly passed (due to the GitHub release\npublishing process), add that to the CircleCI tests.\n\n[skip appveyor]\n[appveyor skip]'},
#      {'message': 'Merge pull request #26 from jakirkham/release_publish_gh\n\nPublish GitHub Release'}]},
#    'repo': {'id': 115889434, 'name': 'jakirkham/miniforge'},
#    'type': 'PushEvent'},
#   '_type': 'data'},
#  {'_id': '7100265967',
#   '_index': 'github',
#   '_score': 0.9999803,
#   '_source': {'actor': {'id': 17463361},
#    'created_at': '2018-01-15T13:34:17Z',
#    'id': '7100265967',
#    'repo': {'id': 50881110, 'name': 'aimacode/aima-python'},
#    'type': 'IssueCommentEvent'},
#   '_type': 'data'},
#  {'_id': '7091666141',
#   '_index': 'github',
#   '_score': 0.9999803,
#   '_source': {'actor': {'id': 30829071},
#    'created_at': '2018-01-12T13:58:56Z',
#    'id': '7091666141',
#    'payload': {'commits': [{'message': 'first chapter'}]},
#    'repo': {'id': 117092761, 'name': 'PanMartinez/Django_Tut'},
#    'type': 'PushEvent'},
#   '_type': 'data'}]

# %%
xdix = pd.io.json.json_normalize(xres3['hits']['hits'])

# %%
xdix=xdix.fillna('')

# %%
xdix
# Out:
#             _id  _index    _score  _source.actor.id    _source.created_at  \
# 0    7067358132  github  1.000000          29607371  2018-01-07T22:04:35Z
# 1    5113737188  github  1.000000           8656788  2017-01-06T16:14:38Z
# 2    5122428165  github  1.000000          19617700  2017-01-09T13:28:37Z
# 3    7071338041  github  1.000000          17437789  2018-01-08T19:39:51Z
# 4    7097961580  github  1.000000           2705860  2018-01-15T01:07:07Z
# 5    7095116372  github  1.000000            380816  2018-01-13T13:15:11Z
# 6    7082982095  github  1.000000          29139614  2018-01-10T22:09:58Z
# 7    7076559875  github  1.000000            123951  2018-01-09T18:37:32Z
# 8    7160719216  github  1.000000           4778485  2018-01-28T04:35:36Z
# 9    7089617330  github  1.000000          33857496  2018-01-12T03:56:48Z
# 10   7103218980  github  1.000000          30585466  2018-01-16T03:24:30Z
# 11   7111309903  github  1.000000          16133320  2018-01-17T13:51:21Z
# 12   7119871132  github  1.000000           1042445  2018-01-18T22:27:01Z
# 13   7125771892  github  1.000000          16934066  2018-01-20T01:24:00Z
# 14   7127051203  github  1.000000          31182295  2018-01-20T17:24:21Z
# 15   7148948950  github  1.000000          32764315  2018-01-25T09:13:48Z
# 16   7139910034  github  1.000000          28762106  2018-01-23T18:49:39Z
# 17   7137701292  github  1.000000            686247  2018-01-23T11:59:45Z
# 18   7153258707  github  1.000000            307049  2018-01-26T00:41:05Z
# 19   7169461196  github  1.000000          17991461  2018-01-30T06:36:10Z
# 20   5172466611  github  1.000000           4216574  2017-01-18T13:39:11Z
# 21   7169709731  github  1.000000           9927080  2018-01-30T07:51:21Z
# 22   7165547760  github  1.000000             51265  2018-01-29T14:13:04Z
# 23   7063563134  github  0.999999          16723349  2018-01-05T22:11:10Z
# 24   5118767513  github  0.999999          23665947  2017-01-08T10:33:59Z
# 25   7064011467  github  0.999999          14175800  2018-01-06T01:08:08Z
# 26   7068747454  github  0.999999           3502741  2018-01-08T09:53:40Z
# 27   7095994107  github  0.999999            656739  2018-01-13T23:38:49Z
# 28   7092773796  github  0.999999           4711480  2018-01-12T17:51:37Z
# 29   7083127863  github  0.999999           1686556  2018-01-10T22:47:02Z
# ..          ...     ...       ...               ...                   ...
# 970  7124365308  github  0.999981           7640693  2018-01-19T18:36:19Z
# 971  7114498455  github  0.999981          28941271  2018-01-18T01:04:09Z
# 972  7125413948  github  0.999981          32054652  2018-01-19T22:55:54Z
# 973  5153807691  github  0.999981            160078  2017-01-14T16:14:08Z
# 974  7128250760  github  0.999981          17859844  2018-01-21T09:36:03Z
# 975  7146991256  github  0.999981          25781788  2018-01-24T22:35:53Z
# 976  7141142014  github  0.999981           4700817  2018-01-23T23:08:18Z
# 977  7142362995  github  0.999981           3425702  2018-01-24T06:20:25Z
# 978  7137226663  github  0.999981           9041370  2018-01-23T10:15:37Z
# 979  7148250330  github  0.999981          35626411  2018-01-25T05:45:16Z
# 980  7163337145  github  0.999981          15681491  2018-01-29T06:48:21Z
# 981  7152898861  github  0.999981           1255037  2018-01-25T22:48:52Z
# 982  7156236348  github  0.999981           4370550  2018-01-26T15:39:50Z
# 983  7158579262  github  0.999981           8337409  2018-01-27T02:03:11Z
# 984  5149621270  github  0.999981          10059507  2017-01-13T15:19:28Z
# 985  5152154709  github  0.999981          20230450  2017-01-13T23:50:42Z
# 986  7161074494  github  0.999981            158862  2018-01-28T09:46:42Z
# 987  7159982723  github  0.999981           1589480  2018-01-27T19:29:22Z
# 988  7166732586  github  0.999981            323385  2018-01-29T18:10:50Z
# 989  7168766803  github  0.999981           8546787  2018-01-30T02:17:24Z
# 990  7164274927  github  0.999981          29216624  2018-01-29T10:38:43Z
# 991  7166101979  github  0.999981           8078968  2018-01-29T16:16:20Z
# 992  5166516586  github  0.999981           8770962  2017-01-17T16:24:46Z
# 993  7180970111  github  0.999981          18696528  2018-02-01T02:04:05Z
# 994  5116764190  github  0.999980           1175888  2017-01-07T08:10:17Z
# 995  7058403913  github  0.999980          22189186  2018-01-04T20:14:23Z
# 996  7064921198  github  0.999980          32674674  2018-01-06T13:45:03Z
# 997  7071741771  github  0.999980           3019665  2018-01-08T21:15:09Z
# 998  7100265967  github  0.999980          17463361  2018-01-15T13:34:17Z
# 999  7091666141  github  0.999980          30829071  2018-01-12T13:58:56Z
#
#      _source.id         _source.payload.comment.commit_id  \
# 0    7067358132
# 1    5113737188
# 2    5122428165
# 3    7071338041
# 4    7097961580
# 5    7095116372
# 6    7082982095
# 7    7076559875
# 8    7160719216
# 9    7089617330
# 10   7103218980
# 11   7111309903
# 12   7119871132
# 13   7125771892
# 14   7127051203
# 15   7148948950
# 16   7139910034
# 17   7137701292
# 18   7153258707
# 19   7169461196
# 20   5172466611
# 21   7169709731
# 22   7165547760  34af1ad9be9c6c369f7c57a21dd09c1648bc05f1
# 23   7063563134
# 24   5118767513
# 25   7064011467
# 26   7068747454
# 27   7095994107
# 28   7092773796
# 29   7083127863
# ..          ...                                       ...
# 970  7124365308
# 971  7114498455
# 972  7125413948
# 973  5153807691
# 974  7128250760
# 975  7146991256
# 976  7141142014
# 977  7142362995
# 978  7137226663
# 979  7148250330
# 980  7163337145
# 981  7152898861
# 982  7156236348
# 983  7158579262
# 984  5149621270
# 985  5152154709
# 986  7161074494
# 987  7159982723
# 988  7166732586
# 989  7168766803
# 990  7164274927
# 991  7166101979  9558dc9e1507e7fcc83d1de0010c41fb31970c5c
# 992  5166516586
# 993  7180970111
# 994  5116764190
# 995  7058403913
# 996  7064921198
# 997  7071741771
# 998  7100265967
# 999  7091666141
#
#                                _source.payload.commits  _source.repo.id  \
# 0    [{'message': 'visage moyen en cours'}, {'messa...        114908151
# 1     [{'message': 'BFS with level tracking working'}]         78219720
# 2                                                              45979262
# 3              [{'message': 'lcl_progress to global'}]         88505824
# 4                                                             109106298
# 5                                                              95909196
# 6    [{'message': 'chore(deps): update dependency t...         92611177
# 7          [{'message': 'Mirroring from Micro.blog.'}]         98114596
# 8                                                              18928344
# 9    [{'message': 'Made changes'}, {'message': 'Mer...        115075610
# 10   [{'message': 'タイムオブジェクト削除
# 落ちるブロックの「ステージ５ボスを倒した...         98849727
# 11                                                             84476389
# 12                                                            118045683
# 13                                                            118197016
# 14                                  [{'message': 'A'}]        107002666
# 15                                                            106801355
# 16                                                             92620036
# 17                                                             49767244
# 18                                                            117670548
# 19   [{'message': 'Added the read me file to the re...        110939007
# 20   [{'message': '对于当前的贴图，边界限制应该是u重复，v限定。
# （以后自己实现m...         76718001
# 21                                                             27179591
# 22                                                            113197161
# 23   [{'message': 'Initial changes
#
# Initial changes...        116416329
# 24   [{'message': 'Remove materialize, add bootstra...         77447347
# 25      [{'message': 'add test handback xliff files'}]         82270896
# 26                                                            116659139
# 27                                                            112615188
# 28                                                            117128377
# 29              [{'message': 'directory restructure'}]         79676108
# ..                                                 ...              ...
# 970                                                           118163451
# 971                                                           109101070
# 972              [{'message': 'Update documentation'}]        117305331
# 973                        [{'message': 'Minor fix.'}]         72878106
# 974                                                            76328745
# 975  [{'message': 'fixed layout problem temporarly ...        118637698
# 976                         [{'message': 'adds name'}]         78133698
# 977                                                             3100121
# 978  [{'message': 'Add issue template'}, {'message'...        118454607
# 979                                                           118866564
# 980                      [{'message': '简单的restful服务'}]        119325090
# 981                                                             1377159
# 982                                                             1257084
# 983                                                           119123533
# 984               [{'message': 'Update manifest.jps'}]         78859254
# 985                  [{'message': 'Update README.md'}]         78525453
# 986                                                           110998941
# 987  [{'message': 'ranger: fix homepage'}, {'messag...         53493223
# 988  [{'message': 'Revert "Release of eeacms/apache...         48365759
# 989  [{'message': 'key now must be one of the cache...        101675455
# 990                                                           114521849
# 991                                                              858127
# 992                                                             5427753
# 993                                                           113098524
# 994                                                            24656814
# 995  [{'message': 'Изменены параметры теней текста ...        114562496
# 996    [{'message': 'Update Census special variable'}]        106039066
# 997  [{'message': 'Provide option to publish releas...        115889434
# 998                                                            50881110
# 999                     [{'message': 'first chapter'}]        117092761
#
#                                     _source.repo.name  \
# 0                                    Hellyon/Faceties
# 1                              KevinDalleau/graph2vec
# 2                                   MichaelRow/Lyrics
# 3                           christianguenter2/abapGit
# 4     matteocng/storybook-fetch-messages-task-example
# 5                                 em-casa/re-frontend
# 6                           ikatyang/tsconfig-extends
# 7                               adamprocter/microblog
# 8                  thelinmichael/spotify-web-api-java
# 9                            gwilliam187/agro-crm-app
# 10                                  TsudaD/teamcreate
# 11                        thejameskyle/react-loadable
# 12                               arcVyas/jenkins-docs
# 13                            sieunkr/design-patterns
# 14                                 plt-laboratory/plt
# 15                                Smartling-test/test
# 16   dipper-github-lhr-yul-sfo-icn/test-python-sample
# 17                                 primefaces/primeng
# 18                               dotclear/clearbricks
# 19                   heshanpadmasiri/Robot-Controller
# 20                              guozhaokui/threejspbr
# 21                                          T5750/poi
# 22                         openshift/cluster-operator
# 23                          rulesninja/domain-modeler
# 24                                   RamizIb/DeepAqua
# 25          OpenLocalizationTestOrg/ol-test3-handback
# 26                                 erikll/consignment
# 27                      project-cx/pbx-group-security
# 28                                jakent/tree-of-life
# 29                                  patrickkunka/tome
# ..                                                ...
# 970    ngesa254/Digital-Outputs-with-Rainbow-Hat-LEDs
# 971                       ouzhrm/useGithubByDeveloper
# 972                             VizRI/vizri.github.io
# 973                        brettkromkamp/story_engine
# 974                                 mananapr/dotfiles
# 975                     ErikaDib/SmartCheckoutProject
# 976             hbahamonde/Comparative_Politics_UGRAD
# 977                                        nwjs/nw.js
# 978                         HeathWallace/ethereum-pos
# 979                          RashikaMishra95/DemoNode
# 980                     yejunyu/spring-boot-practise2
# 981                                           coq/coq
# 982                                      dlang/phobos
# 983                                  deikatsuo/btc-id
# 984                            yulchitaj/lets-encrypt
# 985                          MrHDR/Sun-Moon_ShinyCalc
# 986                 arlac77/local-repository-provider
# 987                         BrewTestBot/homebrew-core
# 988                           eea/eea.rancher.catalog
# 989                                 databio/shinyLOLA
# 990                              Mouris1/SpotterProps
# 991                                 pandas-dev/pandas
# 992                            unitedstates/python-us
# 993                         DufourVictor/openannuaire
# 994                                    elyase/geotext
# 995                                   dimavz/dev_proj
# 996                   NYCPlanning/labs-nyc-factfinder
# 997                               jakirkham/miniforge
# 998                              aimacode/aima-python
# 999                            PanMartinez/Django_Tut
#
#                       _source.type _type
# 0                        PushEvent  data
# 1                        PushEvent  data
# 2                       WatchEvent  data
# 3                        PushEvent  data
# 4                      DeleteEvent  data
# 5                      DeleteEvent  data
# 6                        PushEvent  data
# 7                        PushEvent  data
# 8                     ReleaseEvent  data
# 9                        PushEvent  data
# 10                       PushEvent  data
# 11                      WatchEvent  data
# 12                     CreateEvent  data
# 13                     CreateEvent  data
# 14                       PushEvent  data
# 15                     DeleteEvent  data
# 16                     CreateEvent  data
# 17                     IssuesEvent  data
# 18                       PushEvent  data
# 19                       PushEvent  data
# 20                       PushEvent  data
# 21                     CreateEvent  data
# 22   PullRequestReviewCommentEvent  data
# 23                       PushEvent  data
# 24                       PushEvent  data
# 25                       PushEvent  data
# 26                     CreateEvent  data
# 27               IssueCommentEvent  data
# 28                     CreateEvent  data
# 29                       PushEvent  data
# ..                             ...   ...
# 970                    CreateEvent  data
# 971                     WatchEvent  data
# 972                      PushEvent  data
# 973                      PushEvent  data
# 974                     WatchEvent  data
# 975                      PushEvent  data
# 976                      PushEvent  data
# 977                     WatchEvent  data
# 978                      PushEvent  data
# 979               PullRequestEvent  data
# 980                      PushEvent  data
# 981              IssueCommentEvent  data
# 982               PullRequestEvent  data
# 983                    CreateEvent  data
# 984                      PushEvent  data
# 985                      PushEvent  data
# 986                    DeleteEvent  data
# 987                      PushEvent  data
# 988                      PushEvent  data
# 989                      PushEvent  data
# 990                    IssuesEvent  data
# 991  PullRequestReviewCommentEvent  data
# 992                    IssuesEvent  data
# 993               PullRequestEvent  data
# 994              IssueCommentEvent  data
# 995                      PushEvent  data
# 996                      PushEvent  data
# 997                      PushEvent  data
# 998              IssueCommentEvent  data
# 999                      PushEvent  data
#
# [1000 rows x 12 columns]

# %%
xdix['_source.payload.commits']
# Out:
# 0      [{'message': 'visage moyen en cours'}, {'messa...
# 1       [{'message': 'BFS with level tracking working'}]
# 2
# 3                [{'message': 'lcl_progress to global'}]
# 4
# 5
# 6      [{'message': 'chore(deps): update dependency t...
# 7            [{'message': 'Mirroring from Micro.blog.'}]
# 8
# 9      [{'message': 'Made changes'}, {'message': 'Mer...
# 10     [{'message': 'タイムオブジェクト削除
# 落ちるブロックの「ステージ５ボスを倒した...
# 11
# 12
# 13
# 14                                    [{'message': 'A'}]
# 15
# 16
# 17
# 18
# 19     [{'message': 'Added the read me file to the re...
# 20     [{'message': '对于当前的贴图，边界限制应该是u重复，v限定。
# （以后自己实现m...
# 21
# 22
# 23     [{'message': 'Initial changes
#
# Initial changes...
# 24     [{'message': 'Remove materialize, add bootstra...
# 25        [{'message': 'add test handback xliff files'}]
# 26
# 27
# 28
# 29                [{'message': 'directory restructure'}]
#                              ...
# 970
# 971
# 972                [{'message': 'Update documentation'}]
# 973                          [{'message': 'Minor fix.'}]
# 974
# 975    [{'message': 'fixed layout problem temporarly ...
# 976                           [{'message': 'adds name'}]
# 977
# 978    [{'message': 'Add issue template'}, {'message'...
# 979
# 980                        [{'message': '简单的restful服务'}]
# 981
# 982
# 983
# 984                 [{'message': 'Update manifest.jps'}]
# 985                    [{'message': 'Update README.md'}]
# 986
# 987    [{'message': 'ranger: fix homepage'}, {'messag...
# 988    [{'message': 'Revert "Release of eeacms/apache...
# 989    [{'message': 'key now must be one of the cache...
# 990
# 991
# 992
# 993
# 994
# 995    [{'message': 'Изменены параметры теней текста ...
# 996      [{'message': 'Update Census special variable'}]
# 997    [{'message': 'Provide option to publish releas...
# 998
# 999                       [{'message': 'first chapter'}]
# Name: _source.payload.commits, Length: 1000, dtype: object

# %% [markdown]
# #bad
# xdix['source_payload_commits']=xdix['_source.payload.commits'].apply(lambda x : map(dict,x) if (x != None) and (x != 'NaN') else '')

# %%
xdix['_source.payload.commits']=xdix['_source.payload.commits'].apply(lambda x : ','.join([v['message'] for v in x]))

# %% [markdown]
# print("\n==".join(map(str,xdix['_source.payload.commits'])))

# %%
xdix['source_payload_commits']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/.local/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2524             try:
# -> 2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'source_payload_commits'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-141-9ef26cec8b2e> in <module>()
# ----> 1 xdix['source_payload_commits']
#
# ~/.local/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2137             return self._getitem_multilevel(key)
#    2138         else:
# -> 2139             return self._getitem_column(key)
#    2140
#    2141     def _getitem_column(self, key):
#
# ~/.local/lib/python3.6/site-packages/pandas/core/frame.py in _getitem_column(self, key)
#    2144         # get column
#    2145         if self.columns.is_unique:
# -> 2146             return self._get_item_cache(key)
#    2147
#    2148         # duplicate columns & possible reduce dimensionality
#
# ~/.local/lib/python3.6/site-packages/pandas/core/generic.py in _get_item_cache(self, item)
#    1840         res = cache.get(item)
#    1841         if res is None:
# -> 1842             values = self._data.get(item)
#    1843             res = self._box_item_values(item, values)
#    1844             cache[item] = res
#
# ~/.local/lib/python3.6/site-packages/pandas/core/internals.py in get(self, item, fastpath)
#    3841
#    3842             if not isna(item):
# -> 3843                 loc = self.items.get_loc(item)
#    3844             else:
#    3845                 indexer = np.arange(len(self.items))[isna(self.items)]
#
# ~/.local/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2525                 return self._engine.get_loc(key)
#    2526             except KeyError:
# -> 2527                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2528
#    2529         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'source_payload_commits'

# %%
xdix.to_dict(orient='records')
# Out:
# [{'_id': '7067358132',
#   '_index': 'github',
#   '_score': 0.9999999,
#   '_source.actor.id': 29607371,
#   '_source.created_at': '2018-01-07T22:04:35Z',
#   '_source.id': '7067358132',
#   '_source.payload.comment.commit_id': '',
#   '_source.payload.commits': 'visage moyen en cours,visage moyen marche',
#   '_source.repo.id': 114908151,
#   '_source.repo.name': 'Hellyon/Faceties',
#   '_source.type': 'PushEvent',
#   '_type': 'data'},
#  {'_id': '5113737188',
#   '_index': 'github',
#   '_score': 0.9999999,
#   '_source.actor.id': 8656788,
#   '_source.created_at': '2017-01-06T16:14:38Z',
#   '_source.id': '5113737188',
#   '_source.payload.comment.commit_id': '',
#   '_source.payload.commits': 'BFS with level tracking working',
#   '_source.repo.id': 78219720,
#   '_source.repo.name': 'KevinDalleau/graph2vec',
#   '_source.type': 'PushEvent',
#   '_type': 'data'},
#  {'_id': '5122428165',
#   '_index': 'github',
#   '_score': 0.9999999,
#   '_source.actor.id': 19617700,
#   '_source.created_at': '2017-01-09T13:28:37Z',
#   '_source.id': '5122428165',
#   '_source.payload.comment.commit_id': '',
#   '_source.payload.commits': '',
#   '_source.repo.id': 45979262,
#   '_source.repo.name': 'MichaelRow/Lyrics',
#   '_source.type': 'WatchEvent',
#   '_type': 'data'},
#  {'_id': '7071338041',
#   '_index': 'github',
#   '_score': 0.9999999,
#   '_source.actor.id': 17437789,
#   '_source.created_at': '2018-01-08T19:39:51Z',
#   '_source.id': '7071338041',
#   '_source.payload.comment.commit_id': '',
#   '_source.payload.commits': 'lcl_progress to global',
#   '_source.repo.id': 88505824,
#   '_source.repo.name': 'christianguenter2/abapGit',
#   '_source.type': 'PushEvent',
#   '_type': 'data'},
#  {'_id': '7097961580',
#   '_index': 'github',
#   '_score': 0.9999999,
#   '_source.actor.id': 2705860,
#   '_source.created_at': '2018-01-15T01:07:07Z',
#   '_source.id': '7097961580',
#   '_source.payload.comment.commit_id': '',
#   '_source.payload.commits': '',
#   '_source.repo.id': 109106298,
#   '_source.repo.name': 'matteocng/storybook-fetch-messages-task-example',
#   '_source.type': 'DeleteEvent',
#   '_type': 'data'},
#  {'_id': '7095116372',
#   '_index': 'github',
#   '_score': 0.9999999,
#   '_source.actor.id': 380816,
#   '_source.created_at': '2018-01-13T13:15:11Z',
#   '_source.id': '7095116372',
#   '_source.payload.comment.commit_id': '',
#   '_source.payload.commits': '',
#   '_source.repo.id': 95909196,
#   '_source.repo.name': 'em-casa/re-frontend',
#   '_source.type': 'DeleteEvent',
#   '_type': 'data'},
#  {'_id': '7082982095',
#   '_index': 'github',
#   '_score': 0.9999999,
#   '_source.actor.id': 29139614,
#   '_source.created_at': '2018-01-10T22:09:58Z',
#   '_source.id': '7082982095',
#   '_source.payload.comment.commit_id': '',
#   '_source.payload.commits': 'chore(deps): update dependency tslint to v5.9.0',
#   '_source.repo.id': 92611177,
#   '_source.repo.name': 'ikatyang/tsconfig-extends',
#   '_source.type': 'PushEvent',
#   '_type': 'data'},
#  {'_id': '7076559875',
#   '_index': 'github',
#   '_score': 0.9999999,
#   '_source.actor.id': 123951,
#   '_source.created_at': '2018-01-09T18:37:32Z',
#   '_source.id': '7076559875',
#   '_source.payload.comment.commit_id': '',
#   '_source.payload.commits': 'Mirroring from Micro.blog.',
#   '_source.repo.id': 98114596,
#   '_source.repo.name': 'adamprocter/microblog',
#   '_source.type': 'PushEvent',
#   '_type': 'data'},
#  {'_id': '7160719216',
#   '_index': 'github',
#   '_score': 0.9999999,
#   '_source.actor.id': 4778485,
#   '_source.created_at': '2018-01-28T04:35:36Z',
#   '_source.id': '7160719216',
#   '_source.payload.comment.commit_id': '',
#   '_source.payload.commits': '',
#   '_source.repo.id': 18928344,
#   '_source.repo.name': 'thelinmichael/spotify-web-api-java',
#   '_source.type': 'ReleaseEvent',
#   '_type': 'data'},
#  {'_id': '7089617330',
#   '_index': 'github',
#   '_score': 0.9999999,
#   '_source.actor.id': 33857496,
#   '_source.created_at': '2018-01-12T03:56:48Z',
#   '_source.id': '7089617330',
#   '_source.payload.comment.commit_id': '',
#   '_source.payload.commits': "Made changes,Merge remote-tracking branch 'origin/master'\n\n# Conflicts:\n#\tapp/src/main/java/com/agro/agrocrm/util/URLRequest.java",
#   '_source.repo.id': 115075610,
#   '_source.repo.name': 'gwilliam187/agro-crm-app',
#   '_source.type': 'PushEvent',
#   '_type': 'data'},
#  {'_id': '7103218980',
#   '_index': 'github',
#   '_score': 0.9999999,
#   '_source.actor.id': 30585466,
#   '_source.created_at': '2018-01-16T03:24:30Z',
#   '_source.id': '7103218980',
#   '_source.payload.comment.commit_id': '',
#   '_source.payload.commits': 'タイムオブジェクト削除\n落ちるブロックの「ステージ５ボスを倒したときに初期位置に瞬時に戻す」仕様を「倒したとき、ブロックを初期位置まで上昇させる」仕様に変更しました。',
#   '_source.repo.id': 98849727,
#   '_source.repo.name': 'TsudaD/teamcreate',
#   '_source.type': 'PushEvent',
#   '_type': 'data'},
#  {'_id': '7111309903',
#   '_index': 'github',
#   '_score': 0.9999999,
#   '_source.actor.id': 16133320,
#   '_source.created_at': '2018-01-17T13:51:21Z',
#   '_source.id': '7111309903',
#   '_source.payload.comment.commit_id': '',
#   '_source.payload.commits': '',
#   '_source.repo.id': 84476389,
#   '_source.repo.name': 'thejameskyle/react-loadable',
#   '_source.type': 'WatchEvent',
#   '_type': 'data'},
#  {'_id': '7119871132',
#   '_index': 'github',
#   '_score': 0.9999999,
#   '_source.actor.id': 1042445,
#   '_source.created_at': '2018-01-18T22:27:01Z',
#   '_source.id': '7119871132',
#   '_source.payload.comment.commit_id': '',
#   '_source.payload.commits': '',
#   '_source.repo.id': 118045683,
#   '_source.repo.name': 'arcVyas/jenkins-docs',
#   '_source.type': 'CreateEvent',
#   '_type': 'data'},
#  {'_id': '7125771892',
#   '_index': 'github',
#   '_score': 0.9999999,
#   '_source.actor.id': 16934066,
#   '_source.created_at': '2018-01-20T01:24:00Z',
#   '_source.id': '7125771892',
#   '_source.payload.comment.commit_id': '',
#   '_source.payload.commits': '',
#   '_source.repo.id': 118197016,
#   '_source.repo.name': 'sieunkr/design-patterns',
#   '_source.type': 'CreateEvent',
#   '_type': 'data'},
#  {'_id': '7127051203',
#   '_index': 'github',
#   '_score': 0.9999999,
#   '_source.actor.id': 31182295,
#   '_source.created_at': '2018-01-20T17:24:21Z',
#   '_source.id': '7127051203',
#   '_source.payload.comment.commit_id': '',
#   '_source.payload.commits': 'A',
#   '_source.repo.id': 107002666,
#   '_source.repo.name': 'plt-laboratory/plt',
#   '_source.type': 'PushEvent',
#   '_type': 'data'},
#  {'_id': '7148948950',
#   '_index': 'github',
#   '_score': 0.9999999,
#   '_source.actor.id': 32764315,
#   '_source.created_at': '2018-01-25T09:13:48Z',
#   '_source.id': '7148948950',
#   '_source.payload.comment.commit_id': '',
#   '_source.payload.commits': '',
#   '_source.repo.id': 106801355,
#   '_source.repo.name': 'Smartling-test/test',
#   '_source.type': 'DeleteEvent',
#   '_type': 'data'},
#  {'_id': '7139910034',
#   '_index': 'github',
#   '_score': 0.9999999,
#   '_source.actor.id': 28762106,
#   '_source.created_at': '2018-01-23T18:49:39Z',
#   '_source.id': '7139910034',
#   '_source.payload.comment.commit_id': '',
#   '_source.payload.commits': '',
#   '_source.repo.id': 92620036,
#   '_source.repo.name': 'dipper-github-lhr-yul-sfo-icn/test-python-sample',
#   '_source.type': 'CreateEvent',
#   '_type': 'data'},
#  {'_id': '7137701292',
#   '_index': 'github',
#   '_score': 0.9999999,
#   '_source.actor.id': 686247,
#   '_source.created_at': '2018-01-23T11:59:45Z',
#   '_source.id': '7137701292',
#   '_source.payload.comment.commit_id': '',
#   '_source.payload.commits': '',
#   '_source.repo.id': 49767244,
#   '_source.repo.name': 'primefaces/primeng',
#   '_source.type': 'IssuesEvent',
#   '_type': 'data'},
#  {'_id': '7153258707',
#   '_index': 'github',
#   '_score': 0.9999999,
#   '_source.actor.id': 307049,
#   '_source.created_at': '2018-01-26T00:41:05Z',
#   '_source.id': '7153258707',
#   '_source.payload.comment.commit_id': '',
#   '_source.payload.commits': '',
#   '_source.repo.id': 117670548,
#   '_source.repo.name': 'dotclear/clearbricks',
#   '_source.type': 'PushEvent',
#   '_type': 'data'},
#  {'_id': '7169461196',
#   '_index': 'github',
#   '_score': 0.9999999,
#   '_source.actor.id': 17991461,
#   '_source.created_at': '2018-01-30T06:36:10Z',
#   '_source.id': '7169461196',
#   '_source.payload.comment.commit_id': '',
#   '_source.payload.commits': 'Added the read me file to the repo\n\nThis is just an template for the readme',
#   '_source.repo.id': 110939007,
#   '_source.repo.name': 'heshanpadmasiri/Robot-Controller',
#   '_source.type': 'PushEvent',
#   '_type': 'data'},
#  {'_id': '5172466611',
#   '_index': 'github',
#   '_score': 0.9999999,
#   '_source.actor.id': 4216574,
#   '_source.created_at': '2017-01-18T13:39:11Z',
#   '_source.id': '5172466611',
#   '_source.payload.comment.commit_id': '',
#   '_source.payload.commits': '对于当前的贴图，边界限制应该是u重复，v限定。\n（以后自己实现mipmap的时候怎么办？）',
#   '_source.repo.id': 76718001,
#   '_source.repo.name': 'guozhaokui/threejspbr',
#   '_source.type': 'PushEvent',
#   '_type': 'data'},
#  {'_id': '7169709731',
#   '_index': 'github',
#   '_score': 0.9999999,
#   '_source.actor.id': 9927080,
#   '_source.created_at': '2018-01-30T07:51:21Z',
#   '_source.id': '7169709731',
#   '_source.payload.comment.commit_id': '',
#   '_source.payload.commits': '',
#   '_source.repo.id': 27179591,
#   '_source.repo.name': 'T5750/poi',
#   '_source.type': 'CreateEvent',
#   '_type': 'data'},
#  {'_id': '7165547760',
#   '_index': 'github',
#   '_score': 0.9999999,
#   '_source.actor.id': 51265,
#   '_source.created_at': '2018-01-29T14:13:04Z',
#   '_source.id': '7165547760',
#   '_source.payload.comment.commit_id': '34af1ad9be9c6c369f7c57a21dd09c1648bc05f1',
#   '_source.payload.commits': '',
#   '_source.repo.id': 113197161,
#   '_source.repo.name': 'openshift/cluster-operator',
#   '_source.type': 'PullRequestReviewCommentEvent',
#   '_type': 'data'},
#  {'_id': '7063563134',
#   '_index': 'github',
#   '_score': 0.99999946,
#   '_source.actor.id': 16723349,
#   '_source.created_at': '2018-01-05T22:11:10Z',
#   '_source.id': '7063563134',
#   '_source.payload.comment.commit_id': '',
#   '_source.payload.commits': 'Initial changes\n\nInitial changes.',
#   '_source.repo.id': 116416329,
#   '_source.repo.name': 'rulesninja/domain-modeler',
#   '_source.type': 'PushEvent',
#   '_type': 'data'},
#  {'_id': '5118767513',
#   '_index': 'github',
#   '_score': 0.99999946,
#   '_source.actor.id': 23665947,
#   '_source.created_at': '2017-01-08T10:33:59Z',
#   '_source.id': '5118767513',
#   '_source.payload.comment.commit_id': '',
#   '_source.payload.commits': 'Remove materialize, add bootstrap,html markup index,Markup index.html,index.html working,Build test,Build test 2,gulpfile,Build task ready',
#   '_source.repo.id': 77447347,
#   '_source.repo.name': 'RamizIb/DeepAqua',
#   '_source.type': 'PushEvent',
#   '_type': 'data'},
#  {'_id': '7064011467',
#   '_index': 'github',
#   '_score': 0.99999946,
#   '_source.actor.id': 14175800,
#   '_source.created_at': '2018-01-06T01:08:08Z',
#   '_source.id': '7064011467',
#   '_source.payload.comment.commit_id': '',
#   '_source.payload.commits': 'add test handback xliff files',
#   '_source.repo.id': 82270896,
#   '_source.repo.name': 'OpenLocalizationTestOrg/ol-test3-handback',
#   '_source.type': 'PushEvent',
#   '_type': 'data'},
#  {'_id': '7068747454',
#   '_index': 'github',
#   '_score': 0.99999946,
#   '_source.actor.id': 3502741,
#   '_source.created_at': '2018-01-08T09:53:40Z',
#   '_source.id': '7068747454',
#   '_source.payload.comment.commit_id': '',
#   '_source.payload.commits': '',
#   '_source.repo.id': 116659139,
#   '_source.repo.name': 'erikll/consignment',
#   '_source.type': 'CreateEvent',
#   '_type': 'data'},
#  {'_id': '7095994107',
#   '_index': 'github',
#   '_score': 0.99999946,
#   '_source.actor.id': 656739,
#   '_source.created_at': '2018-01-13T23:38:49Z',
#   '_source.id': '7095994107',
#   '_source.payload.comment.commit_id': '',
#   '_source.payload.commits': '',
#   '_source.repo.id': 112615188,
#   '_source.repo.name': 'project-cx/pbx-group-security',
#   '_source.type': 'IssueCommentEvent',
#   '_type': 'data'},
#  {'_id': '7092773796',
#   '_index': 'github',
#   '_score': 0.99999946,
#   '_source.actor.id': 4711480,
#   '_source.created_at': '2018-01-12T17:51:37Z',
#   '_source.id': '7092773796',
#   '_source.payload.comment.commit_id': '',
#   '_source.payload.commits': '',
#   '_source.repo.id': 117128377,
#   '_source.repo.name': 'jakent/tree-of-life',
#   '_source.type': 'CreateEvent',
#   '_type': 'data'},
#  {'_id': '7083127863',
#   '_index': 'github',
#   '_score': 0.99999946,
#   '_source.actor.id': 1686556,
#   '_source.created_at': '2018-01-10T22:47:02Z',
#   '_source.id': '7083127863',
#   '_source.payload.comment.commit_id': '',
#   '_source.payload.commits': 'directory restructure',
#   '_source.repo.id': 79676108,
#   '_source.repo.name': 'patrickkunka/tome',
#   '_source.type': 'PushEvent',
#   '_type': 'data'},
#  {'_id': '7078617779',
#   '_index': 'github',
#   '_score': 0.99999946,
#   '_source.actor.id': 11293084,
#   '_source.created_at': '2018-01-10T05:13:47Z',
#   '_source.id': '7078617779',
#   '_source.payload.comment.commit_id': '',
#   '_source.payload.commits': '',
#   '_source.repo.id': 109843059,
#   '_source.repo.name': 'leusonmario/cron-utils',
#   '_source.type': 'CreateEvent',
#   '_type': 'data'},
#  {'_id': '7177929788',
#   '_index': 'github',
#   '_score': 0.99999946,
#   '_source.actor.id': 12693984,
#   '_source.created_at': '2018-01-31T15:07:51Z',
#   '_source.id': '7177929788',
#   '_source.payload.comment.commit_id': '',
#   '_source.payload.commits': '200 OK http://wolesi.website/pve/showdoc.aspx?Id=1887',
#   '_source.repo.id': 42310621,
#   '_source.repo.name': 'everypolitician-scrapers/afghanistan-assembly',
#   '_source.type': 'PushEvent',
#   '_type': 'data'},
#  {'_id': '7090790060',
#   '_index': 'github',
#   '_score': 0.99999946,
#   '_source.actor.id': 29726686,
#   '_source.created_at': '2018-01-12T10:21:18Z',
#   '_source.id': '7090790060',
#   '_source.payload.comment.commit_id': '',
#   '_source.payload.commits': '',
#   '_source.repo.id': 111383521,
#   '_source.repo.name': 'difi/jenkins-pipeline',
#   '_source.type': 'DeleteEvent',
#   '_type': 'data'},
#  {'_id': '7106691800',
#   '_index': 'github',
#   '_score': 0.99999946,
#   '_source.actor.id': 313721,
#   '_source.created_at': '2018-01-16T17:23:02Z',
#   '_source.id': '7106691800',
#   '_source.payload.comment.commit_id': '',
#   '_source.payload.commits': '',
#   '_source.repo.id': 45061433,
#   '_source.repo.name': 'cmu-phil/tetrad',
#   '_source.type': 'IssueCommentEvent',
#   '_type': 'data'},
#  {'_id': '7109095729',
#   '_index': 'github',
#   '_score': 0.99999946,
#   '_source.actor.id': 630673,
#   '_source.created_at': '2018-01-17T03:56:40Z',
#   '_source.id': '7109095729',
#   '_source.payload.comment.commit_id': '',
#   '_source.payload.commits': "Update multiple files\n\nChange service to ContactSensor for doors and windows,Merge pull request #54 from schmittx/door-window-sensor-fix\n\nFix service for door and window sensors,Bumped version to 1.5.9,Remove deprecated services from cached accessories,Bumped version to 1.6.0,Remove the Android app's Client ID and secret,Config is validated upon startup\n\nWill raise an error when when client_id or client_secret are missing,Update binary_switch.js\n\nAdded support for leakSMART valve by checking for state.opened.\nAdded config option for outlets and switches. Modified state.consumption (consumption only exists for Quirky Outlinks),Added support for doorbell motion sensors,Updated dependencies,Bumped version to 1.7.0,Fixed #69,Bumped version to 1.7.1,Fixed typo in readme,Added a mention of Chamberlain MyQ® Home Bridge to README,Updated dependencies,Docs,Bumped version to 1.8.0,Fixed enums in sensor_pod.js,Added ability to expose binary switches as outlets or switches. Fixes #58",
#   '_source.repo.id': 106365403,
#   '_source.repo.name': 'schmittx/homebridge-wink3',
#   '_source.type': 'PushEvent',
#   '_type': 'data'},
#  {'_id': '7118087577',
#   '_index': 'github',
#   '_score': 0.99999946,
#   '_source.actor.id': 32717724,
#   '_source.created_at': '2018-01-18T16:21:08Z',
#   '_source.id': '7118087577',
#   '_source.payload.comment.commit_id': '',
#   '_source.payload.commits': 'automatically backed up by learn',
#   '_source.repo.id': 118004785,
#   '_source.repo.name': 'jshwa/js-ajax-ajax-and-callbacks-lab-v-000',
#   '_source.type': 'PushEvent',
#   '_type': 'data'},
#  {'_id': '7123383501',
#   '_index': 'github',
#   '_score': 0.99999946,
#   '_source.actor.id': 10077243,
#   '_source.created_at': '2018-01-19T15:15:11Z',
#   '_source.id': '7123383501',
#   '_source.payload.comment.commit_id': '',
#   '_source.payload.commits': '',
#   '_source.repo.id': 113460766,
#   '_source.repo.name': 'avtomon/PQFormBuilder',
#   '_source.type': 'PushEvent',
#   '_type': 'data'},
#  {'_id': '7161943149',
#   '_index': 'github',
#   '_score': 0.99999946,
#   '_source.actor.id': 24826908,
#   '_source.created_at': '2018-01-28T18:58:04Z',
#   '_source.id': '7161943149',
#   '_source.payload.comment.commit_id': '',
#   '_source.payload.commits': '',
#   '_source.repo.id': 119279799,
#   '_source.repo.name': 'Plajer/Village_Defense',
#   '_source.type': 'CreateEvent',
#   '_type': 'data'},
#  {'_id': '7127636020',
#   '_index': 'github',
#   '_score': 0.99999946,
#   '_source.actor.id': 8517910,
#   '_source.created_at': '2018-01-21T00:06:58Z',
#   '_source.id': '7127636020',
#   '_source.payload.comment.commit_id': '',
#   '_source.payload.commits': '',
#   '_source.repo.id': 46629356,
#   '_source.repo.name': 'Lombiq/Orchard-Scripting-Extensions-PHP',
#   '_source.type': 'PushEvent',
#   '_type': 'data'},
#  {'_id': '7151376821',
#   '_index': 'github',
#   '_score': 0.99999946,
#   '_source.actor.id': 1282050,
#   '_source.created_at': '2018-01-25T17:18:19Z',
#   '_source.id': '7151376821',
#   '_source.payload.comment.commit_id': '',
#   '_source.payload.commits': 'Deployed c6a2c00 with MkDocs version: 0.17.2',
#   '_source.repo.id': 116691622,
#   '_source.repo.name': 'Yichuans/iucn-hand-over',
#   '_source.type': 'PushEvent',
#   '_type': 'data'},
#  {'_id': '7140674334',
#   '_index': 'github',
#   '_score': 0.99999946,
#   '_source.actor.id': 4951803,
#   '_source.created_at': '2018-01-23T21:25:05Z',
#   '_source.id': '7140674334',
#   '_source.payload.comment.commit_id': '',
#   '_source.payload.commits': '',
#   '_source.repo.id': 80638907,
#   '_source.repo.name': 'birm/gh-funstats',
#   '_source.type': 'IssuesEvent',
#   '_type': 'data'},
#  {'_id': '7130634606',
#   '_index': 'github',
#   '_score': 0.99999946,
#   '_source.actor.id': 13191938,
#   '_source.created_at': '2018-01-22T07:44:55Z',
#   '_source.id': '7130634606',
#   '_source.payload.comment.commit_id': '',
#   '_source.payload.commits': 'update',
#   '_source.repo.id': 118422266,
#   '_source.repo.name': 'mutex73/LeetCode',
#   '_source.type': 'PushEvent',
#   '_type': 'data'},
#  {'_id': '7168151553',
#   '_index': 'github',
#   '_score': 0.99999946,
#   '_source.actor.id': 10729230,
#   '_source.created_at': '2018-01-29T23:07:46Z',
#   '_source.id': '7168151553',
#   '_source.payload.comment.commit_id': '',
#   '_source.payload.commits': 'automatically backed up by learn',
#   '_source.repo.id': 119306543,
#   '_source.repo.name': 'sherryptk/sinatra-fwitter-group-project-v-000',
#   '_source.type': 'PushEvent',
#   '_type': 'data'},
#  {'_id': '5142971472',
#   '_index': 'github',
#   '_score': 0.99999946,
#   '_source.actor.id': 16478785,
#   '_source.created_at': '2017-01-12T14:51:11Z',
#   '_source.id': '5142971472',
#   '_source.payload.comment.commit_id': '',
#   '_source.payload.commits': 'Fix Upadate,FIX BUG,FIX REBASE ;),add lib locally,Print CSV\n\nwith System.out.prinln,commit 1,Fix toString()\n\nfix toStirng(),dell lines,fix CSVtoObject \n\n;),refresh ;)',
#   '_source.repo.id': 75382517,
#   '_source.repo.name': 'Bakhah/Godsavethebibine',
#   '_source.type': 'PushEvent',
#   '_type': 'data'},
#  {'_id': '7163775771',
#   '_index': 'github',
#   '_score': 0.99999946,
#   '_source.actor.id': 35590162,
#   '_source.created_at': '2018-01-29T08:54:18Z',
#   '_source.id': '7163775771',
#   '_source.payload.comment.commit_id': '',
#   '_source.payload.commits': '',
#   '_source.repo.id': 118083636,
#   '_source.repo.name': 'unitydemo2/Docworks',
#   '_source.type': 'PushEvent',
#   '_type': 'data'},
#  {'_id': '7173078026',
#   '_index': 'github',
#   '_score': 0.99999946,
#   '_source.actor.id': 233,
#   '_source.created_at': '2018-01-30T18:45:21Z',
#   '_source.id': '7173078026',
#   '_source.payload.comment.commit_id': '',
#   '_source.payload.commits': 'Resolve Haml 5 warnings (#2149)',
#   '_source.repo.id': 261943,
#   '_source.repo.name': 'middleman/middleman',
#   '_source.type': 'PushEvent',
#   '_type': 'data'},
#  {'_id': '7162214909',
#   '_index': 'github',
#   '_score': 0.99999946,
#   '_source.actor.id': 16711277,
#   '_source.created_at': '2018-01-28T21:35:52Z',
#   '_source.id': '7162214909',
#   '_source.payload.comment.commit_id': '',
#   '_source.payload.commits': 'cleaning',
#   '_source.repo.id': 113304584,
#   '_source.repo.name': 'Sachka/Tolkienizer',
#   '_source.type': 'PushEvent',
#   '_type': 'data'},
#  {'_id': '5173060005',
#   '_index': 'github',
#   '_score': 0.99999946,
#   '_source.actor.id': 13338419,
#   '_source.created_at': '2017-01-18T15:12:54Z',
#   '_source.id': '5173060005',
#   '_source.payload.comment.commit_id': '',
#   '_source.payload.commits': '',
#   '_source.repo.id': 79352018,
#   '_source.repo.name': 'Dezodev/verbose-pancake',
#   '_source.type': 'CreateEvent',
#   '_type': 'data'},
#  {'_id': '5128228169',
#   '_index': 'github',
#   '_score': 0.9999993,
#   '_source.actor.id': 3624877,
#   '_source.created_at': '2017-01-10T10:44:17Z',
#   '_source.id': '5128228169',
#   '_source.payload.comment.commit_id': '',
#   '_source.payload.commits': '',
#   '_source.repo.id': 15348522,
#   '_source.repo.name': 'googleads/googleads-php-lib',
#   '_source.type': 'IssueCommentEvent',
#   '_type': 'data'},
#  {'_id': '5127331197',
#   '_index': 'github',
#   '_score': 0.9999993,
#   '_source.actor.id': 22745312,
#   '_source.created_at': '2017-01-10T07:16:48Z',
#   '_source.id': '5127331197',
#   '_source.payload.comment.commit_id': '',
#   '_source.payload.commits': '',
#   '_source.repo.id': 78507943,
#   '_source.repo.name': 'RuoChen95/coursera-test',
#   '_source.type': 'CreateEvent',
#   '_type': 'data'},
#  {'_id': '7060842488',
#   '_index': 'github',
#   '_score': 0.9999993,
#   '_source.actor.id': 4701338,
#   '_source.created_at': '2018-01-05T10:33:36Z',
#   '_source.id': '7060842488',
#   '_source.payload.comment.commit_id': '',
#   '_source.payload.commits': '',
#   '_source.repo.id': 15634981,
#   '_source.repo.name': 'godotengine/godot',
#   '_source.type': 'IssueCommentEvent',
#   '_type': 'data'},
#  {'_id': '5120547590',
#   '_index': 'github',
#   '_score': 0.9999993,
#   '_source.actor.id': 24231314,
#   '_source.created_at': '2017-01-09T04:21:30Z',
#   '_source.id': '5120547590',
#   '_source.payload.comment.commit_id': '',
#   '_source.payload.commits': 'tomo',
#   '_source.repo.id': 78305198,
#   '_source.repo.name': 'Bigsam82/prouno',
#   '_source.type': 'PushEvent',
#   '_type': 'data'},
#  {'_id': '7070666318',
#   '_index': 'github',
#   '_score': 0.9999993,
#   '_source.actor.id': 14952196,
#   '_source.created_at': '2018-01-08T17:06:40Z',
#   '_source.id': '7070666318',
#   '_source.payload.comment.commit_id': '',
#   '_source.payload.commits': '',
#   '_source.repo.id': 116704123,
#   '_source.repo.name': 'orlov-dev/fenix',
#   '_source.type': 'CreateEvent',
#   '_type': 'data'},
#  {'_id': '7100000214',
#   '_index': 'github',
#   '_score': 0.9999993,
#   '_source.actor.id': 33111559,
#   '_source.created_at': '2018-01-15T12:32:49Z',
#   '_source.id': '7100000214',
#   '_source.payload.comment.commit_id': '',
#   '_source.payload.commits': 'Site updated: 2018-01-15 12:32:39',
#   '_source.repo.id': 108649285,
#   '_source.repo.name': 'geyan666/geyan666.github.io',
#   '_source.type': 'PushEvent',
#   '_type': 'data'},
#  {'_id': '7098922940',
#   '_index': 'github',
#   '_score': 0.9999993,
#   '_source.actor.id': 15936115,
#   '_source.created_at': '2018-01-15T08:16:57Z',
#   '_source.id': '7098922940',
#   '_source.payload.comment.commit_id': '',
#   '_source.payload.commits': '',
#   '_source.repo.id': 51924293,
#   '_source.repo.name': 'PHPfox-Official/phpfox-v4-feature-requests',
#   '_source.type': 'IssueCommentEvent',
#   '_type': 'data'},
#  {'_id': '7095759880',
#   '_index': 'github',
#   '_score': 0.9999993,
#   '_source.actor.id': 418747,
#   '_source.created_at': '2018-01-13T20:40:17Z',
#   '_source.id': '7095759880',
#   '_source.payload.comment.commit_id': '',
#   '_source.payload.commits': 'Add Ruby code to create basic robots.txt file',
#   '_source.repo.id': 116636265,
#   '_source.repo.name': 'jbampton/charts',
#   '_source.type': 'PushEvent',
#   '_type': 'data'},
#  {'_id': '7084458077',
#   '_index': 'github',
#   '_score': 0.9999993,
#   '_source.actor.id': 8517910,
#   '_source.created_at': '2018-01-11T06:59:25Z',
#   '_source.id': '7084458077',
#   '_source.payload.comment.commit_id': '',
#   '_source.payload.commits': '',
#   '_source.repo.id': 46566064,
#   '_source.repo.name': 'Lombiq/Combinator',
#   '_source.type': 'PushEvent',
#   '_type': 'data'},
#  {'_id': '7074719354',
#   '_index': 'github',
#   '_score': 0.9999993,
#   '_source.actor.id': 3455449,
#   '_source.created_at': '2018-01-09T12:27:28Z',
#   '_source.id': '7074719354',
#   '_source.payload.comment.commit_id': '',
#   '_source.payload.commits': '',
#   '_source.repo.id': 92093628,
#   '_source.repo.name': 'Didstopia/SDL',
#   '_source.type': 'PushEvent',
#   '_type': 'data'},
#  {'_id': '7162430479',
#   '_index': 'github',
#   '_score': 0.9999993,
#   '_source.actor.id': 363388,
#   '_source.created_at': '2018-01-28T23:45:30Z',
#   '_source.id': '7162430479',
#   '_source.payload.comment.commit_id': '',
#   '_source.payload.commits': '',
#   '_source.repo.id': 118678476,
#   '_source.repo.name': 'SomethingWithHorizons/mailserver',
#   '_source.type': 'GollumEvent',
#   '_type': 'data'},
#  {'_id': '5170566239',
#   '_index': 'github',
#   '_score': 0.9999993,
#   '_source.actor.id': 979929,
#   '_source.created_at': '2017-01-18T06:54:45Z',
#   '_source.id': '5170566239',
#   '_source.payload.comment.commit_id': '',
#   '_source.payload.commits': '',
#   '_source.repo.id': 26677107,
#   '_source.repo.name': 'jedireza/hapi-node-postgres',
#   '_source.type': 'PullRequestEvent',
#   '_type': 'data'},
#  {'_id': '7088921209',
#   '_index': 'github',
#   '_score': 0.9999993,
#   '_source.actor.id': 16406727,
#   '_source.created_at': '2018-01-11T23:34:06Z',
#   '_source.id': '7088921209',
#   '_source.payload.comment.commit_id': '',
#   '_source.payload.commits': '',
#   '_source.repo.id': 49035474,
#   '_source.repo.name': 'NOAA-PMEL/LAS',
#   '_source.type': 'IssueCommentEvent',
#   '_type': 'data'},
#  {'_id': '7101450645',
#   '_index': 'github',
#   '_score': 0.9999993,
#   '_source.actor.id': 5014119,
#   '_source.created_at': '2018-01-15T17:33:29Z',
#   '_source.id': '7101450645',
#   '_source.payload.comment.commit_id': '',
#   '_source.payload.commits': 'I18n: Update translation uk (100%).\n\n28 translated messages.\n\nTransifex (https://www.transifex.com/xfce/public/).',
#   '_source.repo.id': 28493731,
#   '_source.repo.name': 'xfce-mirror/xfce4-verve-plugin',
#   '_source.type': 'PushEvent',
#   '_type': 'data'},
#  {'_id': '7111049746',
#   '_index': 'github',
#   '_score': 0.9999993,
#   '_source.actor.id': 2412177,
#   '_source.created_at': '2018-01-17T12:58:13Z',
#   '_source.id': '7111049746',
#   '_source.payload.comment.commit_id': '',
#   '_source.payload.commits': '',
#   '_source.repo.id': 104457964,
#   '_source.repo.name': 'loevgaard/dandomain-foundation-entities',
#   '_source.type': 'CreateEvent',
#   '_type': 'data'},
#  {'_id': '7114129327',
#   '_index': 'github',
#   '_score': 0.9999993,
#   '_source.actor.id': 1288694,
#   '_source.created_at': '2018-01-17T23:05:16Z',
#   '_source.id': '7114129327',
#   '_source.payload.comment.commit_id': '',
#   '_source.payload.commits': '2.1.1,Prepare next development version',
#   '_source.repo.id': 115447167,
#   '_source.repo.name': 'wKovacs64/meetup-raffle-web',
#   '_source.type': 'PushEvent',
#   '_type': 'data'},
#  {'_id': '7124694839',
#   '_index': 'github',
#   '_score': 0.9999993,
#   '_source.actor.id': 32944990,
#   '_source.created_at': '2018-01-19T19:52:16Z',
#   '_source.id': '7124694839',
#   '_source.payload.comment.commit_id': '',
#   '_source.payload.commits': '',
#   '_source.repo.id': 118171210,
#   '_source.repo.name': 'AbhirajSidhu/hello-world',
#   '_source.type': 'CreateEvent',
#   '_type': 'data'},
#  {'_id': '7126631465',
#   '_index': 'github',
#   '_score': 0.9999993,
#   '_source.actor.id': 5219415,
#   '_source.created_at': '2018-01-20T12:48:30Z',
#   '_source.id': '7126631465',
#   '_source.payload.comment.commit_id': '',
#   '_source.payload.commits': '📦 Game Update 20.01.2018 (3.3 MB)',
#   '_source.repo.id': 52203133,
#   '_source.repo.name': 'frk1/hazedumper',
#   '_source.type': 'PushEvent',
#   '_type': 'data'},
#  {'_id': '7152392745',
#   '_index': 'github',
#   '_score': 0.9999993,
#   '_source.actor.id': 29377728,
#   '_source.created_at': '2018-01-25T20:52:18Z',
#   '_source.id': '7152392745',
#   '_source.payload.comment.commit_id': '',
#   '_source.payload.commits': 'added home page table',
#   '_source.repo.id': 118670262,
#   '_source.repo.name': 'landonwshields/sla-db',
#   '_source.type': 'PushEvent',
#   '_type': 'data'},
#  {'_id': '7143570966',
#   '_index': 'github',
#   '_score': 0.9999993,
#   '_source.actor.id': 7017740,
#   '_source.created_at': '2018-01-24T11:16:10Z',
#   '_source.id': '7143570966',
#   '_source.payload.comment.commit_id': '',
#   '_source.payload.commits': 'Rename carrot-cake.md to _my_recipes/carrot-cake.md',
#   '_source.repo.id': 89935632,
#   '_source.repo.name': 'trianglegirl/recipes',
#   '_source.type': 'PushEvent',
#   '_type': 'data'},
#  {'_id': '7131475372',
#   '_index': 'github',
#   '_score': 0.9999993,
#   '_source.actor.id': 3446885,
#   '_source.created_at': '2018-01-22T11:07:45Z',
#   '_source.id': '7131475372',
#   '_source.payload.comment.commit_id': '',
#   '_source.payload.commits': '',
#   '_source.repo.id': 18780056,
#   '_source.repo.name': 'xxorde/librekinect',
#   '_source.type': 'WatchEvent',
#   '_type': 'data'},
#  {'_id': '5147405214',
#   '_index': 'github',
#   '_score': 0.9999993,
#   '_source.actor.id': 111481,
#   '_source.created_at': '2017-01-13T07:05:49Z',
#   '_source.id': '5147405214',
#   '_source.payload.comment.commit_id': '',
#   '_source.payload.commits': '',
#   '_source.repo.id': 72848828,
#   '_source.repo.name': 'xorock/zend-service-recaptcha-v2',
#   '_source.type': 'IssueCommentEvent',
#   '_type': 'data'},
#  {'_id': '5155803176',
#   '_index': 'github',
#   '_score': 0.9999993,
#   '_source.actor.id': 810762,
#   '_source.created_at': '2017-01-15T16:36:03Z',
#   '_source.id': '5155803176',
#   '_source.payload.comment.commit_id': '',
#   '_source.payload.commits': '',
#   '_source.repo.id': 12084976,
#   '_source.repo.name': 'modesttree/Zenject',
#   '_source.type': 'IssueCommentEvent',
#   '_type': 'data'},
#  {'_id': '7170598465',
#   '_index': 'github',
#   '_score': 0.9999993,
#   '_source.actor.id': 33541658,
#   '_source.created_at': '2018-01-30T11:00:05Z',
#   '_source.id': '7170598465',
#   '_source.payload.comment.commit_id': '',
#   '_source.payload.commits': '',
#   '_source.repo.id': 112326848,
#   '_source.repo.name': 'Community-Tech/admin',
#   '_source.type': 'IssueCommentEvent',
#   '_type': 'data'},
#  {'_id': '5161735839',
#   '_index': 'github',
#   '_score': 0.9999993,
#   '_source.actor.id': 16896769,
#   '_source.created_at': '2017-01-16T21:26:28Z',
#   '_source.id': '5161735839',
#   '_source.payload.comment.commit_id': '',
#   '_source.payload.commits': 'Add all commit',
#   '_source.repo.id': 50422059,
#   '_source.repo.name': 'FGtatsuroWork3/TestForStaticFileSharing2',
#   '_source.type': 'PushEvent',
#   '_type': 'data'},
#  {'_id': '7179854114',
#   '_index': 'github',
#   '_score': 0.9999993,
#   '_source.actor.id': 11655766,
#   '_source.created_at': '2018-01-31T21:07:47Z',
#   '_source.id': '7179854114',
#   '_source.payload.comment.commit_id': '',
#   '_source.payload.commits': '',
#   '_source.repo.id': 107575570,
#   '_source.repo.name': 'blackbaud/skyux-lib-testing',
#   '_source.type': 'PullRequestEvent',
#   '_type': 'data'},
#  {'_id': '7066176087',
#   '_index': 'github',
#   '_score': 0.999999,
#   '_source.actor.id': 35184566,
#   '_source.created_at': '2018-01-07T07:18:32Z',
#   '_source.id': '7066176087',
#   '_source.payload.comment.commit_id': '',
#   '_source.payload.commits': 'commit',
#   '_source.repo.id': 116545082,
#   '_source.repo.name': 'qxdys6bm/qxdys6bm.github.io',
#   '_source.type': 'PushEvent',
#   '_type': 'data'},
#  {'_id': '7060348209',
#   '_index': 'github',
#   '_score': 0.999999,
#   '_source.actor.id': 275871,
#   '_source.created_at': '2018-01-05T08:18:28Z',
#   '_source.id': '7060348209',
#   '_source.payload.comment.commit_id': '',
#   '_source.payload.commits': '',
#   '_source.repo.id': 27193779,
#   '_source.repo.name': 'nodejs/node',
#   '_source.type': 'IssueCommentEvent',
#   '_type': 'data'},
#  {'_id': '5119713653',
#   '_index': 'github',
#   '_score': 0.999999,
#   '_source.actor.id': 16382930,
#   '_source.created_at': '2017-01-08T20:36:44Z',
#   '_source.id': '5119713653',
#   '_source.payload.comment.commit_id': '',
#   '_source.payload.commits': 'debug',
#   '_source.repo.id': 70310108,
#   '_source.repo.name': 'fpasquer/21sh',
#   '_source.type': 'PushEvent',
#   '_type': 'data'},
#  {'_id': '7072869978',
#   '_index': 'github',
#   '_score': 0.999999,
#   '_source.actor.id': 35247092,
#   '_source.created_at': '2018-01-09T03:16:38Z',
#   '_source.id': '7072869978',
#   '_source.payload.comment.commit_id': '',
#   '_source.payload.commits': '',
#   '_source.repo.id': 116759712,
#   '_source.repo.name': 'ljs6874521/HelloWord',
#   '_source.type': 'CreateEvent',
#   '_type': 'data'},
#  {'_id': '7097512499',
#   '_index': 'github',
#   '_score': 0.999999,
#   '_source.actor.id': 17279765,
#   '_source.created_at': '2018-01-14T20:06:11Z',
#   '_source.id': '7097512499',
#   '_source.payload.comment.commit_id': '',
#   '_source.payload.commits': '',
#   '_source.repo.id': 50256891,
#   '_source.repo.name': 'pret/pokeruby',
#   '_source.type': 'PullRequestEvent',
#   '_type': 'data'},
#  {'_id': '7094051840',
#   '_index': 'github',
#   '_score': 0.999999,
#   '_source.actor.id': 28762106,
#   '_source.created_at': '2018-01-12T23:30:21Z',
#   '_source.id': '7094051840',
#   '_source.payload.comment.commit_id': '',
#   '_source.payload.commits': '',
#   '_source.repo.id': 92620036,
#   '_source.repo.name': 'dipper-github-lhr-yul-sfo-icn/test-python-sample',
#   '_source.type': 'CreateEvent',
#   '_type': 'data'},
#  {'_id': '7079771879',
#   '_index': 'github',
#   '_score': 0.999999,
#   '_source.actor.id': 28945567,
#   '_source.created_at': '2018-01-10T10:53:45Z',
#   '_source.id': '7079771879',
#   '_source.payload.comment.commit_id': '',
#   '_source.payload.commits': '',
#   '_source.repo.id': 116944189,
#   '_source.repo.name': 'kammavamsi/sample-react-application',
#   '_source.type': 'CreateEvent',
#   '_type': 'data'},
#  {'_id': '7074394700',
#   '_index': 'github',
#   '_score': 0.999999,
#   '_source.actor.id': 123951,
#   '_source.created_at': '2018-01-09T11:07:12Z',
#   '_source.id': '7074394700',
#   '_source.payload.comment.commit_id': '',
#   '_source.payload.commits': 'Mirroring from Micro.blog.',
#   '_source.repo.id': 98114596,
#   '_source.repo.name': 'adamprocter/microblog',
#   '_source.type': 'PushEvent',
#   '_type': 'data'},
#  {'_id': '5142236250',
#   '_index': 'github',
#   '_score': 0.999999,
#   '_source.actor.id': 17688012,
#   '_source.created_at': '2017-01-12T12:37:25Z',
#   '_source.id': '5142236250',
#   '_source.payload.comment.commit_id': '',
#   '_source.payload.commits': '',
#   '_source.repo.id': 51830024,
#   '_source.repo.name': 'popcorn-official/popcorn-desktop',
#   '_source.type': 'IssueCommentEvent',
#   '_type': 'data'},
#  {'_id': '7086997101',
#   '_index': 'github',
#   '_score': 0.999999,
#   '_source.actor.id': 35341807,
#   '_source.created_at': '2018-01-11T16:25:52Z',
#   '_source.id': '7086997101',
#   '_source.payload.comment.commit_id': '',
#   '_source.payload.commits': '',
#   '_source.repo.id': 117123930,
#   '_source.repo.name': 'sheminaz/DemoTest',
#   '_source.type': 'CreateEvent',
#   '_type': 'data'},
#  {'_id': '7101638565',
#   '_index': 'github',
#   '_score': 0.999999,
#   '_source.actor.id': 7769313,
#   '_source.created_at': '2018-01-15T18:23:44Z',
#   '_source.id': '7101638565',
#   '_source.payload.comment.commit_id': '',
#   '_source.payload.commits': 'placeholder for queue name for htcondor',
#   '_source.repo.id': 86180687,
#   '_source.repo.name': 'TGAC/grassroots-core',
#   '_source.type': 'PushEvent',
#   '_type': 'data'},
#  {'_id': '7109947378',
#   '_index': 'github',
#   '_score': 0.999999,
#   '_source.actor.id': 35522968,
#   '_source.created_at': '2018-01-17T08:54:24Z',
#   '_source.id': '7109947378',
#   '_source.payload.comment.commit_id': '',
#   '_source.payload.commits': '',
#   '_source.repo.id': 117810494,
#   '_source.repo.name': 'yzwia/vision',
#   '_source.type': 'CreateEvent',
#   '_type': 'data'},
#  {'_id': '7116249922',
#   '_index': 'github',
#   '_score': 0.999999,
#   '_source.actor.id': 207405,
#   '_source.created_at': '2018-01-18T10:19:57Z',
#   '_source.id': '7116249922',
#   '_source.payload.comment.commit_id': '',
#   '_source.payload.commits': 'auto publish 2018-01-18 10:19:54+00:00',
#   '_source.repo.id': 36236297,
#   '_source.repo.name': 'sagemath/planet',
#   '_source.type': 'PushEvent',
#   '_type': 'data'},
#  {'_id': '7122313398',
#   '_index': 'github',
#   '_score': 0.999999,
#   '_source.actor.id': 9824023,
#   '_source.created_at': '2018-01-19T11:16:35Z',
#   '_source.id': '7122313398',
#   '_source.payload.comment.commit_id': '',
#   '_source.payload.commits': 'sql: Disable asserts for release builds\n\nMacro SQLITE_DEBUG was set unconditionally, so both release build\nmodes had debugging enabled, including all asserts() and TESTCASE().\nMove this macro definition under check if mode is Debug and fix all\nwarning which arised after disabling asserts().\nMost of them are unused variables.,sql: Enable asserts for box/sql.c\n\nSince asserts were always disbled in src/box/sql.c, number\nof issues were hidden. This patch enables asserts for mentioned\nfile by disabling set of NDEBUG in box/src/sqliteInt.h.\nAlso this patch fixes incorrect assertions about strlen() and\nassertion that fieldno should always be less than format->field_count.\nThis assert is not always hold, e.g. for _schema space where max_id\nis stored behind formatted fields.\n\nCloses #3057',
#   '_source.repo.id': 911980,
#   '_source.repo.name': 'tarantool/tarantool',
#   '_source.type': 'PushEvent',
#   '_type': 'data'},
#  {'_id': '7161160056',
#   '_index': 'github',
#   '_score': 0.999999,
#   '_source.actor.id': 2992398,
#   '_source.created_at': '2018-01-28T10:53:12Z',
#   '_source.id': '7161160056',
#   '_source.payload.comment.commit_id': '',
#   '_source.payload.commits': 'Ajout forRoot',
#   '_source.repo.id': 112198184,
#   '_source.repo.name': 'Agesse/NGAgesse',
#   '_source.type': 'PushEvent',
#   '_type': 'data'},
#  {'_id': '7128370422',
#   '_index': 'github',
#   '_score': 0.999999,
#   '_source.actor.id': 19528094,
#   '_source.created_at': '2018-01-21T11:12:32Z',
#   '_source.id': '7128370422',
#   '_source.payload.comment.commit_id': '',
#   '_source.payload.commits': 'Update data.json',
#   '_source.repo.id': 59465493,
#   '_source.repo.name': 'shenzhouzd/update',
#   '_source.type': 'PushEvent',
#   '_type': 'data'},
#  {'_id': '7145312263',
#   '_index': 'github',
#   '_score': 0.999999,
#   '_source.actor.id': 35577041,
#   '_source.created_at': '2018-01-24T16:50:12Z',
#   '_source.id': '7145312263',
#   '_source.payload.comment.commit_id': '',
#   '_source.payload.commits': 'Update index.html',
#   '_source.repo.id': 118027131,
#   '_source.repo.name': 'Jmb1922/jmb1922.github.io',
#   '_source.type': 'PushEvent',
#   '_type': 'data'},
#  {'_id': '5131817850',
#   '_index': 'github',
#   '_score': 0.999999,
#   '_source.actor.id': 19152466,
#   '_source.created_at': '2017-01-10T21:09:38Z',
#   '_source.id': '5131817850',
#   '_source.payload.comment.commit_id': '',
#   '_source.payload.commits': 'Final ver.',
#   '_source.repo.id': 78215780,
#   '_source.repo.name': 'catSalem/KPI-Files',
#   '_source.type': 'PushEvent',
#   '_type': 'data'},
#  {'_id': '7142247221',
#   '_index': 'github',
#   '_score': 0.999999,
#   '_source.actor.id': 23658480,
#   '_source.created_at': '2018-01-24T05:36:51Z',
#   '_source.id': '7142247221',
#   '_source.payload.comment.commit_id': '',
#   '_source.payload.commits': 'small change',
#   '_source.repo.id': 117473450,
#   '_source.repo.name': 'Yujia-Wang/yujia-wang.github.io',
#   '_source.type': 'PushEvent',
#   '_type': 'data'},
#  {'_id': '7136107484',
#   '_index': 'github',
#   '_score': 0.999999,
#   '_source.actor.id': 22823376,
#   '_source.created_at': '2018-01-23T05:04:59Z',
#   '_source.id': '7136107484',
#   '_source.payload.comment.commit_id': '',
#   '_source.payload.commits': 'Add measurement measurements/circuit/2018-01-23T05:04:58.084289.json.',
#   '_source.repo.id': 70839104,
#   '_source.repo.name': 'StanfordLegion/perf-data',
#   '_source.type': 'PushEvent',
#   '_type': 'data'},
#  {'_id': '5134491342',
#   '_index': 'github',
#   '_score': 0.999999,
#   '_source.actor.id': 4760551,
#   '_source.created_at': '2017-01-11T09:12:22Z',
#   '_source.id': '5134491342',
#   '_source.payload.comment.commit_id': '',
#   '_source.payload.commits': "- fixed the railgun's spiral duration was set incorrectly.",
#   '_source.repo.id': 10879376,
#   '_source.repo.name': 'coelckers/gzdoom',
#   '_source.type': 'PushEvent',
#   '_type': 'data'},
#  {'_id': '7163076261',
#   '_index': 'github',
#   '_score': 0.999999,
#   '_source.actor.id': 35910504,
#   '_source.created_at': '2018-01-29T05:05:16Z',
#   '_source.id': '7163076261',
#   '_source.payload.comment.commit_id': '',
#   '_source.payload.commits': '',
#   '_source.repo.id': 119334060,
#   '_source.repo.name': 'linhtetpaing9/hello-world',
#   '_source.type': 'CreateEvent',
#   '_type': 'data'},
#  {'_id': '5139262258',
#   '_index': 'github',
#   '_score': 0.999999,
#   '_source.actor.id': 1504464,
#   '_source.created_at': '2017-01-11T23:10:39Z',
#   '_source.id': '5139262258',
#   '_source.payload.comment.commit_id': '',
#   '_source.payload.commits': 'brats/brats-staticfile-edge build 8 unclaiming: edge-1.buildpacks.ci',
#   '_source.repo.id': 34543204,
#   '_source.repo.name': 'cloudfoundry/buildpacks-ci',
#   '_source.type': 'PushEvent',
#   '_type': 'data'},
#  {'_id': '5145933966',
#   '_index': 'github',
#   '_score': 0.999999,
#   '_source.actor.id': 2874596,
#   '_source.created_at': '2017-01-12T23:06:16Z',
#   '_source.id': '5145933966',
#   '_source.payload.comment.commit_id': '',
#   '_source.payload.commits': 'Update README.md',
#   '_source.repo.id': 78784569,
#   '_source.repo.name': 'pablovilla83/do-cdmx-nginx',
#   '_source.type': 'PushEvent',
#   '_type': 'data'},
#  {'_id': '5143181206',
#   '_index': 'github',
#   '_score': 0.999999,
#   '_source.actor.id': 20407524,
#   '_source.created_at': '2017-01-12T15:22:46Z',
#   '_source.id': '5143181206',
#   '_source.payload.comment.commit_id': '',
#   '_source.payload.commits': '',
#   '_source.repo.id': 20580498,
#   '_source.repo.name': 'kubernetes/kubernetes',
#   '_source.type': 'IssueCommentEvent',
#   '_type': 'data'},
#  {'_id': '7159005846',
#   '_index': 'github',
#   '_score': 0.999999,
#   '_source.actor.id': 14920103,
#   '_source.created_at': '2018-01-27T07:52:56Z',
#   '_source.id': '7159005846',
#   '_source.payload.comment.commit_id': '',
#   '_source.payload.commits': '获取用户信息接口修改',
#   '_source.repo.id': 115163628,
#   '_source.repo.name': 'Andy-Yin/XinDaSchoolAPI',
#   '_source.type': 'PushEvent',
#   '_type': 'data'},
#  {'_id': '7160312662',
#   '_index': 'github',
#   '_score': 0.999999,
#   '_source.actor.id': 3906539,
#   '_source.created_at': '2018-01-27T22:59:39Z',
#   '_source.id': '7160312662',
#   '_source.payload.comment.commit_id': '',
#   '_source.payload.commits': '',
#   '_source.repo.id': 42519441,
#   '_source.repo.name': 'chiuan/TTUIFramework',
#   '_source.type': 'WatchEvent',
#   '_type': 'data'},
#  {'_id': '7161308379',
#   '_index': 'github',
#   '_score': 0.999999,
#   '_source.actor.id': 35888182,
#   '_source.created_at': '2018-01-28T12:40:16Z',
#   '_source.id': '7161308379',
#   '_source.payload.comment.commit_id': '',
#   '_source.payload.commits': '',
#   '_source.repo.id': 119257070,
#   '_source.repo.name': 'yusuke-j0728/sample',
#   '_source.type': 'CreateEvent',
#   '_type': 'data'},
#  {'_id': '5150807757',
#   '_index': 'github',
#   '_score': 0.999999,
#   '_source.actor.id': 11401319,
#   '_source.created_at': '2017-01-13T19:06:22Z',
#   '_source.id': '5150807757',
#   '_source.payload.comment.commit_id': '',
#   '_source.payload.commits': 'uploading project',
#   '_source.repo.id': 78876321,
#   '_source.repo.name': 'stone-pagamentos/demo-sdk-android',
#   '_source.type': 'PushEvent',
#   '_type': 'data'},
#  {'_id': '7166842610',
#   '_index': 'github',
#   '_score': 0.999999,
#   '_source.actor.id': 5539247,
#   '_source.created_at': '2018-01-29T18:33:11Z',
#   '_source.id': '7166842610',
#   '_source.payload.comment.commit_id': '',
#   '_source.payload.commits': 'Removed .DS_Store file from repository',
#   '_source.repo.id': 108033929,
#   '_source.repo.name': 'jdelcastillo1/Pythium_Pop',
#   '_source.type': 'PushEvent',
#   '_type': 'data'},
#  {'_id': '5162998187',
#   '_index': 'github',
#   '_score': 0.999999,
#   '_source.actor.id': 24291069,
#   '_source.created_at': '2017-01-17T03:58:21Z',
#   '_source.id': '5162998187',
#   '_source.payload.comment.commit_id': '',
#   '_source.payload.commits': 'Update huanxingtu.html',
#   '_source.repo.id': 77388549,
#   '_source.repo.name': 'likailun6/likailun6.github.io',
#   '_source.type': 'PushEvent',
#   '_type': 'data'},
#  {'_id': '5154983935',
#   '_index': 'github',
#   '_score': 0.999999,
#   '_source.actor.id': 1060,
#   '_source.created_at': '2017-01-15T06:45:29Z',
#   '_source.id': '5154983935',
#   '_source.payload.comment.commit_id': '',
#   '_source.payload.commits': '',
#   '_source.repo.id': 46619651,
#   '_source.repo.name': 'librariesio/sentinel',
#   '_source.type': 'IssuesEvent',
#   '_type': 'data'},
#  {'_id': '5172629697',
#   '_index': 'github',
#   '_score': 0.999999,
#   '_source.actor.id': 431261,
#   '_source.created_at': '2017-01-18T14:07:21Z',
#   '_source.id': '5172629697',
#   '_source.payload.comment.commit_id': '',
#   '_source.payload.commits': '',
#   '_source.repo.id': 17143026,
#   '_source.repo.name': 'jarcoal/httpmock',
#   '_source.type': 'MemberEvent',
#   '_type': 'data'},
#  {'_id': '7174712747',
#   '_index': 'github',
#   '_score': 0.999999,
#   '_source.actor.id': 33104488,
#   '_source.created_at': '2018-01-31T01:03:14Z',
#   '_source.id': '7174712747',
#   '_source.payload.comment.commit_id': '',
#   '_source.payload.commits': '',
#   '_source.repo.id': 108593869,
#   '_source.repo.name': 'dipper-github-fra-sin-syd-nrt/test-python-sample',
#   '_source.type': 'CreateEvent',
#   '_type': 'data'},
#  {'_id': '5177467656',
#   '_index': 'github',
#   '_score': 0.999999,
#   '_source.actor.id': 2328242,
#   '_source.created_at': '2017-01-19T06:14:01Z',
#   '_source.id': '5177467656',
#   '_source.payload.comment.commit_id': 'df5752f03030a5e03cfc4c74c5914abb59ea42da',
#   '_source.payload.commits': '',
#   '_source.repo.id': 57415761,
#   '_source.repo.name': 'gereeter/crossbeam',
#   '_source.type': 'PullRequestReviewCommentEvent',
#   '_type': 'data'},
#  {'_id': '7065861304',
#   '_index': 'github',
#   '_score': 0.99999887,
#   '_source.actor.id': 5384588,
#   '_source.created_at': '2018-01-07T02:03:17Z',
#   '_source.id': '7065861304',
#   '_source.payload.comment.commit_id': '',
#   '_source.payload.commits': '',
#   '_source.repo.id': 98467418,
#   '_source.repo.name': 'google-test/signcla-probe-repo',
#   '_source.type': 'IssueCommentEvent',
#   '_type': 'data'},
#  {'_id': '7062015788',
#   '_index': 'github',
#   '_score': 0.99999887,
#   '_source.actor.id': 536803,
#   '_source.created_at': '2018-01-05T15:41:16Z',
#   '_source.id': '7062015788',
#   '_source.payload.comment.commit_id': '',
#   '_source.payload.commits': '',
#   '_source.repo.id': 17803236,
#   '_source.repo.name': 'ncw/rclone',
#   '_source.type': 'IssuesEvent',
#   '_type': 'data'},
#  {'_id': '5120619939',
#   '_index': 'github',
#   '_score': 0.99999887,
#   '_source.actor.id': 24999509,
#   '_source.created_at': '2017-01-09T04:59:44Z',
#   '_source.id': '5120619939',
#   '_source.payload.comment.commit_id': '',
#   '_source.payload.commits': '',
#   '_source.repo.id': 78395316,
#   '_source.repo.name': 'ItsRaw/ExoticBans',
#   '_source.type': 'CreateEvent',
#   '_type': 'data'},
#  {'_id': '7068805513',
#   '_index': 'github',
#   '_score': 0.99999887,
#   '_source.actor.id': 8314092,
#   '_source.created_at': '2018-01-08T10:07:58Z',
#   '_source.id': '7068805513',
#   '_source.payload.comment.commit_id': '',
#   '_source.payload.commits': 'Updated: archive.md',
#   '_source.repo.id': 109661188,
#   '_source.repo.name': 'unconfigured/unconfigured.github.io',
#   '_source.type': 'PushEvent',
#   '_type': 'data'},
#  {'_id': '7096235012',
#   '_index': 'github',
#   '_score': 0.99999887,
#   '_source.actor.id': 13212452,
#   '_source.created_at': '2018-01-14T03:31:03Z',
#   '_source.id': '7096235012',
#   '_source.payload.comment.commit_id': '',
# ...
#   '_source.id': '7095596376',
#   '_source.payload.comment.commit_id': '',
#   '_source.payload.commits': 'GIT CloneShare Commit',
#   '_source.repo.id': 117347799,
#   '_source.repo.name': 'amaximus/JamesBond',
#   '_source.type': 'PushEvent',
#   '_type': 'data'},
#  {'_id': '7084540758',
#   '_index': 'github',
#   '_score': 0.9999813,
#   '_source.actor.id': 35326208,
#   '_source.created_at': '2018-01-11T07:26:18Z',
#   '_source.id': '7084540758',
#   '_source.payload.comment.commit_id': '',
#   '_source.payload.commits': 'Add files via upload',
#   '_source.repo.id': 117065133,
#   '_source.repo.name': 'AdhetyaPutra/PerancanganWeb',
#   '_source.type': 'PushEvent',
#   '_type': 'data'},
#  {'_id': '7075372249',
#   '_index': 'github',
#   '_score': 0.9999813,
#   '_source.actor.id': 22060658,
#   '_source.created_at': '2018-01-09T14:46:45Z',
#   '_source.id': '7075372249',
#   '_source.payload.comment.commit_id': '',
#   '_source.payload.commits': 'Delete .gitignore~',
#   '_source.repo.id': 114273918,
#   '_source.repo.name': 'konopac/MovieListApp',
#   '_source.type': 'PushEvent',
#   '_type': 'data'},
#  {'_id': '7153856956',
#   '_index': 'github',
#   '_score': 0.9999813,
#   '_source.actor.id': 3455798,
#   '_source.created_at': '2018-01-26T04:36:20Z',
#   '_source.id': '7153856956',
#   '_source.payload.comment.commit_id': '',
#   '_source.payload.commits': '',
#   '_source.repo.id': 94298220,
#   '_source.repo.name': 'alibaba/react-intl-universal',
#   '_source.type': 'IssueCommentEvent',
#   '_type': 'data'},
#  {'_id': '7087899765',
#   '_index': 'github',
#   '_score': 0.9999813,
#   '_source.actor.id': 13518195,
#   '_source.created_at': '2018-01-11T19:29:18Z',
#   '_source.id': '7087899765',
#   '_source.payload.comment.commit_id': '',
#   '_source.payload.commits': '',
#   '_source.repo.id': 116836845,
#   '_source.repo.name': 'DavidJonDiana/sugar-rush',
#   '_source.type': 'PullRequestEvent',
#   '_type': 'data'},
#  {'_id': '7102407328',
#   '_index': 'github',
#   '_score': 0.9999813,
#   '_source.actor.id': 7333583,
#   '_source.created_at': '2018-01-15T22:05:47Z',
#   '_source.id': '7102407328',
#   '_source.payload.comment.commit_id': '',
#   '_source.payload.commits': '',
#   '_source.repo.id': 117598844,
#   '_source.repo.name': 'hytung/hytung.github.io',
#   '_source.type': 'PullRequestEvent',
#   '_type': 'data'},
#  {'_id': '7108038101',
#   '_index': 'github',
#   '_score': 0.9999813,
#   '_source.actor.id': 10270330,
#   '_source.created_at': '2018-01-16T22:13:22Z',
#   '_source.id': '7108038101',
#   '_source.payload.comment.commit_id': '',
#   '_source.payload.commits': 'Update',
#   '_source.repo.id': 114691623,
#   '_source.repo.name': 'yuchingho/university',
#   '_source.type': 'PushEvent',
#   '_type': 'data'},
#  {'_id': '7124365308',
#   '_index': 'github',
#   '_score': 0.9999813,
#   '_source.actor.id': 7640693,
#   '_source.created_at': '2018-01-19T18:36:19Z',
#   '_source.id': '7124365308',
#   '_source.payload.comment.commit_id': '',
#   '_source.payload.commits': '',
#   '_source.repo.id': 118163451,
#   '_source.repo.name': 'ngesa254/Digital-Outputs-with-Rainbow-Hat-LEDs',
#   '_source.type': 'CreateEvent',
#   '_type': 'data'},
#  {'_id': '7114498455',
#   '_index': 'github',
#   '_score': 0.9999813,
#   '_source.actor.id': 28941271,
#   '_source.created_at': '2018-01-18T01:04:09Z',
#   '_source.id': '7114498455',
#   '_source.payload.comment.commit_id': '',
#   '_source.payload.commits': '',
#   '_source.repo.id': 109101070,
#   '_source.repo.name': 'ouzhrm/useGithubByDeveloper',
#   '_source.type': 'WatchEvent',
#   '_type': 'data'},
#  {'_id': '7125413948',
#   '_index': 'github',
#   '_score': 0.9999813,
#   '_source.actor.id': 32054652,
#   '_source.created_at': '2018-01-19T22:55:54Z',
#   '_source.id': '7125413948',
#   '_source.payload.comment.commit_id': '',
#   '_source.payload.commits': 'Update documentation',
#   '_source.repo.id': 117305331,
#   '_source.repo.name': 'VizRI/vizri.github.io',
#   '_source.type': 'PushEvent',
#   '_type': 'data'},
#  {'_id': '5153807691',
#   '_index': 'github',
#   '_score': 0.9999813,
#   '_source.actor.id': 160078,
#   '_source.created_at': '2017-01-14T16:14:08Z',
#   '_source.id': '5153807691',
#   '_source.payload.comment.commit_id': '',
#   '_source.payload.commits': 'Minor fix.',
#   '_source.repo.id': 72878106,
#   '_source.repo.name': 'brettkromkamp/story_engine',
#   '_source.type': 'PushEvent',
#   '_type': 'data'},
#  {'_id': '7128250760',
#   '_index': 'github',
#   '_score': 0.9999813,
#   '_source.actor.id': 17859844,
#   '_source.created_at': '2018-01-21T09:36:03Z',
#   '_source.id': '7128250760',
#   '_source.payload.comment.commit_id': '',
#   '_source.payload.commits': '',
#   '_source.repo.id': 76328745,
#   '_source.repo.name': 'mananapr/dotfiles',
#   '_source.type': 'WatchEvent',
#   '_type': 'data'},
#  {'_id': '7146991256',
#   '_index': 'github',
#   '_score': 0.9999813,
#   '_source.actor.id': 25781788,
#   '_source.created_at': '2018-01-24T22:35:53Z',
#   '_source.id': '7146991256',
#   '_source.payload.comment.commit_id': '',
#   '_source.payload.commits': 'fixed layout problem temporarly until more style changes made,changes to the css and the color pattern of the website',
#   '_source.repo.id': 118637698,
#   '_source.repo.name': 'ErikaDib/SmartCheckoutProject',
#   '_source.type': 'PushEvent',
#   '_type': 'data'},
#  {'_id': '7141142014',
#   '_index': 'github',
#   '_score': 0.9999813,
#   '_source.actor.id': 4700817,
#   '_source.created_at': '2018-01-23T23:08:18Z',
#   '_source.id': '7141142014',
#   '_source.payload.comment.commit_id': '',
#   '_source.payload.commits': 'adds name',
#   '_source.repo.id': 78133698,
#   '_source.repo.name': 'hbahamonde/Comparative_Politics_UGRAD',
#   '_source.type': 'PushEvent',
#   '_type': 'data'},
#  {'_id': '7142362995',
#   '_index': 'github',
#   '_score': 0.9999813,
#   '_source.actor.id': 3425702,
#   '_source.created_at': '2018-01-24T06:20:25Z',
#   '_source.id': '7142362995',
#   '_source.payload.comment.commit_id': '',
#   '_source.payload.commits': '',
#   '_source.repo.id': 3100121,
#   '_source.repo.name': 'nwjs/nw.js',
#   '_source.type': 'WatchEvent',
#   '_type': 'data'},
#  {'_id': '7137226663',
#   '_index': 'github',
#   '_score': 0.9999813,
#   '_source.actor.id': 9041370,
#   '_source.created_at': '2018-01-23T10:15:37Z',
#   '_source.id': '7137226663',
#   '_source.payload.comment.commit_id': '',
#   '_source.payload.commits': 'Add issue template,Add pull request template,Merge pull request #1 from dan1elhughes/feature/github-template-integration\n\nGitHub template integration',
#   '_source.repo.id': 118454607,
#   '_source.repo.name': 'HeathWallace/ethereum-pos',
#   '_source.type': 'PushEvent',
#   '_type': 'data'},
#  {'_id': '7148250330',
#   '_index': 'github',
#   '_score': 0.9999813,
#   '_source.actor.id': 35626411,
#   '_source.created_at': '2018-01-25T05:45:16Z',
#   '_source.id': '7148250330',
#   '_source.payload.comment.commit_id': '',
#   '_source.payload.commits': '',
#   '_source.repo.id': 118866564,
#   '_source.repo.name': 'RashikaMishra95/DemoNode',
#   '_source.type': 'PullRequestEvent',
#   '_type': 'data'},
#  {'_id': '7163337145',
#   '_index': 'github',
#   '_score': 0.9999813,
#   '_source.actor.id': 15681491,
#   '_source.created_at': '2018-01-29T06:48:21Z',
#   '_source.id': '7163337145',
#   '_source.payload.comment.commit_id': '',
#   '_source.payload.commits': '简单的restful服务',
#   '_source.repo.id': 119325090,
#   '_source.repo.name': 'yejunyu/spring-boot-practise2',
#   '_source.type': 'PushEvent',
#   '_type': 'data'},
#  {'_id': '7152898861',
#   '_index': 'github',
#   '_score': 0.9999813,
#   '_source.actor.id': 1255037,
#   '_source.created_at': '2018-01-25T22:48:52Z',
#   '_source.id': '7152898861',
#   '_source.payload.comment.commit_id': '',
#   '_source.payload.commits': '',
#   '_source.repo.id': 1377159,
#   '_source.repo.name': 'coq/coq',
#   '_source.type': 'IssueCommentEvent',
#   '_type': 'data'},
#  {'_id': '7156236348',
#   '_index': 'github',
#   '_score': 0.9999813,
#   '_source.actor.id': 4370550,
#   '_source.created_at': '2018-01-26T15:39:50Z',
#   '_source.id': '7156236348',
#   '_source.payload.comment.commit_id': '',
#   '_source.payload.commits': '',
#   '_source.repo.id': 1257084,
#   '_source.repo.name': 'dlang/phobos',
#   '_source.type': 'PullRequestEvent',
#   '_type': 'data'},
#  {'_id': '7158579262',
#   '_index': 'github',
#   '_score': 0.9999813,
#   '_source.actor.id': 8337409,
#   '_source.created_at': '2018-01-27T02:03:11Z',
#   '_source.id': '7158579262',
#   '_source.payload.comment.commit_id': '',
#   '_source.payload.commits': '',
#   '_source.repo.id': 119123533,
#   '_source.repo.name': 'deikatsuo/btc-id',
#   '_source.type': 'CreateEvent',
#   '_type': 'data'},
#  {'_id': '5149621270',
#   '_index': 'github',
#   '_score': 0.9999813,
#   '_source.actor.id': 10059507,
#   '_source.created_at': '2017-01-13T15:19:28Z',
#   '_source.id': '5149621270',
#   '_source.payload.comment.commit_id': '',
#   '_source.payload.commits': 'Update manifest.jps',
#   '_source.repo.id': 78859254,
#   '_source.repo.name': 'yulchitaj/lets-encrypt',
#   '_source.type': 'PushEvent',
#   '_type': 'data'},
#  {'_id': '5152154709',
#   '_index': 'github',
#   '_score': 0.9999813,
#   '_source.actor.id': 20230450,
#   '_source.created_at': '2017-01-13T23:50:42Z',
#   '_source.id': '5152154709',
#   '_source.payload.comment.commit_id': '',
#   '_source.payload.commits': 'Update README.md',
#   '_source.repo.id': 78525453,
#   '_source.repo.name': 'MrHDR/Sun-Moon_ShinyCalc',
#   '_source.type': 'PushEvent',
#   '_type': 'data'},
#  {'_id': '7161074494',
#   '_index': 'github',
#   '_score': 0.9999813,
#   '_source.actor.id': 158862,
#   '_source.created_at': '2018-01-28T09:46:42Z',
#   '_source.id': '7161074494',
#   '_source.payload.comment.commit_id': '',
#   '_source.payload.commits': '',
#   '_source.repo.id': 110998941,
#   '_source.repo.name': 'arlac77/local-repository-provider',
#   '_source.type': 'DeleteEvent',
#   '_type': 'data'},
#  {'_id': '7159982723',
#   '_index': 'github',
#   '_score': 0.9999813,
#   '_source.actor.id': 1589480,
#   '_source.created_at': '2018-01-27T19:29:22Z',
#   '_source.id': '7159982723',
#   '_source.payload.comment.commit_id': '',
#   '_source.payload.commits': 'ranger: fix homepage,ranger: update 1.8.1 bottle.',
#   '_source.repo.id': 53493223,
#   '_source.repo.name': 'BrewTestBot/homebrew-core',
#   '_source.type': 'PushEvent',
#   '_type': 'data'},
#  {'_id': '7166732586',
#   '_index': 'github',
#   '_score': 0.9999813,
#   '_source.actor.id': 323385,
#   '_source.created_at': '2018-01-29T18:10:50Z',
#   '_source.id': '7166732586',
#   '_source.payload.comment.commit_id': '',
#   '_source.payload.commits': 'Revert "Release of eeacms/apache-eea-www:5.0"\n\nThis reverts commit fb59357534a9ab31fad98f78783152c7e17b2dc2.,Revert "Prepare for release of eeacms/apache-eea-www:5.0"\n\nThis reverts commit 3f9d10842f75dd75229549b7fc93d1128f4c8cf4.',
#   '_source.repo.id': 48365759,
#   '_source.repo.name': 'eea/eea.rancher.catalog',
#   '_source.type': 'PushEvent',
#   '_type': 'data'},
#  {'_id': '7168766803',
#   '_index': 'github',
#   '_score': 0.9999813,
#   '_source.actor.id': 8546787,
#   '_source.created_at': '2018-01-30T02:17:24Z',
#   '_source.id': '7168766803',
#   '_source.payload.comment.commit_id': '',
#   '_source.payload.commits': 'key now must be one of the cache names',
#   '_source.repo.id': 101675455,
#   '_source.repo.name': 'databio/shinyLOLA',
#   '_source.type': 'PushEvent',
#   '_type': 'data'},
#  {'_id': '7164274927',
#   '_index': 'github',
#   '_score': 0.9999813,
#   '_source.actor.id': 29216624,
#   '_source.created_at': '2018-01-29T10:38:43Z',
#   '_source.id': '7164274927',
#   '_source.payload.comment.commit_id': '',
#   '_source.payload.commits': '',
#   '_source.repo.id': 114521849,
#   '_source.repo.name': 'Mouris1/SpotterProps',
#   '_source.type': 'IssuesEvent',
#   '_type': 'data'},
#  {'_id': '7166101979',
#   '_index': 'github',
#   '_score': 0.9999813,
#   '_source.actor.id': 8078968,
#   '_source.created_at': '2018-01-29T16:16:20Z',
#   '_source.id': '7166101979',
#   '_source.payload.comment.commit_id': '9558dc9e1507e7fcc83d1de0010c41fb31970c5c',
#   '_source.payload.commits': '',
#   '_source.repo.id': 858127,
#   '_source.repo.name': 'pandas-dev/pandas',
#   '_source.type': 'PullRequestReviewCommentEvent',
#   '_type': 'data'},
#  {'_id': '5166516586',
#   '_index': 'github',
#   '_score': 0.9999813,
#   '_source.actor.id': 8770962,
#   '_source.created_at': '2017-01-17T16:24:46Z',
#   '_source.id': '5166516586',
#   '_source.payload.comment.commit_id': '',
#   '_source.payload.commits': '',
#   '_source.repo.id': 5427753,
#   '_source.repo.name': 'unitedstates/python-us',
#   '_source.type': 'IssuesEvent',
#   '_type': 'data'},
#  {'_id': '7180970111',
#   '_index': 'github',
#   '_score': 0.9999813,
#   '_source.actor.id': 18696528,
#   '_source.created_at': '2018-02-01T02:04:05Z',
#   '_source.id': '7180970111',
#   '_source.payload.comment.commit_id': '',
#   '_source.payload.commits': '',
#   '_source.repo.id': 113098524,
#   '_source.repo.name': 'DufourVictor/openannuaire',
#   '_source.type': 'PullRequestEvent',
#   '_type': 'data'},
#  {'_id': '5116764190',
#   '_index': 'github',
#   '_score': 0.9999803,
#   '_source.actor.id': 1175888,
#   '_source.created_at': '2017-01-07T08:10:17Z',
#   '_source.id': '5116764190',
#   '_source.payload.comment.commit_id': '',
#   '_source.payload.commits': '',
#   '_source.repo.id': 24656814,
#   '_source.repo.name': 'elyase/geotext',
#   '_source.type': 'IssueCommentEvent',
#   '_type': 'data'},
#  {'_id': '7058403913',
#   '_index': 'github',
#   '_score': 0.9999803,
#   '_source.actor.id': 22189186,
#   '_source.created_at': '2018-01-04T20:14:23Z',
#   '_source.id': '7058403913',
#   '_source.payload.comment.commit_id': '',
#   '_source.payload.commits': 'Изменены параметры теней текста и блока,Создана структура и настроены стили для шапки сайта с помощью flexbox,Скрытие панели поиска при малых разрешениях,Добавлены альтернативные цвета',
#   '_source.repo.id': 114562496,
#   '_source.repo.name': 'dimavz/dev_proj',
#   '_source.type': 'PushEvent',
#   '_type': 'data'},
#  {'_id': '7064921198',
#   '_index': 'github',
#   '_score': 0.9999803,
#   '_source.actor.id': 32674674,
#   '_source.created_at': '2018-01-06T13:45:03Z',
#   '_source.id': '7064921198',
#   '_source.payload.comment.commit_id': '',
#   '_source.payload.commits': 'Update Census special variable',
#   '_source.repo.id': 106039066,
#   '_source.repo.name': 'NYCPlanning/labs-nyc-factfinder',
#   '_source.type': 'PushEvent',
#   '_type': 'data'},
#  {'_id': '7071741771',
#   '_index': 'github',
#   '_score': 0.9999803,
#   '_source.actor.id': 3019665,
#   '_source.created_at': '2018-01-08T21:15:09Z',
#   '_source.id': '7071741771',
#   '_source.payload.comment.commit_id': '',
#   '_source.payload.commits': 'Provide option to publish releases to GitHub\n\nIn order to upload artifacts, we need a preexisting release on GitHub.\nThat release can be a prerelease or not. So provide an option in the\n`release.py` script to publish a prerelease or a final release. In\norder to make this work smoothly with pushing and handle changing the\nrelease type, allow the remote to be specified independently of whether\nto push or not.\n\n[skip appveyor]\n[appveyor skip],Pass `--tag` to `release.py` tests\n\nNow that `--tag` must be explicitly passed (due to the GitHub release\npublishing process), add that to the CircleCI tests.\n\n[skip appveyor]\n[appveyor skip],Merge pull request #26 from jakirkham/release_publish_gh\n\nPublish GitHub Release',
#   '_source.repo.id': 115889434,
#   '_source.repo.name': 'jakirkham/miniforge',
#   '_source.type': 'PushEvent',
#   '_type': 'data'},
#  {'_id': '7100265967',
#   '_index': 'github',
#   '_score': 0.9999803,
#   '_source.actor.id': 17463361,
#   '_source.created_at': '2018-01-15T13:34:17Z',
#   '_source.id': '7100265967',
#   '_source.payload.comment.commit_id': '',
#   '_source.payload.commits': '',
#   '_source.repo.id': 50881110,
#   '_source.repo.name': 'aimacode/aima-python',
#   '_source.type': 'IssueCommentEvent',
#   '_type': 'data'},
#  {'_id': '7091666141',
#   '_index': 'github',
#   '_score': 0.9999803,
#   '_source.actor.id': 30829071,
#   '_source.created_at': '2018-01-12T13:58:56Z',
#   '_source.id': '7091666141',
#   '_source.payload.comment.commit_id': '',
#   '_source.payload.commits': 'first chapter',
#   '_source.repo.id': 117092761,
#   '_source.repo.name': 'PanMartinez/Django_Tut',
#   '_source.type': 'PushEvent',
#   '_type': 'data'}]

# %%
# ?map
# Out:
# Init signature: map(self, /, *args, **kwargs)
# Docstring:
# map(func, *iterables) --> map object
#
# Make an iterator that computes the function using arguments from
# each of the iterables.  Stops when the shortest iterable is exhausted.
# Type:           type

# %%
xdix
# Out:
#             _id  _index    _score  _source.actor.id    _source.created_at  \
# 0    5128174503  github  1.000000          22254315  2017-01-10T10:33:53Z
# 1    5117709046  github  1.000000          18059751  2017-01-07T19:46:13Z
# 2    7063984556  github  1.000000           3397638  2018-01-06T00:53:42Z
# 3    7070599425  github  1.000000          10004612  2018-01-08T16:53:25Z
# 4    7099871799  github  1.000000          35448313  2018-01-15T12:00:32Z
# 5    7095743601  github  1.000000          33013318  2018-01-13T20:28:03Z
# 6    7085071222  github  1.000000          12358972  2018-01-11T09:41:07Z
# 7    7077218812  github  1.000000          31147364  2018-01-09T21:11:33Z
# 8    7178088487  github  1.000000          33209918  2018-01-31T15:33:40Z
# 9    7087861705  github  1.000000          24903720  2018-01-11T19:20:56Z
# 10   7101992625  github  1.000000           4083846  2018-01-15T20:02:45Z
# 11   7110526897  github  1.000000          33623047  2018-01-17T10:56:27Z
# 12   7114021614  github  1.000000             66500  2018-01-17T22:37:46Z
# 13   7124404153  github  1.000000          18581488  2018-01-19T18:45:30Z
# 14   7126749746  github  1.000000          10847488  2018-01-20T14:10:59Z
# 15   7151138914  github  1.000000          20861293  2018-01-25T16:35:34Z
# 16   7143869580  github  1.000000          13482856  2018-01-24T12:25:25Z
# 17   7131835506  github  1.000000          34455040  2018-01-22T12:32:56Z
# 18   7157766649  github  1.000000            401055  2018-01-26T21:12:04Z
# 19   5155611662  github  1.000000           4602382  2017-01-15T14:44:29Z
# 20   7170828258  github  1.000000          21197492  2018-01-30T11:51:05Z
# 21   5158812707  github  1.000000           3344634  2017-01-16T12:01:34Z
# 22   5174876263  github  1.000000            182893  2017-01-18T19:46:25Z
# 23   7059914974  github  0.999999          12240115  2018-01-05T05:20:05Z
# 24   5115515049  github  0.999999           6569980  2017-01-06T22:04:25Z
# 25   5121133098  github  0.999999           8265472  2017-01-09T08:29:05Z
# 26   7071701531  github  0.999999            153498  2018-01-08T21:05:34Z
# 27   7100041158  github  0.999999          34911577  2018-01-15T12:42:46Z
# 28   7094575315  github  0.999999           8517910  2018-01-13T05:13:37Z
# 29   7083867302  github  0.999999          23428392  2018-01-11T02:57:45Z
# ..          ...     ...       ...               ...                   ...
# 970  7161070321  github  0.999984          35732885  2018-01-28T09:43:27Z
# 971  7159978752  github  0.999984          11829420  2018-01-27T19:26:50Z
# 972  7166723920  github  0.999984          11447263  2018-01-29T18:09:07Z
# 973  5161519969  github  0.999984           8517910  2017-01-16T20:36:40Z
# 974  7164265593  github  0.999984          25581967  2018-01-29T10:36:46Z
# 975  7166092864  github  0.999984           8517910  2018-01-29T16:14:49Z
# 976  7174557049  github  0.999984          11900174  2018-01-31T00:14:38Z
# 977  7180963379  github  0.999984          17734229  2018-02-01T02:01:46Z
# 978  7059339412  github  0.999984           2354108  2018-01-05T00:56:19Z
# 979  5122403065  github  0.999984          15882411  2017-01-09T13:23:23Z
# 980  5128627302  github  0.999984           3416770  2017-01-10T12:07:57Z
# 981  7086121279  github  0.999984           5760625  2018-01-11T13:34:38Z
# 982  7128104777  github  0.999984           4974203  2018-01-21T07:28:33Z
# 983  5138345149  github  0.999984          22400602  2017-01-11T20:25:17Z
# 984  7157834695  github  0.999984          28494872  2018-01-26T21:29:25Z
# 985  7171234893  github  0.999984          33193871  2018-01-30T13:19:30Z
# 986  5176346562  github  0.999984            504826  2017-01-19T00:19:28Z
# 987  7066717583  github  0.999984          13731532  2018-01-07T14:47:59Z
# 988  7096483552  github  0.999984           9045186  2018-01-14T07:49:32Z
# 989  7177256355  github  0.999984          25549696  2018-01-31T13:01:38Z
# 990  5139460010  github  0.999984           1787524  2017-01-11T23:53:40Z
# 991  7158309416  github  0.999984          35740132  2018-01-26T23:50:56Z
# 992  7175527308  github  0.999984           4777881  2018-01-31T06:04:36Z
# 993  7183073025  github  0.999984           8478530  2018-02-01T12:04:17Z
# 994  7066434023  github  0.999983          19528094  2018-01-07T11:17:14Z
# 995  7066855801  github  0.999983              4287  2018-01-07T16:19:01Z
# 996  5118528243  github  0.999983            146378  2017-01-08T07:02:58Z
# 997  5122014331  github  0.999983           1094804  2017-01-09T11:55:54Z
# 998  7072974558  github  0.999983          16041515  2018-01-09T03:59:47Z
# 999  7100984621  github  0.999983          10827040  2018-01-15T15:55:35Z
#
#      _source.id         _source.payload.comment.commit_id  \
# 0    5128174503
# 1    5117709046
# 2    7063984556
# 3    7070599425
# 4    7099871799
# 5    7095743601
# 6    7085071222
# 7    7077218812
# 8    7178088487
# 9    7087861705
# 10   7101992625
# 11   7110526897
# 12   7114021614
# 13   7124404153
# 14   7126749746
# 15   7151138914
# 16   7143869580
# 17   7131835506
# 18   7157766649
# 19   5155611662
# 20   7170828258
# 21   5158812707
# 22   5174876263
# 23   7059914974
# 24   5115515049
# 25   5121133098
# 26   7071701531
# 27   7100041158
# 28   7094575315
# 29   7083867302
# ..          ...                                       ...
# 970  7161070321
# 971  7159978752
# 972  7166723920
# 973  5161519969
# 974  7164265593
# 975  7166092864
# 976  7174557049
# 977  7180963379
# 978  7059339412
# 979  5122403065
# 980  5128627302
# 981  7086121279
# 982  7128104777
# 983  5138345149
# 984  7157834695
# 985  7171234893
# 986  5176346562
# 987  7066717583
# 988  7096483552
# 989  7177256355
# 990  5139460010  3c9b9ba7fb60feb43c337deaee1e9a54f67238ce
# 991  7158309416
# 992  7175527308
# 993  7183073025
# 994  7066434023
# 995  7066855801
# 996  5118528243
# 997  5122014331
# 998  7072974558
# 999  7100984621
#
#                                _source.payload.commits  _source.repo.id  \
# 0                                                              78523384
# 1                                   Create License.txt         78297718
# 2                         Building out Customer Lookup        116417291
# 3                                                             115235578
# 4                     small change to our page content        117537715
# 5                             ya empieza con el loguin        117036807
# 6                                                              63971386
# 7                                                Done.        116868886
# 8    shrink subsample for testing,Merge branch 'mas...        119408549
# 9    show defender cannot attack, show attacker nee...        117137656
# 10                                                            117589821
# 11                                                             46180504
# 12                                                             94498635
# 13               Update StorageReplicatedMergeTree.cpp         60246359
# 14                                  added image upload        110230543
# 15         contact page, vue stuff, donald stuff, etc.        118720598
# 16                   出力対象の物理カラム名と論理カラム名のリストを渡せるように機能拡張        116018939
# 17                                                            118454695
# 18                                                              9902386
# 19                                          Add B.find         77706762
# 20                                      Kolbein commit        117083354
# 21                                                              1690480
# 22   ocaml: use cflags and asflags when compiling C...         47751381
# 23                       Automated update - 1515129600         65428271
# 24                                                             66337915
# 25                                                             75848989
# 26                                                              8853489
# 27   test,Merge branch 'kim' of https://github.com/...        115610892
# 28                                                             46630660
# 29                               GIT CloneShare Commit        117032643
# ..                                                 ...              ...
# 970                             Create properties.json        119232925
# 971  remove unecessary position in app.coffee,Force...        117165090
# 972                              Fixed relocated call.         90175034
# 973                                                            46596221
# 974                                      3f0dd9f 4.2.5         45538081
# 975                                                           109195865
# 976                                                           101684374
# 977                                                           119712194
# 978                                                            67315845
# 979                                    add test folder         72041650
# 980                                                            17217424
# 981                                   Remove dead todo        108689254
# 982                                        Update DATE        116946301
# 983                                                            54419658
# 984                            Connecting to DB 1.0.75        118933549
# 985                              Aggiunta galleria  JS        117450879
# 986                                                            33019098
# 987                Create Heap with counting-array.cpp        116570507
# 988                                                            68783081
# 989                                  SG/31-01-2018.txt         84247991
# 990                                                            64521641
# 991                  Made the asteroid sprite gen work        117901060
# 992                                                            87986701
# 993                                                           119830251
# 994                         2018/01/07,19:15:01 upload         59465493
# 995                         Mirroring from Micro.blog.         89624246
# 996                 Compare the value, not the pointer         64353454
# 997                                                            78423896
# 998                                    modified readme        116763207
# 999                           Improve protect function        117386716
#
#                                _source.repo.name  \
# 0                              mohit-kumar2/test
# 1                 kaisubr/monitor_android_studio
# 2        michaelburnley/reporting_slack_commands
# 3                         damoonrashidi/bitalarm
# 4                      Rishabhhtml/Coursera-test
# 5                              Roboto63/Reveles2
# 6                CodePipeline-Test/feature-tests
# 7            LynieV/css-kitten-wheelbarrow-v-000
# 8                 Mbjoerkh/data-science-practice
# 9                          alicehmd/binmat_rules
# 10                           sergiorb/gockground
# 11            FaridSafi/react-native-gifted-chat
# 12                               dawnlabs/carbon
# 13                             yandex/ClickHouse
# 14                 SvenSommer/LeisureClubWebsite
# 15                             smith-web-dev/web
# 16                    kazenetu/ASPdotNETCoreTest
# 17                                TinaMe/Menu.py
# 18                   AwsmApps/LightPaper-Support
# 19                              christianhg/bukk
# 20                            magnusEdva/NameApp
# 21                                     qgis/QGIS
# 22                         GerritCodeReview/buck
# 23                     jshatch/jshatch.github.io
# 24                       apollostack/GitHunt-API
# 25             Django-Hatchery/hatchery-core-dev
# 26                                 cozeit/czMore
# 27                        kllclcn/kthcrlkmbrlyrn
# 28           Lombiq/Orchard-Training-Demo-Module
# 29                               tacotaco2/Curie
# ..                                           ...
# 970                latheshk9/automata-aws-config
# 971                                pago88/yakyak
# 972                             BoldGrid/library
# 973    Lombiq/Combinator-TypeScript-Preprocessor
# 974                       AutoScout24/showcar-ui
# 975                  Lombiq/TryOrchard.net-Theme
# 976                       satwikkansal/wtfpython
# 977   learn-co-students/first-html-tag-lab-v-000
# 978                            botstory/botstory
# 979                        PeaceMaker503/iManage
# 980                   pawlowski/youtube-dl-queue
# 981                                terezka/lines
# 982                             vlerenc/gardener
# 983            RunnableTest/canary-github-branch
# 984                    DarthAustin42/Music-Depot
# 985               BettyMiun/Sito-Digital-Service
# 986                  RedpointGames/NDesk.Options
# 987  nikolatechie/Algorithms-and-Data-structures
# 988                                 takseki/memo
# 989                      ophobe/trending-youtube
# 990                             Noctem/pokeminer
# 991    DigiPen-Game-Development-Academy/BitFlame
# 992               michaelsevilla/paulocto-popper
# 993                         techflowing/LintCode
# 994                            shenzhouzd/update
# 995                  stevegio/stevegio.github.io
# 996                              knoxite/knoxite
# 997        timsuchanek/awesome-typescript-loader
# 998                        sanketgautam/PIFR-CNN
# 999                              skontar/Utility
#
#                       _source.type _type
# 0                      CreateEvent  data
# 1                        PushEvent  data
# 2                        PushEvent  data
# 3                       WatchEvent  data
# 4                        PushEvent  data
# 5                        PushEvent  data
# 6                      DeleteEvent  data
# 7                        PushEvent  data
# 8                        PushEvent  data
# 9                        PushEvent  data
# 10                     CreateEvent  data
# 11               IssueCommentEvent  data
# 12                      WatchEvent  data
# 13                       PushEvent  data
# 14                       PushEvent  data
# 15                       PushEvent  data
# 16                       PushEvent  data
# 17                     CreateEvent  data
# 18               IssueCommentEvent  data
# 19                       PushEvent  data
# 20                       PushEvent  data
# 21               IssueCommentEvent  data
# 22                       PushEvent  data
# 23                       PushEvent  data
# 24                     CreateEvent  data
# 25                     IssuesEvent  data
# 26               IssueCommentEvent  data
# 27                       PushEvent  data
# 28                       PushEvent  data
# 29                       PushEvent  data
# ..                             ...   ...
# 970                      PushEvent  data
# 971                      PushEvent  data
# 972                      PushEvent  data
# 973                      PushEvent  data
# 974                      PushEvent  data
# 975                      PushEvent  data
# 976                     WatchEvent  data
# 977               PullRequestEvent  data
# 978              IssueCommentEvent  data
# 979                      PushEvent  data
# 980                     WatchEvent  data
# 981                      PushEvent  data
# 982                      PushEvent  data
# 983                    DeleteEvent  data
# 984                      PushEvent  data
# 985                      PushEvent  data
# 986                    CreateEvent  data
# 987                      PushEvent  data
# 988                    GollumEvent  data
# 989                      PushEvent  data
# 990  PullRequestReviewCommentEvent  data
# 991                      PushEvent  data
# 992                    GollumEvent  data
# 993                    CreateEvent  data
# 994                      PushEvent  data
# 995                      PushEvent  data
# 996                      PushEvent  data
# 997                    CreateEvent  data
# 998                      PushEvent  data
# 999                      PushEvent  data
#
# [1000 rows x 12 columns]

# %%
import requests
import time

def sendPost(jsonData)  :
#     global target
#     xdate = date.today()
#     xdate = date.today().strftime("%Y-%m-%d %H:%M:%S.%f")
#     xdate = datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S.%f")     
    print(jsonData)
    response = requests.request("POST",'http://34.215.22.13:5000/xpost', json=jsonData)
    print(response.content)

def searchMatch():
    xreq=requests.get(database + '/_search?',headers=headers, data=json.dumps(
    {
      "query": {
        "function_score": {
          "query": {
            "match_all": {}
          },
          "functions": [
            {
              "random_score": {}
            }
          ]
        }
      }

        ,"size":1000    ,"_source":["type","created_at","id","repo.id","repo.name","actor.id","payload.comment.commit_id","payload.commits.message" ]    
    })).json() 
    return xreq
xres=searchMatch()        
xcount = len(xres['hits']['hits'])
        
while xcount>0 :
    xdix = pd.io.json.json_normalize(xres['hits']['hits'])
    xdix=xdix.fillna('')
    xdix['_source.payload.commits']=xdix['_source.payload.commits'].apply(lambda x : ','.join([v['message'] for v in x]))
    
#     for xid in xdix.rows:
    for index, xid in xdix.iterrows():
        xindex = xid._id
        print (' *** Processing id=%s *** ' % xindex)
        sendPost(  {'repo':xid['_source.repo.name'],'data':'ID : %s => MSG : %s ' % (xid._id,xid['_source.payload.commits'] if xid['_source.payload.commits']!='' else 'VIDE') , 'event': xid['_source.type']})
        
        time.sleep(3.0)
        
    xres=searchMatch()
    xcount = len(xres['hits']['hits'])
    print ( '-- count de restant : %s --' % xcount)

def xtimer():
    global t
    print(sendPost())
    t = threading.Timer(3.0, xtimer)
    t.start()

# %%
for x in xdix:
    print(x)
# Out:
# _id
# _index
# _score
# _source.actor.id
# _source.created_at
# _source.id
# _source.payload.comment.commit_id
# _source.payload.commits
# _source.repo.id
# _source.repo.name
# _source.type
# _type

# %%
        sendPost(  {'repo':xid['_source.repo.name'],'data':'ID : %s => MSG : %s ' % (xid._id, xid['_source.payload.commits'] if xid['_source.payload.commits']!='' else 'VIDE' ) , 'event': xid['_source.type']})
# Out:
# {'repo': 'YM135/YM135.github.io', 'data': 'ID : 7058486053 => MSG : Update style.scss ', 'event': 'PushEvent'}
# b'<!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 3.2 Final//EN">\n<title>500 Internal Server Error</title>\n<h1>Internal Server Error</h1>\n<p>The server encountered an internal error and was unable to complete your request.  Either the server is overloaded or there is an error in the application.</p>\n'
